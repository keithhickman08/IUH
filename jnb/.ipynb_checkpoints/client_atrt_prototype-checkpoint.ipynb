# %% [markdown]
# # Weekly Core Metric Analysis
#
# This notebook provides pre-processing, analysis, and visualization on weekly ATRT data provided by Cerner (Armand Kok) in a .csv dataset that includes daily (aggregated) timer data, transaction counts, etc... for a 90-day lookback period.
#
# 10/26:
# - **Business questions**:
#     - Which timers are negatively affecting ATRT?
#     - What is the makeup of ATRT for a given period, and how has that changed over the previous periods?
#     - When did a shift begin for a particular timer?
#     - What are the smoothed trends for our core metrics overall?
#     - What is our ATRT for relative dates (month to date, past 30/60/90, etc).
#
# **To-do**
# - [ ] consider moving to 120 day lookback period for control charts.
# - [ ] Joining most recent week's data:
#     - MySQL/postgres database that will index based on timer, date, application.
#     - run import job on .csv every week (Friday/Monday) to update with current week's data.

# %%
# Import libraries/packages
import csv
import pandas as pd
import datetime
import numpy as np
import os
from datetime import datetime 
from pandas.tseries.offsets import BDay
from scipy.stats.mstats import winsorize
#import statsmodels.api as sm
#import seaborn as sns
#import matplotlib.pyplot as plt

# %% [markdown]
# ### Import dataset and make sure it's working.
# **To-do**:
# - 10/25 automate dataset generation. Use case for hook into Vertica: Armand is currently manually giving this ds weekly.
# - 10/25 find best place to store to capture history

# %%
#client_atrt = pd.read_csv('Z:\IUH\khickman1\Datasets\client_atrt10.15.18.csv')
client_atrt = pd.read_csv('C:\\Users\\khickman1\\Desktop\\client_atrt10.29.csv')
#client_atrt = client_atrt[['dt', 'application_name', 'Timer Subtimer Name', 'ATRT']]
client_atrt.head()
len(client_atrt) #should be around 650-680k rows
# Out:
# 676399

# %% [markdown]
# ## Preprocessing
#
#  - Dates
#  - Filtering
#  - Outlier removal
#  - moving average calculation
#  - window calculation
#  - if/else statement based on window
#  - calculate UCL/LCL
#  - feature selection
#
# **To-Do**
#  - [ ] remove subtimer name?
#
# ### Date column transformation

# %%
atrt_df = pd.DataFrame(client_atrt)
atrt_df['dt'] = pd.to_datetime(atrt_df['dt'])
print(atrt_df['dt'][0:10])
atrt_df.head()
# check to make sure the 'dt' column is type:datetime64
# Out:
# 0   2018-10-01
# 1   2018-10-29
# 2   2018-08-15
# 3   2018-08-28
# 4   2018-09-11
# 5   2018-10-19
# 6   2018-08-20
# 7   2018-10-17
# 8   2018-09-13
# 9   2018-08-08
# Name: dt, dtype: datetime64[ns]
#    ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 0  0.04                         0.00%                       100.00%
# 1  0.41                         0.00%                       100.00%
# 2  0.65                         0.00%                       100.00%
# 3  0.15                         0.00%                       100.00%
# 4  0.38                         0.00%                       100.00%
#
#                                  Timer Subtimer Name  Number of Records  \
# 0  USR:SRG SNDOCDISP DISCONTINUING SEGMENT (BMH P...                  1
# 1     USR: PDOC NAVIGATOR BAND CLICK (NICU FINNEGAN)                  1
# 2        USR: ICU-OPENING-BAND (PCA ADLS AND SAFETY)                  1
# 3  USR: PDOC NAVIGATOR DOC SET CLICK (PICU RISK A...                  1
# 4  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
#
#   application_name         dt      strt                  subtimername  \
# 0   SNSURGINET.EXE 2018-10-01  0.003983       BMH PACU PHASE 1 DELAYS
# 1       POWERCHART 2018-10-29  0.087445                 NICU FINNEGAN
# 2         FIRSTNET 2018-08-15  0.075630           PCA ADLS AND SAFETY
# 3       POWERCHART 2018-08-28  0.096875          PICU RISK ASSESSMENT
# 4       POWERCHART 2018-09-11  0.311815  VB_WORKFLOWAMBPEDSCARDIOLOGY
#
#                                        timername  total_elapsed  transAbove5  \
# 0        USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.800640            0
# 1                 USR: PDOC NAVIGATOR BAND CLICK      13.028515            0
# 2                          USR: ICU-OPENING-BAND       4.530593            0
# 3              USR: PDOC NAVIGATOR DOC SET CLICK      11.668000            0
# 4  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      36.360582            0
#
#    transUnder2  transaction_cnt     isBDay
# 0           21               21 2018-10-01
# 1           32               32 2018-10-29
# 2            7                7 2018-08-15
# 3           79               79 2018-08-28
# 4           95               95 2018-09-11

# %% [markdown]
# ### Remove non-working days.
#
# Currently only removing weekends.
#
# **To-do**
# - remove federal/bank holidays?  E.g. sept 3 was labor day.
# - clean up is-bday column via subsetting or boolean

# %%
isBusinessDay = BDay().onOffset
match_series = atrt_df['dt'].map(isBusinessDay)
atrt_df['isBDay'] = atrt_df['dt'][match_series]
atrt_df
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 0       0.04                         0.00%                       100.00%
# 1       0.41                         0.00%                       100.00%
# 2       0.65                         0.00%                       100.00%
# 3       0.15                         0.00%                       100.00%
# 4       0.38                         0.00%                       100.00%
# 5       0.21                         0.00%                       100.00%
# 6       0.53                         0.00%                       100.00%
# 7       1.15                         0.00%                       100.00%
# 8       0.61                         0.00%                       100.00%
# 9       0.29                         0.00%                       100.00%
# 10      0.08                         0.00%                       100.00%
# 11      0.69                         0.00%                       100.00%
# 12      0.31                         0.00%                       100.00%
# 13      2.27                         0.66%                        35.77%
# 14      0.04                         0.00%                       100.00%
# 15      0.08                         0.00%                       100.00%
# 16      0.10                         0.00%                       100.00%
# 17      0.08                         0.00%                       100.00%
# 18      0.05                         0.00%                       100.00%
# 19      0.06                         0.00%                       100.00%
# 20      0.04                         0.00%                       100.00%
# 21      0.04                         0.00%                       100.00%
# 22      0.63                         0.00%                        96.30%
# 23      0.04                         0.00%                       100.00%
# 24      0.23                         0.00%                       100.00%
# 25      0.04                         0.00%                       100.00%
# 26      0.24                         0.00%                        99.87%
# 27      0.46                         0.00%                       100.00%
# 28      0.15                         0.00%                       100.00%
# 29      0.14                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 676369  0.29                         0.00%                       100.00%
# 676370  0.04                         0.00%                       100.00%
# 676371  0.31                         0.00%                       100.00%
# 676372  0.12                         0.00%                       100.00%
# 676373  0.52                         0.00%                       100.00%
# 676374  0.61                         0.03%                        99.78%
# 676375  0.68                         0.00%                       100.00%
# 676376  1.25                         0.00%                        76.74%
# 676377  0.12                         0.00%                       100.00%
# 676378  0.30                         0.00%                       100.00%
# 676379  0.04                         0.00%                       100.00%
# 676380  0.20                         0.00%                       100.00%
# 676381  0.07                         0.00%                       100.00%
# 676382  0.56                         0.00%                       100.00%
# 676383  0.80                         0.00%                       100.00%
# 676384  0.06                         0.00%                       100.00%
# 676385  0.14                         0.00%                       100.00%
# 676386  0.45                         0.00%                       100.00%
# 676387  0.08                         0.00%                       100.00%
# 676388  0.61                         0.00%                       100.00%
# 676389  1.41                         0.00%                       100.00%
# 676390  0.07                         0.00%                       100.00%
# 676391  0.32                         0.00%                       100.00%
# 676392  0.15                         0.00%                       100.00%
# 676393  0.85                         0.00%                        94.59%
# 676394  0.99                         1.45%                        94.20%
# 676395  0.38                         0.00%                       100.00%
# 676396  0.29                         0.00%                        97.33%
# 676397  0.28                         0.00%                       100.00%
# 676398  0.59                         0.00%                       100.00%
#
#                                       Timer Subtimer Name  Number of Records  \
# 0       USR:SRG SNDOCDISP DISCONTINUING SEGMENT (BMH P...                  1
# 1          USR: PDOC NAVIGATOR BAND CLICK (NICU FINNEGAN)                  1
# 2             USR: ICU-OPENING-BAND (PCA ADLS AND SAFETY)                  1
# 3       USR: PDOC NAVIGATOR DOC SET CLICK (PICU RISK A...                  1
# 4       USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 5       USR:MPG.MICRO.O2 - LOAD COMPONENT (VB_WORKFLOW...                  1
# 6       USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT (V...                  1
# 7       USR:SRG SNDOCDISP SAVING SEGMENT (UH RAD GENER...                  1
# 8       USR:SRG SNDOCDISP SAVING SEGMENT (NH ENDO DEPA...                  1
# 9                            USR:FAMHX.LOAD PROFILE (N/A)                  1
# 10      USR:SRG SNDOCDISP LOADING SEGMENT (UH ENDO TRA...                  1
# 11      USR:SRG SNDOCDISP SAVING SEGMENT (EHSC SPECIME...                  1
# 12      USR:SRG SNDOCDISP LOADING SEGMENT (BLH SURGICA...                  1
# 13                       USR: DOCV: ADD NEW PN NOTE (N/A)                  1
# 14      USR: ERM PMSEARCH SEARCH ENCOUNTER PREVIEW (PM...                  1
# 15                         USR:ORM.SIGNORDERS-BEGIN (N/A)                  1
# 16      USR:SRG SNDOCDISP LOADING SEGMENT (SM ENDO PAC...                  1
# 17      USR:MPG.SECONDARYASSESSMENT.O2 - LOAD COMPONEN...                  1
# 18        USR:SRG SNDOCDISP LOADING SEGMENT (UN DRESSING)                  1
# 19      USR:SRG SNDOCDISP LOADING SEGMENT (MH RAD SEDA...                  1
# 20        USR:SRG SNDOCDISP LOADING SEGMENT (CL DRESSING)                  1
# 21      USR:SRG SNDOCDISP DISCONTINUING SEGMENT (BMH P...                  1
# 22      USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 23      USR:SRG SNDOCDISP DISCONTINUING SEGMENT (MH EN...                  1
# 24      USR:PWR-REFRESH VIEW (REFRESHING PERIOP TRACKI...                  1
# 25      USR:SRG SNDOCDISP DISCONTINUING SEGMENT (MH RA...                  1
# 26      USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT (VB...                  1
# 27      USR:SRG SNDOCDISP SAVING SEGMENT (UN OB DEPART...                  1
# 28      USR:MPG.IO.O1 - LOAD COMPONENT (VB_INTRAOPERAT...                  1
# 29      USR:MPG.COMMUNICATION_EVENTS.O1.SUM - LOAD COM...                  1
# ...                                                   ...                ...
# 676369  USR:ERM PMSEARCH PERSON SEARCH RESULTS DISPLAY...                  1
# 676370                 USR:SRG SNCASE CHECK-IN CASE (N/A)                  1
# 676371  USR:MPG.MICRO.O2 - LOAD COMPONENT (VB_WORKFLOW...                  1
# 676372  USR:MPG.ACTIVITIES.O1 - LOAD COMPONENT (VB_PRE...                  1
# 676373   USR:MPG.LABS.O1 - LOAD COMPONENT (VB_AMBSUMMARY)                  1
# 676374  USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT (V...                  1
# 676375  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_AMBG...                  1
# 676376                  USR: ICU-OPENING-BAND (PICU ECMO)                  1
# 676377  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 676378      USR:ERM PMSEARCH PERSON RESULTS DISPLAY (N/A)                  1
# 676379  USR:SRG SNDOCDISP DISCONTINUING SEGMENT (SH ME...                  1
# 676380  USR:MPG.RISKFACTOR.O1 - LOAD COMPONENT (VB_WOR...                  1
# 676381  USR:SRG SNDOCDISP LOADING SEGMENT (BSC PACU PH...                  1
# 676382  USR: ICU-OPENING-BAND (PROCEDURAL PRE PROCEDUR...                  1
# 676383  USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT (VB_W...                  1
# 676384  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 676385  USR:MPG.ALLERGY.O1 - LOAD COMPONENT (VB_AMBCUS...                  1
# 676386  USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 676387  USR: PDOC NAVIGATOR DOC SET CLICK (ADULT SS PH...                  1
# 676388  USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 676389  USR:MPG.LABORATORY.WF - LOAD COMPONENT (VB_WOR...                  1
# 676390  USR:SRG SNDOCDISP LOADING SEGMENT (BLH WS DRES...                  1
# 676391  USR:SRA SAANESTHESIA DOCUMENT MEDICATION (SAAN...                  1
# 676392  USR:SRG SNDOCDISP LOADING SEGMENT (UN TOURNIQUET)                  1
# 676393  USR:PWR-PVCHART.DETAILPANE (SINCE LAST TIME.CL...                  1
# 676394  USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT (VB_A...                  1
# 676395  USR: PN OPEN NEW POWERNOTE USING PRECOMPLETED ...                  1
# 676396           USR:ORM.CONVERTTOINPATIENTMR-BEGIN (N/A)                  1
# 676397                       USR:FAMHX.LOAD PROFILE (N/A)                  1
# 676398  USR:SRG SNDOCDISP SAVING SEGMENT (RI GENERAL  ...                  1
#
#         application_name         dt      strt  \
# 0         SNSURGINET.EXE 2018-10-01  0.003983
# 1             POWERCHART 2018-10-29  0.087445
# 2               FIRSTNET 2018-08-15  0.075630
# 3             POWERCHART 2018-08-28  0.096875
# 4             POWERCHART 2018-09-11  0.311815
# 5             POWERCHART 2018-10-19  0.108207
# 6               FIRSTNET 2018-08-20  0.170823
# 7         SNSURGINET.EXE 2018-10-17  0.493563
# 8         SNSURGINET.EXE 2018-09-13  0.320618
# 9             SNSURGINET 2018-08-08  0.081754
# 10        SNSURGINET.EXE 2018-09-27  0.057678
# 11        SNSURGINET.EXE 2018-10-04  0.270045
# 12        SNSURGINET.EXE 2018-09-17  0.162258
# 13            POWERCHART 2018-10-11  1.044684
# 14           SCHAPPTBOOK 2018-10-24       NaN
# 15            SNSURGINET 2018-10-14  0.048561
# 16        SNSURGINET.EXE 2018-09-20  0.064790
# 17            POWERCHART 2018-10-25  0.003860
# 18        POWERCHART.EXE 2018-08-03  0.047602
# 19        SNSURGINET.EXE 2018-10-19  0.040400
# 20        POWERCHART.EXE 2018-09-19  0.045444
# 21        SNSURGINET.EXE 2018-08-06  0.005424
# 22            POWERCHART 2018-08-10  0.449859
# 23        SNSURGINET.EXE 2018-09-26  0.007521
# 24            SNSURGINET 2018-08-01  0.083387
# 25        SNSURGINET.EXE 2018-10-17  0.006407
# 26            POWERCHART 2018-10-11  0.126692
# 27        POWERCHART.EXE 2018-10-24  0.336944
# 28            SNSURGINET 2018-09-15  0.118178
# 29            POWERCHART 2018-09-11       NaN
# ...                  ...        ...       ...
# 676369        SI_MANAGER 2018-09-10  0.084182
# 676370    POWERCHART.EXE 2018-09-24  0.038240
# 676371        POWERCHART 2018-09-27       NaN
# 676372        POWERCHART 2018-10-19  0.127423
# 676373        SNSURGINET 2018-09-13       NaN
# 676374        POWERCHART 2018-09-04  0.206514
# 676375        POWERCHART 2018-10-06  0.343476
# 676376        POWERCHART 2018-09-29  0.965307
# 676377        POWERCHART 2018-10-15  0.047125
# 676378          PMRESEND 2018-10-12  0.029772
# 676379    SNSURGINET.EXE 2018-08-15  0.002084
# 676380        POWERCHART 2018-09-17  0.255326
# 676381    SNSURGINET.EXE 2018-08-08  0.052041
# 676382        POWERCHART 2018-08-22  0.124790
# 676383        POWERCHART 2018-09-08       NaN
# 676384        POWERCHART 2018-08-20  0.030851
# 676385        POWERCHART 2018-09-05  0.048392
# 676386        POWERCHART 2018-10-23  0.084238
# 676387        POWERCHART 2018-10-19  0.043694
# 676388        POWERCHART 2018-10-15  0.379139
# 676389        SNSURGINET 2018-09-27  0.653921
# 676390    POWERCHART.EXE 2018-09-21  0.073795
# 676391  SAANESTHESIA.EXE 2018-08-02  0.076711
# 676392    SNSURGINET.EXE 2018-08-27       NaN
# 676393        POWERCHART 2018-10-22  0.668820
# 676394        POWERCHART 2018-10-08  0.858187
# 676395        SNSURGINET 2018-08-27  0.380431
# 676396          FIRSTNET 2018-08-27  0.483677
# 676397        SNSURGINET 2018-07-31  0.082514
# 676398    SNSURGINET.EXE 2018-08-29  0.469817
#
#                                              subtimername  \
# 0                                 BMH PACU PHASE 1 DELAYS
# 1                                           NICU FINNEGAN
# 2                                     PCA ADLS AND SAFETY
# 3                                    PICU RISK ASSESSMENT
# 4                            VB_WORKFLOWAMBPEDSCARDIOLOGY
# 5                                     VB_WORKFLOWIPCHARIS
# 6                                        VB_EDQUICKORDERS
# 7                                UH RAD GENERAL CASE DATA
# 8                               NH ENDO DEPARTURE FROM OR
# 9                                                     NaN
# 10                                UH ENDO TRANSPORT TO OR
# 11                              EHSC SPECIMENS & CULTURES
# 12                                BLH SURGICAL PROCEDURES
# 13                                                    NaN
# 14      PM:PMQUICKVIEW:ACTION:LOADINFORMATION - ENCOUNTER
# 15                                                    NaN
# 16                    SM ENDO PACU PHASE 1 CASE ATTENDEES
# 17                           VB_WORKFLOWAMBOBPRENATALPPUN
# 18                                            UN DRESSING
# 19                                        MH RAD SEDATION
# 20                                            CL DRESSING
# 21                                BMH PACU PHASE 2 DELAYS
# 22                               VB_WORKFLOWIPPEDSSURGERY
# 23                                     MH ENDO HEMOSTASIS
# 24                         REFRESHING PERIOP TRACKING TAB
# 25                           MH RAD OXYGEN ADMINISTRATION
# 26                                VB_QUICKORDERSPULMONARY
# 27                                UN OB DEPARTURE FROM OR
# 28                         VB_INTRAOPERATIVECOMMUNICATION
# 29                                          VB_HCCASELIST
# ...                                                   ...
# 676369                                                NaN
# 676370                                                NaN
# 676371                               VB_WORKFLOWIPINSIDER
# 676372                      VB_PREOPERATIVECOMMUNICATIONS
# 676373                                      VB_AMBSUMMARY
# 676374                                   VB_OPQUICKORDERS
# 676375                                  VB_AMBGYNWORKFLOW
# 676376                                          PICU ECMO
# 676377                       VB_WORKFLOWIPCHILDPROTECTION
# 676378                                                NaN
# 676379                               SH MEDICATION INTAKE
# 676380                       VB_WORKFLOWIPPREGNANCYVIEWUN
# 676381                              BSC PACU PHASE 2 INFO
# 676382                 PROCEDURAL PRE PROCEDURE CHECKLIST
# 676383                          VB_WORKFLOWAMBCLIPBOARDCS
# 676384                          VB_WORKFLOWAMBPEDSSURGERY
# 676385                                       VB_AMBCUSTOM
# 676386                     VB_WORKFLOWAMBOBCLINICSUPPORTU
# 676387                       ADULT SS PHYSICAL ASSESSMENT
# 676388                     VB_WORKFLOWAMBOBCLINICSUPPORTU
# 676389                             VB_WORKFLOWSUPPORTVIEW
# 676390                                    BLH WS DRESSING
# 676391                                       SAANESTHESIA
# 676392                                      UN TOURNIQUET
# 676393                           SINCE LAST TIME.CLIN_DOC
# 676394                                 VB_AMBRHEUMATOLOGY
# 676395                                                NaN
# 676396                                                NaN
# 676397                                                NaN
# 676398                              RI GENERAL  CASE DATA
#
#                                                 timername  total_elapsed  \
# 0                 USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.800640
# 1                          USR: PDOC NAVIGATOR BAND CLICK      13.028515
# 2                                   USR: ICU-OPENING-BAND       4.530593
# 3                       USR: PDOC NAVIGATOR DOC SET CLICK      11.668000
# 4           USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      36.360582
# 5                       USR:MPG.MICRO.O2 - LOAD COMPONENT       0.615875
# 6             USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT     255.817332
# 7                        USR:SRG SNDOCDISP SAVING SEGMENT      16.084465
# 8                        USR:SRG SNDOCDISP SAVING SEGMENT       7.933674
# 9                                  USR:FAMHX.LOAD PROFILE      15.467000
# 10                      USR:SRG SNDOCDISP LOADING SEGMENT       4.153517
# 11                       USR:SRG SNDOCDISP SAVING SEGMENT       8.943821
# 12                      USR:SRG SNDOCDISP LOADING SEGMENT      71.974724
# 13                             USR: DOCV: ADD NEW PN NOTE   22526.261366
# 14             USR: ERM PMSEARCH SEARCH ENCOUNTER PREVIEW       0.044000
# 15                               USR:ORM.SIGNORDERS-BEGIN      11.420316
# 16                      USR:SRG SNDOCDISP LOADING SEGMENT       7.060011
# 17        USR:MPG.SECONDARYASSESSMENT.O2 - LOAD COMPONENT       0.163154
# 18                      USR:SRG SNDOCDISP LOADING SEGMENT       2.542146
# 19                      USR:SRG SNDOCDISP LOADING SEGMENT       1.651044
# 20                      USR:SRG SNDOCDISP LOADING SEGMENT       0.548160
# 21                USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.191651
# 22                  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT      17.040464
# 23                USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.447954
# 24                                   USR:PWR-REFRESH VIEW    1092.494105
# 25                USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.288891
# 26             USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT     185.579233
# 27                       USR:SRG SNDOCDISP SAVING SEGMENT       2.318622
# 28                         USR:MPG.IO.O1 - LOAD COMPONENT       1.859212
# 29      USR:MPG.COMMUNICATION_EVENTS.O1.SUM - LOAD COM...       0.138463
# ...                                                   ...            ...
# 676369  USR:ERM PMSEARCH PERSON SEARCH RESULTS DISPLAY...       2.325398
# 676370                       USR:SRG SNCASE CHECK-IN CASE       3.927258
# 676371                  USR:MPG.MICRO.O2 - LOAD COMPONENT       0.314373
# 676372             USR:MPG.ACTIVITIES.O1 - LOAD COMPONENT      50.727908
# 676373                   USR:MPG.LABS.O1 - LOAD COMPONENT       0.521796
# 676374        USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT    3699.251052
# 676375              USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT      44.081457
# 676376                              USR: ICU-OPENING-BAND      53.891509
# 676377      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT       0.693061
# 676378            USR:ERM PMSEARCH PERSON RESULTS DISPLAY      23.919501
# 676379            USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.145617
# 676380             USR:MPG.RISKFACTOR.O1 - LOAD COMPONENT      25.041156
# 676381                  USR:SRG SNDOCDISP LOADING SEGMENT       0.131249
# 676382                              USR: ICU-OPENING-BAND      39.976808
# 676383           USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT       0.797867
# 676384      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT       1.051922
# 676385                USR:MPG.ALLERGY.O1 - LOAD COMPONENT      10.174538
# 676386              USR:MPG.REMINDERS.O2 - LOAD COMPONENT       2.699657
# 676387                  USR: PDOC NAVIGATOR DOC SET CLICK       3.904000
# 676388              USR:MPG.REMINDERS.O2 - LOAD COMPONENT       3.031094
# 676389             USR:MPG.LABORATORY.WF - LOAD COMPONENT       2.814991
# 676390                  USR:SRG SNDOCDISP LOADING SEGMENT       0.298837
# 676391           USR:SRA SAANESTHESIA DOCUMENT MEDICATION    1354.965795
# 676392                  USR:SRG SNDOCDISP LOADING SEGMENT       0.146074
# 676393                         USR:PWR-PVCHART.DETAILPANE     614.279000
# 676394           USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT     136.005033
# 676395  USR: PN OPEN NEW POWERNOTE USING PRECOMPLETED ...      26.962205
# 676396                 USR:ORM.CONVERTTOINPATIENTMR-BEGIN      21.501689
# 676397                             USR:FAMHX.LOAD PROFILE      22.820000
# 676398                   USR:SRG SNDOCDISP SAVING SEGMENT      95.937695
#
#         transAbove5  transUnder2  transaction_cnt     isBDay
# 0                 0           21               21 2018-10-01
# 1                 0           32               32 2018-10-29
# 2                 0            7                7 2018-08-15
# 3                 0           79               79 2018-08-28
# 4                 0           95               95 2018-09-11
# 5                 0            3                3 2018-10-19
# 6                 0          484              484 2018-08-20
# 7                 0           14               14 2018-10-17
# 8                 0           13               13 2018-09-13
# 9                 0           53               53 2018-08-08
# 10                0           55               55 2018-09-27
# 11                0           13               13 2018-10-04
# 12                0          232              232 2018-09-17
# 13               66         3551             9928 2018-10-11
# 14                0            1                1 2018-10-24
# 15                0          139              139        NaT
# 16                0           70               70 2018-09-20
# 17                0            2                2 2018-10-25
# 18                0           49               49 2018-08-03
# 19                0           27               27 2018-10-19
# 20                0           13               13 2018-09-19
# 21                0            5                5 2018-08-06
# 22                0           26               27 2018-08-10
# 23                0           12               12 2018-09-26
# 24                0         4772             4772 2018-08-01
# 25                0            7                7 2018-10-17
# 26                0          783              784 2018-10-11
# 27                0            5                5 2018-10-24
# 28                0           12               12        NaT
# 29                0            1                1 2018-09-11
# ...             ...          ...              ...        ...
# 676369            0            8                8 2018-09-10
# 676370            0          104              104 2018-09-24
# 676371            0            1                1 2018-09-27
# 676372            0          408              408 2018-10-19
# 676373            0            1                1 2018-09-13
# 676374            2         6019             6032 2018-09-04
# 676375            0           65               65        NaT
# 676376            0           33               43        NaT
# 676377            0            6                6 2018-10-15
# 676378            0           81               81 2018-10-12
# 676379            0            4                4 2018-08-15
# 676380            0          123              123 2018-09-17
# 676381            0            2                2 2018-08-08
# 676382            0           71               71 2018-08-22
# 676383            0            1                1        NaT
# 676384            0           19               19 2018-08-20
# 676385            0           73               73 2018-09-05
# 676386            0            6                6 2018-10-23
# 676387            0           52               52 2018-10-19
# 676388            0            5                5 2018-10-15
# 676389            0            2                2 2018-09-27
# 676390            0            4                4 2018-09-21
# 676391            0         4185             4185 2018-08-02
# 676392            0            1                1 2018-08-27
# 676393            0          682              721 2018-10-22
# 676394            2          130              138 2018-10-08
# 676395            0           71               71 2018-08-27
# 676396            0           73               75 2018-08-27
# 676397            0           82               82 2018-07-31
# 676398            0          162              162 2018-08-29
#
# [676399 rows x 15 columns]

# %% [markdown]
# ### Filter dataset by application - e.g. Powerchart, firstnet, surginet.
# (Actually apply the weekend/weekday filter here as well).
#
# **to-do**
# - [ ] are there differences between timers in the different applications?
# - [X]clean up the workflow to do one step at a time

# %%
atrt_df_PC = atrt_df[atrt_df['application_name']== 'POWERCHART']
atrt_df_PC = atrt_df_PC[atrt_df_PC.isBDay.notnull()]
atrt_df_PC
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 1       0.41                         0.00%                       100.00%
# 3       0.15                         0.00%                       100.00%
# 4       0.38                         0.00%                       100.00%
# 5       0.21                         0.00%                       100.00%
# 13      2.27                         0.66%                        35.77%
# 17      0.08                         0.00%                       100.00%
# 22      0.63                         0.00%                        96.30%
# 26      0.24                         0.00%                        99.87%
# 29      0.14                         0.00%                       100.00%
# 30      0.25                         0.00%                       100.00%
# 31      0.21                         0.00%                       100.00%
# 35      0.81                         0.02%                        99.87%
# 36      0.29                         0.00%                       100.00%
# 43      0.32                         0.00%                       100.00%
# 48      0.25                         0.00%                       100.00%
# 50      0.30                         0.00%                       100.00%
# 52      2.52                         0.00%                         0.00%
# 54      1.20                         1.19%                        88.76%
# 58      1.90                         5.10%                        64.48%
# 61      0.39                         0.00%                       100.00%
# 65      0.42                         0.00%                       100.00%
# 66      0.50                         0.00%                        97.30%
# 68      0.29                         0.15%                        98.67%
# 69      1.50                         7.14%                        85.71%
# 72      0.37                         0.00%                        99.63%
# 73      0.00                         0.00%                       100.00%
# 76      0.91                         0.00%                        96.67%
# 77      0.85                         0.80%                        87.20%
# 79      1.30                         1.20%                        90.36%
# 84      0.03                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 676280  0.22                         0.00%                        99.96%
# 676283  0.23                         0.00%                       100.00%
# 676285  2.94                         0.00%                         0.00%
# 676293  0.91                         0.00%                       100.00%
# 676297  0.77                         0.00%                       100.00%
# 676310  0.93                         1.85%                        92.59%
# 676318  0.26                         0.00%                        99.87%
# 676320  0.83                         2.28%                        95.19%
# 676321  0.95                         1.95%                        91.56%
# 676322  0.48                         0.47%                        97.32%
# 676331  0.59                         0.00%                       100.00%
# 676336  1.38                         0.00%                        86.73%
# 676340  0.21                         0.02%                        99.90%
# 676349  0.36                         0.12%                        98.13%
# 676351  1.21                         3.09%                        92.78%
# 676353  0.12                         0.00%                        99.85%
# 676367  1.13                         0.00%                        86.67%
# 676371  0.31                         0.00%                       100.00%
# 676372  0.12                         0.00%                       100.00%
# 676374  0.61                         0.03%                        99.78%
# 676377  0.12                         0.00%                       100.00%
# 676380  0.20                         0.00%                       100.00%
# 676382  0.56                         0.00%                       100.00%
# 676384  0.06                         0.00%                       100.00%
# 676385  0.14                         0.00%                       100.00%
# 676386  0.45                         0.00%                       100.00%
# 676387  0.08                         0.00%                       100.00%
# 676388  0.61                         0.00%                       100.00%
# 676393  0.85                         0.00%                        94.59%
# 676394  0.99                         1.45%                        94.20%
#
#                                       Timer Subtimer Name  Number of Records  \
# 1          USR: PDOC NAVIGATOR BAND CLICK (NICU FINNEGAN)                  1
# 3       USR: PDOC NAVIGATOR DOC SET CLICK (PICU RISK A...                  1
# 4       USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 5       USR:MPG.MICRO.O2 - LOAD COMPONENT (VB_WORKFLOW...                  1
# 13                       USR: DOCV: ADD NEW PN NOTE (N/A)                  1
# 17      USR:MPG.SECONDARYASSESSMENT.O2 - LOAD COMPONEN...                  1
# 22      USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 26      USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT (VB...                  1
# 29      USR:MPG.COMMUNICATION_EVENTS.O1.SUM - LOAD COM...                  1
# 30      USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT (VB...                  1
# 31                                USR:FN.SAVE.PATED (N/A)                  1
# 35               USR: ICU-OPENING-BAND (DRAINS AND TUBES)                  1
# 36      USR:MPG.VISITS.O2 - LOAD COMPONENT (VB_WORKFLO...                  1
# 43      USR:MPG.ORDERS.O2 - LOAD COMPONENT (VB_WORKFLO...                  1
# 48      USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT (VB...                  1
# 50                 USR:POWERPLANS.ADD ADHOC OUTCOME (N/A)                  1
# 52      USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT (...                  1
# 54      USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 58                    USR:POWERPLANS.INITIATE PHASE (N/A)                  1
# 61      USR:MPG.PATINFO.O1 - LOAD COMPONENT (VB_CMREAD...                  1
# 65      USR: PDOC NAVIGATOR BAND CLICK (ED PSYCH DETAI...                  1
# 66      USR:MPG.DIAGNOSTICS.O2 - LOAD COMPONENT (VB_WO...                  1
# 68      USR:MPG.ORDERS.O2 - LOAD COMPONENT (VB_WORKFLO...                  1
# 69      USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 72      USR:MPG.WORKLIST.FRAMEWORK.CUSTOM_COLUMN - LOA...                  1
# 73      USR:PWR-REFRESH VIEW (REFRESHING MEDICATION LI...                  1
# 76      USR:MPG.ALLERGY.O2 - LOAD COMPONENT (VB_WORKFL...                  1
# 77      USR:MPG.TRIAGE_DOC.O2 - LOAD COMPONENT (VB_EDP...                  1
# 79      USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 84      USR: PDOC NAVIGATOR DOC SET CLICK (PEDS SS MEA...                  1
# ...                                                   ...                ...
# 676280  USR:MPG.MICRO.O1 - LOAD COMPONENT (VB_CMUTILIZ...                  1
# 676283  USR: PDOC NAVIGATOR DOC SET CLICK (INCISION AN...                  1
# 676285  USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT (...                  1
# 676293  USR:MPG.PARTOGRAMOVERVIEW.O2 - LOAD COMPONENT ...                  1
# 676297  USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 676310  USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 676318  USR:MPG.RCM.CLINICAL_REVIEW - MODIFY MANUAL CL...                  1
# 676320  USR:MPG.RCM.UTILIZATION_MANAGEMENT - LOAD COMP...                  1
# 676321  USR:MPG.ALLERGY.O2 - LOAD COMPONENT (VB_WORKFL...                  1
# 676322  USR:MPG.MICRO.O2 - LOAD COMPONENT (VB_WORKFLOW...                  1
# 676331  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 676336  USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT (VB_W...                  1
# 676340  USR:MPG.MICRO.O1 - LOAD COMPONENT (VB_CMUTILIZ...                  1
# 676349  USR:MPG.MICRO.O2 - LOAD COMPONENT (VB_WORKFLOW...                  1
# 676351  USR:MPG.PATHOLOGY.O2 - LOAD COMPONENT (VB_WORK...                  1
# 676353  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 676367                  USR: ICU-OPENING-BAND (PICU ECMO)                  1
# 676371  USR:MPG.MICRO.O2 - LOAD COMPONENT (VB_WORKFLOW...                  1
# 676372  USR:MPG.ACTIVITIES.O1 - LOAD COMPONENT (VB_PRE...                  1
# 676374  USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT (V...                  1
# 676377  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 676380  USR:MPG.RISKFACTOR.O1 - LOAD COMPONENT (VB_WOR...                  1
# 676382  USR: ICU-OPENING-BAND (PROCEDURAL PRE PROCEDUR...                  1
# 676384  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 676385  USR:MPG.ALLERGY.O1 - LOAD COMPONENT (VB_AMBCUS...                  1
# 676386  USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 676387  USR: PDOC NAVIGATOR DOC SET CLICK (ADULT SS PH...                  1
# 676388  USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 676393  USR:PWR-PVCHART.DETAILPANE (SINCE LAST TIME.CL...                  1
# 676394  USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT (VB_A...                  1
#
#        application_name         dt      strt  \
# 1            POWERCHART 2018-10-29  0.087445
# 3            POWERCHART 2018-08-28  0.096875
# 4            POWERCHART 2018-09-11  0.311815
# 5            POWERCHART 2018-10-19  0.108207
# 13           POWERCHART 2018-10-11  1.044684
# 17           POWERCHART 2018-10-25  0.003860
# 22           POWERCHART 2018-08-10  0.449859
# 26           POWERCHART 2018-10-11  0.126692
# 29           POWERCHART 2018-09-11       NaN
# 30           POWERCHART 2018-09-25  0.129549
# 31           POWERCHART 2018-10-10  0.111927
# 35           POWERCHART 2018-08-10  0.222734
# 36           POWERCHART 2018-08-17  0.203928
# 43           POWERCHART 2018-10-10  0.166093
# 48           POWERCHART 2018-09-26  0.098826
# 50           POWERCHART 2018-08-10  0.057933
# 52           POWERCHART 2018-08-16  0.318485
# 54           POWERCHART 2018-08-21  0.988152
# 58           POWERCHART 2018-08-10  1.868712
# 61           POWERCHART 2018-09-18  0.242468
# 65           POWERCHART 2018-08-17  0.134137
# 66           POWERCHART 2018-10-15  0.421251
# 68           POWERCHART 2018-08-07  0.378056
# 69           POWERCHART 2018-10-22  1.481894
# 72           POWERCHART 2018-09-27  0.338485
# 73           POWERCHART 2018-10-18  0.001099
# 76           POWERCHART 2018-09-26  0.649559
# 77           POWERCHART 2018-09-19  1.124786
# 79           POWERCHART 2018-10-02  1.078904
# 84           POWERCHART 2018-10-15  0.000707
# ...                 ...        ...       ...
# 676280       POWERCHART 2018-08-15  0.156542
# 676283       POWERCHART 2018-10-19  0.206921
# 676285       POWERCHART 2018-10-04  0.472312
# 676293       POWERCHART 2018-08-22  0.314417
# 676297       POWERCHART 2018-09-18  0.476392
# 676310       POWERCHART 2018-10-12  1.052390
# 676318       POWERCHART 2018-08-10  0.098855
# 676320       POWERCHART 2018-08-13  7.779953
# 676321       POWERCHART 2018-10-19  1.157129
# 676322       POWERCHART 2018-10-15  0.696451
# 676331       POWERCHART 2018-09-17  0.196301
# 676336       POWERCHART 2018-08-21  0.685509
# 676340       POWERCHART 2018-10-26  0.185748
# 676349       POWERCHART 2018-08-20  0.464081
# 676351       POWERCHART 2018-08-13  5.654766
# 676353       POWERCHART 2018-09-24  0.161954
# 676367       POWERCHART 2018-09-05  0.996346
# 676371       POWERCHART 2018-09-27       NaN
# 676372       POWERCHART 2018-10-19  0.127423
# 676374       POWERCHART 2018-09-04  0.206514
# 676377       POWERCHART 2018-10-15  0.047125
# 676380       POWERCHART 2018-09-17  0.255326
# 676382       POWERCHART 2018-08-22  0.124790
# 676384       POWERCHART 2018-08-20  0.030851
# 676385       POWERCHART 2018-09-05  0.048392
# 676386       POWERCHART 2018-10-23  0.084238
# 676387       POWERCHART 2018-10-19  0.043694
# 676388       POWERCHART 2018-10-15  0.379139
# 676393       POWERCHART 2018-10-22  0.668820
# 676394       POWERCHART 2018-10-08  0.858187
#
#                               subtimername  \
# 1                            NICU FINNEGAN
# 3                     PICU RISK ASSESSMENT
# 4             VB_WORKFLOWAMBPEDSCARDIOLOGY
# 5                      VB_WORKFLOWIPCHARIS
# 13                                     NaN
# 17            VB_WORKFLOWAMBOBPRENATALPPUN
# 22                VB_WORKFLOWIPPEDSSURGERY
# 26                 VB_QUICKORDERSPULMONARY
# 29                           VB_HCCASELIST
# 30                 VB_QUICKORDERSPULMONARY
# 31                                     NaN
# 35                        DRAINS AND TUBES
# 36                VB_WORKFLOWIPHOSPITALIST
# 43          VB_WORKFLOWAMBGASTROENTEROLOGY
# 48                     VB_QUICKORDERSBLANK
# 50                                     NaN
# 52             VB_WORKFLOWAMBPEDSNEUROLOGY
# 54                  VB_WORKFLOWSUPPORTVIEW
# 58                                     NaN
# 61                       VB_CMREADMISSIONS
# 65                       ED PSYCH DETAILED
# 66              VB_WORKFLOWIPPEDSNEUROLOGY
# 68          VB_WORKFLOWAMBPCPROVIDERFAMILY
# 69          VB_WORKFLOWIPMANAGEPEDSPULMONA
# 72              VB_CLINICALLEADERORGANIZER
# 73          REFRESHING MEDICATION LIST TAB
# 76             VB_WORKFLOWAMBPEDSNEUROLOGY
# 77                  VB_EDPHYSICIANWORKFLOW
# 79            VB_WORKFLOWAMBPEDSCARDIOLOGY
# 84              PEDS SS MEAL DOCUMENTATION
# ...                                    ...
# 676280          VB_CMUTILIZATIONMANAGEMENT
# 676283       INCISION AND WOUND MANAGEMENT
# 676285      VB_WORKFLOWAMBOBPRENATALPPDIPU
# 676293                                 NaN
# 676297           VB_WORKFLOWAMBPEDSSURGERY
# 676310         VB_WORKFLOWIPOTOLARYNGOLOGY
# 676318                                 NaN
# 676320                                 NaN
# 676321      VB_WORKFLOWAMBCLINICALPHARMACI
# 676322               VB_WORKFLOWOPSTANDARD
# 676331               VB_WORKFLOWAMBPEDSPMR
# 676336      VB_WORKFLOWAMBGYNCLINICALSUPPO
# 676340          VB_CMUTILIZATIONMANAGEMENT
# 676349               VB_WORKFLOWOPSTANDARD
# 676351      VB_WORKFLOWAMBGASTROENTEROLOGY
# 676353            VB_WORKFLOWIPHOSPITALIST
# 676367                           PICU ECMO
# 676371                VB_WORKFLOWIPINSIDER
# 676372       VB_PREOPERATIVECOMMUNICATIONS
# 676374                    VB_OPQUICKORDERS
# 676377        VB_WORKFLOWIPCHILDPROTECTION
# 676380        VB_WORKFLOWIPPREGNANCYVIEWUN
# 676382  PROCEDURAL PRE PROCEDURE CHECKLIST
# 676384           VB_WORKFLOWAMBPEDSSURGERY
# 676385                        VB_AMBCUSTOM
# 676386      VB_WORKFLOWAMBOBCLINICSUPPORTU
# 676387        ADULT SS PHYSICAL ASSESSMENT
# 676388      VB_WORKFLOWAMBOBCLINICSUPPORTU
# 676393            SINCE LAST TIME.CLIN_DOC
# 676394                  VB_AMBRHEUMATOLOGY
#
#                                                 timername  total_elapsed  \
# 1                          USR: PDOC NAVIGATOR BAND CLICK      13.028515
# 3                       USR: PDOC NAVIGATOR DOC SET CLICK      11.668000
# 4           USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      36.360582
# 5                       USR:MPG.MICRO.O2 - LOAD COMPONENT       0.615875
# 13                             USR: DOCV: ADD NEW PN NOTE   22526.261366
# 17        USR:MPG.SECONDARYASSESSMENT.O2 - LOAD COMPONENT       0.163154
# 22                  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT      17.040464
# 26             USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT     185.579233
# 29      USR:MPG.COMMUNICATION_EVENTS.O1.SUM - LOAD COM...       0.138463
# 30             USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT      67.500276
# 31                                      USR:FN.SAVE.PATED       2.773000
# 35                                  USR: ICU-OPENING-BAND    9424.614020
# 36                     USR:MPG.VISITS.O2 - LOAD COMPONENT      50.041575
# 43                     USR:MPG.ORDERS.O2 - LOAD COMPONENT       6.410799
# 48             USR:MPG.ORDERSELECTION.O2 - LOAD COMPONENT     218.521560
# 50                       USR:POWERPLANS.ADD ADHOC OUTCOME       1.480535
# 52           USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT      55.502847
# 54                 USR:MPG.VITALSIGNS.WF - LOAD COMPONENT   42974.508222
# 58                          USR:POWERPLANS.INITIATE PHASE    6502.213402
# 61                    USR:MPG.PATINFO.O1 - LOAD COMPONENT      19.321350
# 65                         USR: PDOC NAVIGATOR BAND CLICK       9.629000
# 66                USR:MPG.DIAGNOSTICS.O2 - LOAD COMPONENT      18.421939
# 68                     USR:MPG.ORDERS.O2 - LOAD COMPONENT     199.809944
# 69                 USR:MPG.VITALSIGNS.WF - LOAD COMPONENT      83.983341
# 72      USR:MPG.WORKLIST.FRAMEWORK.CUSTOM_COLUMN - LOA...     100.881667
# 73                                   USR:PWR-REFRESH VIEW       7.849217
# 76                    USR:MPG.ALLERGY.O2 - LOAD COMPONENT      54.625710
# 77                 USR:MPG.TRIAGE_DOC.O2 - LOAD COMPONENT     106.716796
# 79                  USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT     107.903933
# 84                      USR: PDOC NAVIGATOR DOC SET CLICK       0.065000
# ...                                                   ...            ...
# 676280                  USR:MPG.MICRO.O1 - LOAD COMPONENT    1014.619854
# 676283                  USR: PDOC NAVIGATOR DOC SET CLICK      16.083000
# 676285       USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT     158.743509
# 676293      USR:MPG.PARTOGRAMOVERVIEW.O2 - LOAD COMPONENT      31.914836
# 676297             USR:MPG.VITALSIGNS.WF - LOAD COMPONENT      11.565635
# 676310             USR:MPG.VITALSIGNS.WF - LOAD COMPONENT     100.299727
# 676318  USR:MPG.RCM.CLINICAL_REVIEW - MODIFY MANUAL CL...     199.814114
# 676320  USR:MPG.RCM.UTILIZATION_MANAGEMENT - LOAD COMP...   14095.024086
# 676321                USR:MPG.ALLERGY.O2 - LOAD COMPONENT     146.751194
# 676322                  USR:MPG.MICRO.O2 - LOAD COMPONENT     407.769801
# 676331              USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT      27.059243
# 676336           USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT     134.899609
# 676340                  USR:MPG.MICRO.O1 - LOAD COMPONENT     856.067495
# 676349                  USR:MPG.MICRO.O2 - LOAD COMPONENT     307.317918
# 676351              USR:MPG.PATHOLOGY.O2 - LOAD COMPONENT     117.707944
# 676353      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT      77.152220
# 676367                              USR: ICU-OPENING-BAND      51.000009
# 676371                  USR:MPG.MICRO.O2 - LOAD COMPONENT       0.314373
# 676372             USR:MPG.ACTIVITIES.O1 - LOAD COMPONENT      50.727908
# 676374        USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT    3699.251052
# 676377      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT       0.693061
# 676380             USR:MPG.RISKFACTOR.O1 - LOAD COMPONENT      25.041156
# 676382                              USR: ICU-OPENING-BAND      39.976808
# 676384      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT       1.051922
# 676385                USR:MPG.ALLERGY.O1 - LOAD COMPONENT      10.174538
# 676386              USR:MPG.REMINDERS.O2 - LOAD COMPONENT       2.699657
# 676387                  USR: PDOC NAVIGATOR DOC SET CLICK       3.904000
# 676388              USR:MPG.REMINDERS.O2 - LOAD COMPONENT       3.031094
# 676393                         USR:PWR-PVCHART.DETAILPANE     614.279000
# 676394           USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT     136.005033
#
#         transAbove5  transUnder2  transaction_cnt     isBDay
# 1                 0           32               32 2018-10-29
# 3                 0           79               79 2018-08-28
# 4                 0           95               95 2018-09-11
# 5                 0            3                3 2018-10-19
# 13               66         3551             9928 2018-10-11
# 17                0            2                2 2018-10-25
# 22                0           26               27 2018-08-10
# 26                0          783              784 2018-10-11
# 29                0            1                1 2018-09-11
# 30                0          273              273 2018-09-25
# 31                0           13               13 2018-10-10
# 35                2        11684            11699 2018-08-10
# 36                0          174              174 2018-08-17
# 43                0           20               20 2018-10-10
# 48                0          874              874 2018-09-26
# 50                0            5                5 2018-08-10
# 52                0            0               22 2018-08-16
# 54              427        31853            35885 2018-08-21
# 58              174         2202             3415 2018-08-10
# 61                0           49               49 2018-09-18
# 65                0           23               23 2018-08-17
# 66                0           36               37 2018-10-15
# 68                1          669              678 2018-08-07
# 69                4           48               56 2018-10-22
# 72                0          269              270 2018-09-27
# 73                0         3838             3838 2018-10-18
# 76                0           58               60 2018-09-26
# 77                1          109              125 2018-09-19
# 79                1           75               83 2018-10-02
# 84                0            2                2 2018-10-15
# ...             ...          ...              ...        ...
# 676280            0         4705             4707 2018-08-15
# 676283            0           69               69 2018-10-19
# 676285            0            0               54 2018-10-04
# 676293            0           35               35 2018-08-22
# 676297            0           15               15 2018-09-18
# 676310            2          100              108 2018-10-12
# 676318            0          767              768 2018-08-10
# 676320          386        16137            16952 2018-08-13
# 676321            3          141              154 2018-10-19
# 676322            4          835              858 2018-10-15
# 676331            0           46               46 2018-09-17
# 676336            0           85               98 2018-08-21
# 676340            1         4089             4093 2018-10-26
# 676349            1          840              856 2018-08-20
# 676351            3           90               97 2018-08-13
# 676353            0          661              662 2018-09-24
# 676367            0           39               45 2018-09-05
# 676371            0            1                1 2018-09-27
# 676372            0          408              408 2018-10-19
# 676374            2         6019             6032 2018-09-04
# 676377            0            6                6 2018-10-15
# 676380            0          123              123 2018-09-17
# 676382            0           71               71 2018-08-22
# 676384            0           19               19 2018-08-20
# 676385            0           73               73 2018-09-05
# 676386            0            6                6 2018-10-23
# 676387            0           52               52 2018-10-19
# 676388            0            5                5 2018-10-15
# 676393            0          682              721 2018-10-22
# 676394            2          130              138 2018-10-08
#
# [203605 rows x 15 columns]

# %% [markdown]
# ## Anomaly detection/Handling

# %% [markdown]
# #### Applying quantiles:
#
# Apply 5th and 95th quantiles to each timer for the entire 90 day period.
# Then we can lookup the values using ```loc``` and ```filter```
#
#
# **To-do**
# - Investigate outliers/anomalies by timer. Replace with mean/remove altogether.
# - Use KNN?
# - Complete - remove outliers by timer.
#
# Sample outlier removal calculation by group.
# ```atrt_df_PC[np.abs(atrt_df_PC.ATRT-atrt_df_PC.ATRT.mean()) <= (3*atrt_df_PC.ATRT.std())]```
#
# Takes the absolute value of standardized value for each datapoint, then removes it if it's less than 3 standard deviations from the mean.
# - I need to do this by group!
# - Group first, then pass in group calculation.

# %%
#find outliers
outliers = atrt_df_PC.groupby(["Timer Subtimer Name"])['ATRT'].quantile([0.05, 0.95]).unstack(level=1)
#filter outliers
atrt_df_PC = atrt_df_PC.loc[((outliers.loc[atrt_df_PC['Timer Subtimer Name'], .05] < atrt_df_PC.ATRT.values) & (atrt_df_PC.ATRT.values < outliers.loc[atrt_df_PC['Timer Subtimer Name'], .95])).values]

# %% [markdown]
# ### Rolling average notes
# Lambda function for applying rolling average to a group:
# The groupby statement can be in an earlier variable, but I've chosen to include it here.
#
# **To-do**
# - [ ] Find out exactly what reset_index does - reset the average calculation to the beginning of each group?
# - [ ] Remove outliers/anomalies by timer. Replace with mean/remove altogether.
# - [ ] Use KNN for clustering timers...analyze what timers that have shifted up have in common.
# - [ ] Establish control chart
#     - UCL = .75 quartile + 1.5x IQR
#     - LCL = .25 quartile - 1.5x IQR
#     - mean = 60-day mean
#     - median = 60-day median (use with outliers included)
# ```
# atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])['ATRT'].rolling(30).mean().reset_index(0,drop=True)
# ```
# Pass into dataset feature with ```atrt_df_PC['mavg30'] = (above statement)```
#
# ```atrt_df_PC['mavg30'] = atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])['ATRT'].rolling(30).mean().reset_index(0,drop=True)```

# %%
#Setting index appears to cause issues when outputting to csv: 
#atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name', 'dt'])

atrt_df_PC = atrt_df_PC.sort_values(['Timer Subtimer Name', 'dt'])
atrt_df_PC['mavg30'] = atrt_df_PC.groupby('Timer Subtimer Name')['ATRT'].apply(lambda x:x.rolling(center=False,window=30).mean())

#check to make sure that everything looks correct: 
atrt_df_PC
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 642711  0.14                         0.02%                        99.98%
# 280854  0.14                         0.02%                        99.98%
# 447545  0.15                         0.00%                       100.00%
# 376550  0.16                         0.00%                        99.98%
# 305295  0.15                         0.00%                       100.00%
# 98917   0.15                         0.00%                        99.98%
# 426129  0.16                         0.00%                        99.98%
# 347498  0.16                         0.00%                        99.98%
# 8354    0.16                         0.00%                        99.96%
# 661101  0.15                         0.00%                       100.00%
# 591884  0.15                         0.00%                       100.00%
# 424275  0.15                         0.02%                        99.98%
# 389254  0.15                         0.00%                       100.00%
# 137556  0.16                         0.00%                        99.97%
# 438317  0.16                         0.00%                        99.97%
# 290374  0.15                         0.00%                       100.00%
# 68971   0.16                         0.00%                        99.95%
# 163210  0.15                         0.00%                        99.98%
# 201982  0.15                         0.00%                       100.00%
# 141399  0.15                         0.00%                        99.98%
# 629705  0.15                         0.00%                       100.00%
# 292636  0.15                         0.00%                        99.98%
# 577847  0.15                         0.00%                        99.98%
# 33072   0.14                         0.00%                       100.00%
# 479463  0.15                         0.00%                       100.00%
# 245482  0.14                         0.00%                       100.00%
# 106866  0.15                         0.00%                        99.96%
# 341563  0.15                         0.00%                       100.00%
# 271075  0.15                         0.00%                       100.00%
# 673451  0.15                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 472877  4.12                        45.59%                        50.00%
# 177931  4.96                        56.04%                        37.36%
# 274947  4.18                        43.04%                        46.84%
# 349579  4.72                        53.85%                        44.87%
# 622270  4.49                        48.28%                        50.00%
# 592019  4.95                        53.42%                        41.10%
# 650866  4.76                        52.33%                        38.37%
# 509058  4.38                        48.72%                        46.15%
# 522980  4.60                        53.03%                        37.88%
# 175509  4.29                        46.74%                        43.48%
# 8468    4.75                        52.63%                        44.74%
# 81227   4.17                        48.78%                        47.56%
# 657999  3.89                        41.57%                        53.93%
# 98703   4.53                        51.28%                        43.59%
# 491276  3.89                        43.30%                        50.52%
# 463314  4.69                        48.28%                        46.55%
# 548273  4.75                        52.94%                        43.14%
# 274934  4.84                        55.00%                        40.00%
# 623825  4.53                        51.47%                        39.71%
# 667601  4.06                        46.75%                        50.65%
# 61472   4.53                        55.41%                        44.59%
# 530855  3.99                        41.30%                        45.65%
# 369901  4.63                        57.41%                        37.04%
# 327349  4.44                        46.05%                        38.16%
# 396995  3.95                        47.44%                        51.28%
# 119085  4.32                        42.67%                        46.67%
# 207632  4.12                        45.59%                        45.59%
# 392991  4.85                        53.52%                        33.80%
# 442085  4.07                        46.97%                        48.48%
# 317758  5.52                        61.40%                        26.32%
#
#                                 Timer Subtimer Name  Number of Records  \
# 642711                   DMSM_GETMEDIACONTENT (N/A)                  1
# 280854                   DMSM_GETMEDIACONTENT (N/A)                  1
# 447545                   DMSM_GETMEDIACONTENT (N/A)                  1
# 376550                   DMSM_GETMEDIACONTENT (N/A)                  1
# 305295                   DMSM_GETMEDIACONTENT (N/A)                  1
# 98917                    DMSM_GETMEDIACONTENT (N/A)                  1
# 426129                   DMSM_GETMEDIACONTENT (N/A)                  1
# 347498                   DMSM_GETMEDIACONTENT (N/A)                  1
# 8354                     DMSM_GETMEDIACONTENT (N/A)                  1
# 661101                   DMSM_GETMEDIACONTENT (N/A)                  1
# 591884                   DMSM_GETMEDIACONTENT (N/A)                  1
# 424275                   DMSM_GETMEDIACONTENT (N/A)                  1
# 389254                   DMSM_GETMEDIACONTENT (N/A)                  1
# 137556                   DMSM_GETMEDIACONTENT (N/A)                  1
# 438317                   DMSM_GETMEDIACONTENT (N/A)                  1
# 290374                   DMSM_GETMEDIACONTENT (N/A)                  1
# 68971                    DMSM_GETMEDIACONTENT (N/A)                  1
# 163210                   DMSM_GETMEDIACONTENT (N/A)                  1
# 201982                   DMSM_GETMEDIACONTENT (N/A)                  1
# 141399                   DMSM_GETMEDIACONTENT (N/A)                  1
# 629705                   DMSM_GETMEDIACONTENT (N/A)                  1
# 292636                   DMSM_GETMEDIACONTENT (N/A)                  1
# 577847                   DMSM_GETMEDIACONTENT (N/A)                  1
# 33072                    DMSM_GETMEDIACONTENT (N/A)                  1
# 479463                   DMSM_GETMEDIACONTENT (N/A)                  1
# 245482                   DMSM_GETMEDIACONTENT (N/A)                  1
# 106866                   DMSM_GETMEDIACONTENT (N/A)                  1
# 341563                   DMSM_GETMEDIACONTENT (N/A)                  1
# 271075                   DMSM_GETMEDIACONTENT (N/A)                  1
# 673451                   DMSM_GETMEDIACONTENT (N/A)                  1
# ...                                             ...                ...
# 472877  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 177931  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 274947  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 349579  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 622270  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 592019  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 650866  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 509058  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 522980  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 175509  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 8468    USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 81227   USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 657999  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 98703   USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 491276  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 463314  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 548273  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 274934  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 623825  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 667601  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 61472   USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 530855  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 369901  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 327349  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 396995  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 119085  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 207632  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 392991  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 442085  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 317758  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 642711       POWERCHART 2018-07-31  0.273690          NaN
# 280854       POWERCHART 2018-08-01  0.143897          NaN
# 447545       POWERCHART 2018-08-02  0.074053          NaN
# 376550       POWERCHART 2018-08-03  0.086916          NaN
# 305295       POWERCHART 2018-08-06  0.080803          NaN
# 98917        POWERCHART 2018-08-07  0.085864          NaN
# 426129       POWERCHART 2018-08-08  0.093581          NaN
# 347498       POWERCHART 2018-08-09  0.104255          NaN
# 8354         POWERCHART 2018-08-10  0.097991          NaN
# 661101       POWERCHART 2018-08-14  0.070129          NaN
# 591884       POWERCHART 2018-08-15  0.081760          NaN
# 424275       POWERCHART 2018-08-16  0.109795          NaN
# 389254       POWERCHART 2018-08-17  0.073036          NaN
# 137556       POWERCHART 2018-08-20  0.096728          NaN
# 438317       POWERCHART 2018-08-21  0.105542          NaN
# 290374       POWERCHART 2018-08-22  0.074734          NaN
# 68971        POWERCHART 2018-08-23  0.103197          NaN
# 163210       POWERCHART 2018-08-24  0.085955          NaN
# 201982       POWERCHART 2018-08-27  0.079786          NaN
# 141399       POWERCHART 2018-08-28  0.105092          NaN
# 629705       POWERCHART 2018-08-29  0.077442          NaN
# 292636       POWERCHART 2018-08-30  0.104720          NaN
# 577847       POWERCHART 2018-08-31  0.096848          NaN
# 33072        POWERCHART 2018-09-04  0.079725          NaN
# 479463       POWERCHART 2018-09-05  0.077272          NaN
# 245482       POWERCHART 2018-09-06  0.075886          NaN
# 106866       POWERCHART 2018-09-07  0.100203          NaN
# 341563       POWERCHART 2018-09-10  0.069566          NaN
# 271075       POWERCHART 2018-09-11  0.080959          NaN
# 673451       POWERCHART 2018-09-12  0.070212          NaN
# ...                 ...        ...       ...          ...
# 472877       POWERCHART 2018-09-12  4.013126          NaN
# 177931       POWERCHART 2018-09-13  4.034174          NaN
# 274947       POWERCHART 2018-09-14  3.909331          NaN
# 349579       POWERCHART 2018-09-17  4.164425          NaN
# 622270       POWERCHART 2018-09-18  4.305383          NaN
# 592019       POWERCHART 2018-09-19  4.199626          NaN
# 650866       POWERCHART 2018-09-20  3.840833          NaN
# 509058       POWERCHART 2018-09-21  4.157388          NaN
# 522980       POWERCHART 2018-09-24  3.544378          NaN
# 175509       POWERCHART 2018-09-25  3.780417          NaN
# 8468         POWERCHART 2018-09-26  4.128597          NaN
# 81227        POWERCHART 2018-09-27  3.785608          NaN
# 657999       POWERCHART 2018-09-28  3.793539          NaN
# 98703        POWERCHART 2018-10-01  3.758748          NaN
# 491276       POWERCHART 2018-10-02  3.640664          NaN
# 463314       POWERCHART 2018-10-04  5.265499          NaN
# 548273       POWERCHART 2018-10-05  4.127223          NaN
# 274934       POWERCHART 2018-10-08  3.735527          NaN
# 623825       POWERCHART 2018-10-09  3.649069          NaN
# 667601       POWERCHART 2018-10-10  3.760897          NaN
# 61472        POWERCHART 2018-10-11  3.818554          NaN
# 530855       POWERCHART 2018-10-12  3.615590          NaN
# 369901       POWERCHART 2018-10-15  3.448499          NaN
# 327349       POWERCHART 2018-10-16  3.525056          NaN
# 396995       POWERCHART 2018-10-17  3.615882          NaN
# 119085       POWERCHART 2018-10-18  4.040581          NaN
# 207632       POWERCHART 2018-10-19  3.681307          NaN
# 392991       POWERCHART 2018-10-22  3.616620          NaN
# 442085       POWERCHART 2018-10-23  3.770722          NaN
# 317758       POWERCHART 2018-10-24  3.570586          NaN
#
#                                     timername  total_elapsed  transAbove5  \
# 642711                   DMSM_GETMEDIACONTENT        880.955            1
# 280854                   DMSM_GETMEDIACONTENT        900.327            1
# 447545                   DMSM_GETMEDIACONTENT        889.563            0
# 376550                   DMSM_GETMEDIACONTENT        777.760            0
# 305295                   DMSM_GETMEDIACONTENT        908.990            0
# 98917                    DMSM_GETMEDIACONTENT        931.508            0
# 426129                   DMSM_GETMEDIACONTENT        900.311            0
# 347498                   DMSM_GETMEDIACONTENT        938.544            0
# 8354                     DMSM_GETMEDIACONTENT        782.390            0
# 661101                   DMSM_GETMEDIACONTENT        921.509            0
# 591884                   DMSM_GETMEDIACONTENT        900.628            0
# 424275                   DMSM_GETMEDIACONTENT        939.268            1
# 389254                   DMSM_GETMEDIACONTENT        762.252            0
# 137556                   DMSM_GETMEDIACONTENT        923.240            0
# 438317                   DMSM_GETMEDIACONTENT        983.956            0
# 290374                   DMSM_GETMEDIACONTENT        902.111            0
# 68971                    DMSM_GETMEDIACONTENT        956.747            0
# 163210                   DMSM_GETMEDIACONTENT        737.080            0
# 201982                   DMSM_GETMEDIACONTENT        956.114            0
# 141399                   DMSM_GETMEDIACONTENT        971.635            0
# 629705                   DMSM_GETMEDIACONTENT        873.157            0
# 292636                   DMSM_GETMEDIACONTENT        916.814            0
# 577847                   DMSM_GETMEDIACONTENT        763.421            0
# 33072                    DMSM_GETMEDIACONTENT        901.130            0
# 479463                   DMSM_GETMEDIACONTENT        946.879            0
# 245482                   DMSM_GETMEDIACONTENT        899.205            0
# 106866                   DMSM_GETMEDIACONTENT        753.307            0
# 341563                   DMSM_GETMEDIACONTENT       1054.584            0
# 271075                   DMSM_GETMEDIACONTENT       1071.231            0
# 673451                   DMSM_GETMEDIACONTENT        939.713            0
# ...                                       ...            ...          ...
# 472877  USR:WH-DELIVERY RECORD-ENSURE RESULTS        280.377           31
# 177931  USR:WH-DELIVERY RECORD-ENSURE RESULTS        451.235           51
# 274947  USR:WH-DELIVERY RECORD-ENSURE RESULTS        329.904           34
# 349579  USR:WH-DELIVERY RECORD-ENSURE RESULTS        367.804           42
# 622270  USR:WH-DELIVERY RECORD-ENSURE RESULTS        260.176           28
# 592019  USR:WH-DELIVERY RECORD-ENSURE RESULTS        361.667           39
# 650866  USR:WH-DELIVERY RECORD-ENSURE RESULTS        409.504           45
# 509058  USR:WH-DELIVERY RECORD-ENSURE RESULTS        341.620           38
# 522980  USR:WH-DELIVERY RECORD-ENSURE RESULTS        303.532           35
# 175509  USR:WH-DELIVERY RECORD-ENSURE RESULTS        394.814           43
# 8468    USR:WH-DELIVERY RECORD-ENSURE RESULTS        361.065           40
# 81227   USR:WH-DELIVERY RECORD-ENSURE RESULTS        342.199           40
# 657999  USR:WH-DELIVERY RECORD-ENSURE RESULTS        346.592           37
# 98703   USR:WH-DELIVERY RECORD-ENSURE RESULTS        353.719           40
# 491276  USR:WH-DELIVERY RECORD-ENSURE RESULTS        377.708           42
# 463314  USR:WH-DELIVERY RECORD-ENSURE RESULTS        271.731           28
# 548273  USR:WH-DELIVERY RECORD-ENSURE RESULTS        242.042           27
# 274934  USR:WH-DELIVERY RECORD-ENSURE RESULTS        290.554           33
# 623825  USR:WH-DELIVERY RECORD-ENSURE RESULTS        307.879           35
# 667601  USR:WH-DELIVERY RECORD-ENSURE RESULTS        312.688           36
# 61472   USR:WH-DELIVERY RECORD-ENSURE RESULTS        335.575           41
# 530855  USR:WH-DELIVERY RECORD-ENSURE RESULTS        367.508           38
# 369901  USR:WH-DELIVERY RECORD-ENSURE RESULTS        249.905           31
# 327349  USR:WH-DELIVERY RECORD-ENSURE RESULTS        337.612           35
# 396995  USR:WH-DELIVERY RECORD-ENSURE RESULTS        308.293           37
# 119085  USR:WH-DELIVERY RECORD-ENSURE RESULTS        323.917           32
# 207632  USR:WH-DELIVERY RECORD-ENSURE RESULTS        280.380           31
# 392991  USR:WH-DELIVERY RECORD-ENSURE RESULTS        344.570           38
# 442085  USR:WH-DELIVERY RECORD-ENSURE RESULTS        268.883           31
# 317758  USR:WH-DELIVERY RECORD-ENSURE RESULTS        314.919           35
#
#         transUnder2  transaction_cnt     isBDay    mavg30
# 642711         6210             6211 2018-07-31       NaN
# 280854         6230             6231 2018-08-01       NaN
# 447545         6090             6090 2018-08-02       NaN
# 376550         5006             5007 2018-08-03       NaN
# 305295         6021             6021 2018-08-06       NaN
# 98917          6202             6203 2018-08-07       NaN
# 426129         5663             5664 2018-08-08       NaN
# 347498         5701             5702 2018-08-09       NaN
# 8354           4969             4971 2018-08-10       NaN
# 661101         6318             6318 2018-08-14       NaN
# 591884         6110             6110 2018-08-15       NaN
# 424275         6180             6181 2018-08-16       NaN
# 389254         5042             5042 2018-08-17       NaN
# 137556         5939             5941 2018-08-20       NaN
# 438317         6153             6155 2018-08-21       NaN
# 290374         5971             5971 2018-08-22       NaN
# 68971          6023             6026 2018-08-23       NaN
# 163210         4960             4961 2018-08-24       NaN
# 201982         6325             6325 2018-08-27       NaN
# 141399         6498             6499 2018-08-28       NaN
# 629705         6017             6017 2018-08-29       NaN
# 292636         5953             5954 2018-08-30       NaN
# 577847         5262             5263 2018-08-31       NaN
# 33072          6253             6253 2018-09-04       NaN
# 479463         6437             6437 2018-09-05       NaN
# 245482         6291             6291 2018-09-06       NaN
# 106866         5039             5041 2018-09-07       NaN
# 341563         7014             7014 2018-09-10       NaN
# 271075         7081             7081 2018-09-11       NaN
# 673451         6163             6163 2018-09-12  0.151000
# ...             ...              ...        ...       ...
# 472877           34               68 2018-09-12       NaN
# 177931           34               91 2018-09-13       NaN
# 274947           37               79 2018-09-14  4.499667
# 349579           35               78 2018-09-17  4.508667
# 622270           29               58 2018-09-18  4.508000
# 592019           30               73 2018-09-19  4.520333
# 650866           33               86 2018-09-20  4.538000
# 509058           36               78 2018-09-21  4.530667
# 522980           25               66 2018-09-24  4.523667
# 175509           40               92 2018-09-25  4.533000
# 8468             34               76 2018-09-26  4.563000
# 81227            39               82 2018-09-27  4.555667
# 657999           48               89 2018-09-28  4.538333
# 98703            34               78 2018-10-01  4.550333
# 491276           49               97 2018-10-02  4.543333
# 463314           27               58 2018-10-04  4.523667
# 548273           22               51 2018-10-05  4.517000
# 274934           24               60 2018-10-08  4.535333
# 623825           27               68 2018-10-09  4.551333
# 667601           39               77 2018-10-10  4.539667
# 61472            33               74 2018-10-11  4.532333
# 530855           42               92 2018-10-12  4.539333
# 369901           20               54 2018-10-15  4.528333
# 327349           29               76 2018-10-16  4.540333
# 396995           40               78 2018-10-17  4.479333
# 119085           35               75 2018-10-18  4.458667
# 207632           31               68 2018-10-19  4.457667
# 392991           24               71 2018-10-22  4.484667
# 442085           32               66 2018-10-23  4.448333
# 317758           15               57 2018-10-24  4.465667
#
# [160243 rows x 16 columns]

# %% [markdown]
# ### Windows
#
# Add window - 7/8 day window using pandas shift().
#
# Difference between Trend and Shift
# - trend = "7 days in a row"
# - shift = "8 days above median"
#
# **to-do**
# - [x] start with shift/window.
# - [ ] establish how to identify trends and shifts using elif statements.
#
# **questions**
# - what happens when I compare something with a NaN value? - e.g. I compare days 1-7 with NaN?
# - do I need to drop rows with NaN, or return a null value?

# %%
# dataframe var is atrt_df_PC

atrt_df_PC['t-1'] = atrt_df_PC['ATRT'].shift(1)
atrt_df_PC['t-2'] = atrt_df_PC['ATRT'].shift(2)
atrt_df_PC['t-3'] = atrt_df_PC['ATRT'].shift(3)
atrt_df_PC['t-4'] = atrt_df_PC['ATRT'].shift(4)
atrt_df_PC['t-5'] = atrt_df_PC['ATRT'].shift(5)
atrt_df_PC['t-6'] = atrt_df_PC['ATRT'].shift(6)
atrt_df_PC['t-7'] = atrt_df_PC['ATRT'].shift(7)
atrt_df_PC['t-8'] = atrt_df_PC['ATRT'].shift(8)

df_pc = atrt_df_PC
df_pc.head()
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 642711  0.14                         0.02%                        99.98%
# 280854  0.14                         0.02%                        99.98%
# 447545  0.15                         0.00%                       100.00%
# 376550  0.16                         0.00%                        99.98%
# 305295  0.15                         0.00%                       100.00%
#
#                Timer Subtimer Name  Number of Records application_name  \
# 642711  DMSM_GETMEDIACONTENT (N/A)                  1       POWERCHART
# 280854  DMSM_GETMEDIACONTENT (N/A)                  1       POWERCHART
# 447545  DMSM_GETMEDIACONTENT (N/A)                  1       POWERCHART
# 376550  DMSM_GETMEDIACONTENT (N/A)                  1       POWERCHART
# 305295  DMSM_GETMEDIACONTENT (N/A)                  1       POWERCHART
#
#                dt      strt subtimername             timername ...   \
# 642711 2018-07-31  0.273690          NaN  DMSM_GETMEDIACONTENT ...
# 280854 2018-08-01  0.143897          NaN  DMSM_GETMEDIACONTENT ...
# 447545 2018-08-02  0.074053          NaN  DMSM_GETMEDIACONTENT ...
# 376550 2018-08-03  0.086916          NaN  DMSM_GETMEDIACONTENT ...
# 305295 2018-08-06  0.080803          NaN  DMSM_GETMEDIACONTENT ...
#
#            isBDay  mavg30   t-1   t-2   t-3   t-4  t-5  t-6  t-7  t-8
# 642711 2018-07-31     NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 280854 2018-08-01     NaN  0.14   NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 447545 2018-08-02     NaN  0.14  0.14   NaN   NaN  NaN  NaN  NaN  NaN
# 376550 2018-08-03     NaN  0.15  0.14  0.14   NaN  NaN  NaN  NaN  NaN
# 305295 2018-08-06     NaN  0.16  0.15  0.14  0.14  NaN  NaN  NaN  NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Control Charts
# Set upper and lower control limits, 60-day mean, signal detection.
# - Upper and lower control limits.
#     - Upper OUTLIER = .75 qt + 1.5x IQR??
#     - [x] Upper CONTROL = .75 qt
#     - [ ] Lower Outlier = .25 qt - 1.5x IQR
#     - [x] Lower control = .25 qt
#     - [x] Obtain IQR (on 60 day mean) for each timer.
#     - [ ] Multiply that by 1.5, set as variable
#     - [x] Then calculate UCL and LCL for each timer.
#
# - Shift detection:
#     - When t-n 8 of the previous N days above/below the median/mean
#     - elif statement?
#
# - Trend detection:
#     - When t-n (7) days in a row are higher than the previous day.
#
# **To-Do**
#
# - [x] interquartile range - loc lookup to ds? running calc? pandas has quartile built into running package
# - [x] drop NA values after creating all relevant metrics.
# - [ ] plotting control charts for timer.
#
#
# **Questions**
#
# Does it make sense to aggregate by week for smoother trends and less volatility?
# Which timers gave consistent up/down trend/shift signals for that week? Month?
# Which timers were outside the control limits more than N times during the previous period?
#
# ### Quantiles

# %%
df_pc['LCL_30'] = df_pc['ATRT'].rolling(30).quantile(.25, interpolation='lower')
df_pc['UCL_30'] = df_pc['ATRT'].rolling(30).quantile(.75, interpolation='higher')
df_pc['var_30'] = df_pc['ATRT'].rolling(30).var(ddof=1)

#IQR for future outlier removal
#df_pc['IQR'] = df_pc['.75'] - df_pc['.25']

df_pc
# Out:
# C:\Users\khickman1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\khickman1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\khickman1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 673451  0.15                         0.00%                       100.00%
# 261648  0.16                         0.00%                        99.98%
# 48954   0.15                         0.00%                        99.96%
# 394703  0.15                         0.03%                        99.97%
# 332814  0.14                         0.03%                        99.95%
# 641619  0.15                         0.00%                        99.95%
# 383603  0.15                         0.00%                        99.98%
# 399610  0.14                         0.00%                       100.00%
# 392869  0.14                         0.00%                       100.00%
# 571543  0.14                         0.00%                       100.00%
# 2011    0.14                         0.00%                        99.98%
# 438295  0.14                         0.00%                       100.00%
# 240176  0.14                         0.00%                       100.00%
# 255799  0.14                         0.00%                       100.00%
# 491807  0.14                         0.00%                       100.00%
# 445412  0.14                         0.00%                       100.00%
# 545608  0.70                         0.00%                       100.00%
# 400496  1.07                         0.00%                        66.67%
# 662791  0.37                         0.00%                       100.00%
# 526067  0.41                         0.00%                       100.00%
# 371789  0.63                         0.00%                       100.00%
# 303224  0.53                         0.00%                       100.00%
# 388489  0.84                         0.00%                       100.00%
# 471875  0.47                         0.00%                       100.00%
# 480810  0.58                         0.00%                       100.00%
# 338726  0.81                         0.00%                       100.00%
# 547527  0.67                         0.00%                       100.00%
# 350641  0.72                         0.00%                       100.00%
# 126451  0.36                         0.00%                       100.00%
# 430226  0.64                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 602106  0.67                         0.00%                       100.00%
# 527066  0.78                         0.00%                       100.00%
# 274947  4.18                        43.04%                        46.84%
# 349579  4.72                        53.85%                        44.87%
# 622270  4.49                        48.28%                        50.00%
# 592019  4.95                        53.42%                        41.10%
# 650866  4.76                        52.33%                        38.37%
# 509058  4.38                        48.72%                        46.15%
# 522980  4.60                        53.03%                        37.88%
# 175509  4.29                        46.74%                        43.48%
# 8468    4.75                        52.63%                        44.74%
# 81227   4.17                        48.78%                        47.56%
# 657999  3.89                        41.57%                        53.93%
# 98703   4.53                        51.28%                        43.59%
# 491276  3.89                        43.30%                        50.52%
# 463314  4.69                        48.28%                        46.55%
# 548273  4.75                        52.94%                        43.14%
# 274934  4.84                        55.00%                        40.00%
# 623825  4.53                        51.47%                        39.71%
# 667601  4.06                        46.75%                        50.65%
# 61472   4.53                        55.41%                        44.59%
# 530855  3.99                        41.30%                        45.65%
# 369901  4.63                        57.41%                        37.04%
# 327349  4.44                        46.05%                        38.16%
# 396995  3.95                        47.44%                        51.28%
# 119085  4.32                        42.67%                        46.67%
# 207632  4.12                        45.59%                        45.59%
# 392991  4.85                        53.52%                        33.80%
# 442085  4.07                        46.97%                        48.48%
# 317758  5.52                        61.40%                        26.32%
#
#                                       Timer Subtimer Name  Number of Records  \
# 673451                         DMSM_GETMEDIACONTENT (N/A)                  1
# 261648                         DMSM_GETMEDIACONTENT (N/A)                  1
# 48954                          DMSM_GETMEDIACONTENT (N/A)                  1
# 394703                         DMSM_GETMEDIACONTENT (N/A)                  1
# 332814                         DMSM_GETMEDIACONTENT (N/A)                  1
# 641619                         DMSM_GETMEDIACONTENT (N/A)                  1
# 383603                         DMSM_GETMEDIACONTENT (N/A)                  1
# 399610                         DMSM_GETMEDIACONTENT (N/A)                  1
# 392869                         DMSM_GETMEDIACONTENT (N/A)                  1
# 571543                         DMSM_GETMEDIACONTENT (N/A)                  1
# 2011                           DMSM_GETMEDIACONTENT (N/A)                  1
# 438295                         DMSM_GETMEDIACONTENT (N/A)                  1
# 240176                         DMSM_GETMEDIACONTENT (N/A)                  1
# 255799                         DMSM_GETMEDIACONTENT (N/A)                  1
# 491807                         DMSM_GETMEDIACONTENT (N/A)                  1
# 445412                         DMSM_GETMEDIACONTENT (N/A)                  1
# 545608                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 400496                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 662791                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 526067                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 371789                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 303224                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 388489                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 471875                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 480810                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 338726                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 547527                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 350641                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 126451                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 430226                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# ...                                                   ...                ...
# 602106  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 527066  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 274947        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 349579        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 622270        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 592019        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 650866        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 509058        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 522980        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 175509        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 8468          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 81227         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 657999        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 98703         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 491276        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 463314        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 548273        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 274934        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 623825        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 667601        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 61472         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 530855        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 369901        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 327349        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 396995        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 119085        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 207632        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 392991        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 442085        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 317758        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 673451       POWERCHART 2018-09-12  0.070212          NaN
# 261648       POWERCHART 2018-09-13  0.089830          NaN
# 48954        POWERCHART 2018-09-14  0.089884          NaN
# 394703       POWERCHART 2018-09-17  0.156930          NaN
# 332814       POWERCHART 2018-09-18  0.233025          NaN
# 641619       POWERCHART 2018-09-27  0.101519          NaN
# 383603       POWERCHART 2018-09-28  0.100805          NaN
# 399610       POWERCHART 2018-10-02  0.070028          NaN
# 392869       POWERCHART 2018-10-03  0.062836          NaN
# 571543       POWERCHART 2018-10-09  0.069858          NaN
# 2011         POWERCHART 2018-10-15  0.083543          NaN
# 438295       POWERCHART 2018-10-16  0.075542          NaN
# 240176       POWERCHART 2018-10-18  0.062809          NaN
# 255799       POWERCHART 2018-10-23  0.068284          NaN
# 491807       POWERCHART 2018-10-24  0.069277          NaN
# 445412       POWERCHART 2018-10-29  0.078902          NaN
# 545608       POWERCHART 2018-09-17  0.298399          NaN
# 400496       POWERCHART 2018-09-18  1.308079          NaN
# 662791       POWERCHART 2018-09-20  0.413173          NaN
# 526067       POWERCHART 2018-09-21  0.165633          NaN
# 371789       POWERCHART 2018-09-24  0.282050          NaN
# 303224       POWERCHART 2018-09-25  0.368174          NaN
# 388489       POWERCHART 2018-09-26  0.094260          NaN
# 471875       POWERCHART 2018-09-27  0.409663          NaN
# 480810       POWERCHART 2018-09-28  0.178580          NaN
# 338726       POWERCHART 2018-10-01       NaN          NaN
# 547527       POWERCHART 2018-10-03  0.265165          NaN
# 350641       POWERCHART 2018-10-04  0.420021          NaN
# 126451       POWERCHART 2018-10-05  0.238620          NaN
# 430226       POWERCHART 2018-10-09  0.066468          NaN
# ...                 ...        ...       ...          ...
# 602106       POWERCHART 2018-10-25  0.037541          NaN
# 527066       POWERCHART 2018-10-26  0.238071          NaN
# 274947       POWERCHART 2018-09-14  3.909331          NaN
# 349579       POWERCHART 2018-09-17  4.164425          NaN
# 622270       POWERCHART 2018-09-18  4.305383          NaN
# 592019       POWERCHART 2018-09-19  4.199626          NaN
# 650866       POWERCHART 2018-09-20  3.840833          NaN
# 509058       POWERCHART 2018-09-21  4.157388          NaN
# 522980       POWERCHART 2018-09-24  3.544378          NaN
# 175509       POWERCHART 2018-09-25  3.780417          NaN
# 8468         POWERCHART 2018-09-26  4.128597          NaN
# 81227        POWERCHART 2018-09-27  3.785608          NaN
# 657999       POWERCHART 2018-09-28  3.793539          NaN
# 98703        POWERCHART 2018-10-01  3.758748          NaN
# 491276       POWERCHART 2018-10-02  3.640664          NaN
# 463314       POWERCHART 2018-10-04  5.265499          NaN
# 548273       POWERCHART 2018-10-05  4.127223          NaN
# 274934       POWERCHART 2018-10-08  3.735527          NaN
# 623825       POWERCHART 2018-10-09  3.649069          NaN
# 667601       POWERCHART 2018-10-10  3.760897          NaN
# 61472        POWERCHART 2018-10-11  3.818554          NaN
# 530855       POWERCHART 2018-10-12  3.615590          NaN
# 369901       POWERCHART 2018-10-15  3.448499          NaN
# 327349       POWERCHART 2018-10-16  3.525056          NaN
# 396995       POWERCHART 2018-10-17  3.615882          NaN
# 119085       POWERCHART 2018-10-18  4.040581          NaN
# 207632       POWERCHART 2018-10-19  3.681307          NaN
# 392991       POWERCHART 2018-10-22  3.616620          NaN
# 442085       POWERCHART 2018-10-23  3.770722          NaN
# 317758       POWERCHART 2018-10-24  3.570586          NaN
#
#                                               timername    ...      t-2   t-3  \
# 673451                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 261648                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 48954                              DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 394703                             DMSM_GETMEDIACONTENT    ...     0.16  0.15
# 332814                             DMSM_GETMEDIACONTENT    ...     0.15  0.16
# 641619                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 383603                             DMSM_GETMEDIACONTENT    ...     0.14  0.15
# 399610                             DMSM_GETMEDIACONTENT    ...     0.15  0.14
# 392869                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 571543                             DMSM_GETMEDIACONTENT    ...     0.14  0.15
# 2011                               DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 438295                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 240176                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 255799                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 491807                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 445412                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 545608                          DMSM_GETMEDIAOBJECTLIST    ...     0.75  0.91
# 400496                          DMSM_GETMEDIAOBJECTLIST    ...     0.89  0.75
# 662791                          DMSM_GETMEDIAOBJECTLIST    ...     0.70  0.89
# 526067                          DMSM_GETMEDIAOBJECTLIST    ...     1.07  0.70
# 371789                          DMSM_GETMEDIAOBJECTLIST    ...     0.37  1.07
# 303224                          DMSM_GETMEDIAOBJECTLIST    ...     0.41  0.37
# 388489                          DMSM_GETMEDIAOBJECTLIST    ...     0.63  0.41
# 471875                          DMSM_GETMEDIAOBJECTLIST    ...     0.53  0.63
# 480810                          DMSM_GETMEDIAOBJECTLIST    ...     0.84  0.53
# 338726                          DMSM_GETMEDIAOBJECTLIST    ...     0.47  0.84
# 547527                          DMSM_GETMEDIAOBJECTLIST    ...     0.58  0.47
# 350641                          DMSM_GETMEDIAOBJECTLIST    ...     0.81  0.58
# 126451                          DMSM_GETMEDIAOBJECTLIST    ...     0.67  0.81
# 430226                          DMSM_GETMEDIAOBJECTLIST    ...     0.72  0.67
# ...                                                 ...    ...      ...   ...
# 602106  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME    ...     0.86  0.90
# 527066  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME    ...     0.93  0.86
# 274947            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.12  5.00
# 349579            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.96  4.12
# 622270            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.18  4.96
# 592019            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.72  4.18
# 650866            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.49  4.72
# 509058            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.95  4.49
# 522980            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.76  4.95
# 175509            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.38  4.76
# 8468              USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.60  4.38
# 81227             USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.29  4.60
# 657999            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.75  4.29
# 98703             USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.17  4.75
# 491276            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.89  4.17
# 463314            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.53  3.89
# 548273            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.89  4.53
# 274934            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.69  3.89
# 623825            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.75  4.69
# 667601            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.84  4.75
# 61472             USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.53  4.84
# 530855            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.06  4.53
# 369901            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.53  4.06
# 327349            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.99  4.53
# 396995            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.63  3.99
# 119085            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.44  4.63
# 207632            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.95  4.44
# 392991            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.32  3.95
# 442085            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.12  4.32
# 317758            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.85  4.12
#
#          t-4   t-5   t-6   t-7   t-8  LCL_30  UCL_30    var_30
# 673451  0.14  0.15  0.14  0.15  0.15     NaN     NaN       NaN
# 261648  0.15  0.14  0.15  0.14  0.15     NaN     NaN       NaN
# 48954   0.15  0.15  0.14  0.15  0.14     NaN     NaN       NaN
# 394703  0.15  0.15  0.15  0.14  0.15     NaN     NaN       NaN
# 332814  0.15  0.15  0.15  0.15  0.14     NaN     NaN       NaN
# 641619  0.16  0.15  0.15  0.15  0.15     NaN     NaN       NaN
# 383603  0.15  0.16  0.15  0.15  0.15     NaN     NaN       NaN
# 399610  0.15  0.15  0.16  0.15  0.15     NaN     NaN       NaN
# 392869  0.14  0.15  0.15  0.16  0.15     NaN     NaN       NaN
# 571543  0.15  0.14  0.15  0.15  0.16     NaN     NaN       NaN
# 2011    0.15  0.15  0.14  0.15  0.15     NaN     NaN       NaN
# 438295  0.14  0.15  0.15  0.14  0.15     NaN     NaN       NaN
# 240176  0.14  0.14  0.15  0.15  0.14     NaN     NaN       NaN
# 255799  0.14  0.14  0.14  0.15  0.15     NaN     NaN       NaN
# 491807  0.14  0.14  0.14  0.14  0.15     NaN     NaN       NaN
# 445412  0.14  0.14  0.14  0.14  0.14     NaN     NaN       NaN
# 545608  0.78  0.90  0.70  1.14  0.67     NaN     NaN       NaN
# 400496  0.91  0.78  0.90  0.70  1.14     NaN     NaN       NaN
# 662791  0.75  0.91  0.78  0.90  0.70     NaN     NaN       NaN
# 526067  0.89  0.75  0.91  0.78  0.90     NaN     NaN       NaN
# 371789  0.70  0.89  0.75  0.91  0.78     NaN     NaN       NaN
# 303224  1.07  0.70  0.89  0.75  0.91     NaN     NaN       NaN
# 388489  0.37  1.07  0.70  0.89  0.75     NaN     NaN       NaN
# 471875  0.41  0.37  1.07  0.70  0.89     NaN     NaN       NaN
# 480810  0.63  0.41  0.37  1.07  0.70     NaN     NaN       NaN
# 338726  0.53  0.63  0.41  0.37  1.07     NaN     NaN       NaN
# 547527  0.84  0.53  0.63  0.41  0.37     NaN     NaN       NaN
# 350641  0.47  0.84  0.53  0.63  0.41     NaN     NaN       NaN
# 126451  0.58  0.47  0.84  0.53  0.63     NaN     NaN       NaN
# 430226  0.81  0.58  0.47  0.84  0.53    0.14    0.63  0.078031
# ...      ...   ...   ...   ...   ...     ...     ...       ...
# 602106  0.79  0.88  0.82  0.72  0.75    0.80    0.89  0.012973
# 527066  0.90  0.79  0.88  0.82  0.72    0.79    0.88  0.011360
# 274947  5.16  4.04  4.15  4.94  5.78    0.79    0.88  0.380256
# 349579  5.00  5.16  4.04  4.15  4.94    0.79    0.88  0.854860
# 622270  4.12  5.00  5.16  4.04  4.15    0.79    0.89  1.241556
# 592019  4.96  4.12  5.00  5.16  4.04    0.79    0.89  1.706412
# 650866  4.18  4.96  4.12  5.00  5.16    0.79    0.90  2.087688
# 509058  4.72  4.18  4.96  4.12  5.00    0.79    0.90  2.354754
# 522980  4.49  4.72  4.18  4.96  4.12    0.79    0.93  2.634038
# 175509  4.95  4.49  4.72  4.18  4.96    0.79    4.18  2.826246
# 8468    4.76  4.95  4.49  4.72  4.18    0.79    4.29  3.077470
# 81227   4.38  4.76  4.95  4.49  4.72    0.79    4.29  3.192950
# 657999  4.60  4.38  4.76  4.95  4.49    0.79    4.29  3.251177
# 98703   4.29  4.60  4.38  4.76  4.95    0.79    4.38  3.366464
# 491276  4.75  4.29  4.60  4.38  4.76    0.80    4.38  3.366249
# 463314  4.17  4.75  4.29  4.60  4.38    0.80    4.49  3.444787
# 548273  3.89  4.17  4.75  4.29  4.60    0.82    4.53  3.498226
# 274934  4.53  3.89  4.17  4.75  4.29    0.82    4.60  3.540314
# 623825  3.89  4.53  3.89  4.17  4.75    0.82    4.60  3.501420
# 667601  4.69  3.89  4.53  3.89  4.17    0.86    4.60  3.380626
# 61472   4.75  4.69  3.89  4.53  3.89    0.88    4.60  3.276229
# 530855  4.84  4.75  4.69  3.89  4.53    0.88    4.60  3.117024
# 369901  4.53  4.84  4.75  4.69  3.89    0.90    4.63  2.953529
# 327349  4.06  4.53  4.84  4.75  4.69    0.93    4.63  2.736059
# 396995  4.53  4.06  4.53  4.84  4.75    3.89    4.63  2.486342
# 119085  3.99  4.53  4.06  4.53  4.84    3.89    4.63  2.236922
# 207632  4.63  3.99  4.53  4.06  4.53    3.95    4.63  1.936265
# 392991  4.44  4.63  3.99  4.53  4.06    3.99    4.69  1.660991
# 442085  3.95  4.44  4.63  3.99  4.53    4.06    4.69  1.320104
# 317758  4.32  3.95  4.44  4.63  3.99    4.07    4.72  1.032095
#
# [64554 rows x 27 columns]

# %% [markdown]
# ### Remove missing values
# Removing any values without the 30 day moving average.
# Use ```np.isfinite``` instead of dropping na values.
#
# **ToDo**
#
#     [ ] should we instead just use a dummy var if any value isna?

# %%
df_pc = df_pc[np.isfinite(df_pc['mavg30'])]
df_pc
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 673451  0.15                         0.00%                       100.00%
# 261648  0.16                         0.00%                        99.98%
# 48954   0.15                         0.00%                        99.96%
# 394703  0.15                         0.03%                        99.97%
# 332814  0.14                         0.03%                        99.95%
# 641619  0.15                         0.00%                        99.95%
# 383603  0.15                         0.00%                        99.98%
# 399610  0.14                         0.00%                       100.00%
# 392869  0.14                         0.00%                       100.00%
# 571543  0.14                         0.00%                       100.00%
# 2011    0.14                         0.00%                        99.98%
# 438295  0.14                         0.00%                       100.00%
# 240176  0.14                         0.00%                       100.00%
# 255799  0.14                         0.00%                       100.00%
# 491807  0.14                         0.00%                       100.00%
# 445412  0.14                         0.00%                       100.00%
# 545608  0.70                         0.00%                       100.00%
# 400496  1.07                         0.00%                        66.67%
# 662791  0.37                         0.00%                       100.00%
# 526067  0.41                         0.00%                       100.00%
# 371789  0.63                         0.00%                       100.00%
# 303224  0.53                         0.00%                       100.00%
# 388489  0.84                         0.00%                       100.00%
# 471875  0.47                         0.00%                       100.00%
# 480810  0.58                         0.00%                       100.00%
# 338726  0.81                         0.00%                       100.00%
# 547527  0.67                         0.00%                       100.00%
# 350641  0.72                         0.00%                       100.00%
# 126451  0.36                         0.00%                       100.00%
# 430226  0.64                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 602106  0.67                         0.00%                       100.00%
# 527066  0.78                         0.00%                       100.00%
# 274947  4.18                        43.04%                        46.84%
# 349579  4.72                        53.85%                        44.87%
# 622270  4.49                        48.28%                        50.00%
# 592019  4.95                        53.42%                        41.10%
# 650866  4.76                        52.33%                        38.37%
# 509058  4.38                        48.72%                        46.15%
# 522980  4.60                        53.03%                        37.88%
# 175509  4.29                        46.74%                        43.48%
# 8468    4.75                        52.63%                        44.74%
# 81227   4.17                        48.78%                        47.56%
# 657999  3.89                        41.57%                        53.93%
# 98703   4.53                        51.28%                        43.59%
# 491276  3.89                        43.30%                        50.52%
# 463314  4.69                        48.28%                        46.55%
# 548273  4.75                        52.94%                        43.14%
# 274934  4.84                        55.00%                        40.00%
# 623825  4.53                        51.47%                        39.71%
# 667601  4.06                        46.75%                        50.65%
# 61472   4.53                        55.41%                        44.59%
# 530855  3.99                        41.30%                        45.65%
# 369901  4.63                        57.41%                        37.04%
# 327349  4.44                        46.05%                        38.16%
# 396995  3.95                        47.44%                        51.28%
# 119085  4.32                        42.67%                        46.67%
# 207632  4.12                        45.59%                        45.59%
# 392991  4.85                        53.52%                        33.80%
# 442085  4.07                        46.97%                        48.48%
# 317758  5.52                        61.40%                        26.32%
#
#                                       Timer Subtimer Name  Number of Records  \
# 673451                         DMSM_GETMEDIACONTENT (N/A)                  1
# 261648                         DMSM_GETMEDIACONTENT (N/A)                  1
# 48954                          DMSM_GETMEDIACONTENT (N/A)                  1
# 394703                         DMSM_GETMEDIACONTENT (N/A)                  1
# 332814                         DMSM_GETMEDIACONTENT (N/A)                  1
# 641619                         DMSM_GETMEDIACONTENT (N/A)                  1
# 383603                         DMSM_GETMEDIACONTENT (N/A)                  1
# 399610                         DMSM_GETMEDIACONTENT (N/A)                  1
# 392869                         DMSM_GETMEDIACONTENT (N/A)                  1
# 571543                         DMSM_GETMEDIACONTENT (N/A)                  1
# 2011                           DMSM_GETMEDIACONTENT (N/A)                  1
# 438295                         DMSM_GETMEDIACONTENT (N/A)                  1
# 240176                         DMSM_GETMEDIACONTENT (N/A)                  1
# 255799                         DMSM_GETMEDIACONTENT (N/A)                  1
# 491807                         DMSM_GETMEDIACONTENT (N/A)                  1
# 445412                         DMSM_GETMEDIACONTENT (N/A)                  1
# 545608                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 400496                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 662791                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 526067                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 371789                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 303224                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 388489                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 471875                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 480810                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 338726                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 547527                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 350641                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 126451                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 430226                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# ...                                                   ...                ...
# 602106  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 527066  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 274947        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 349579        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 622270        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 592019        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 650866        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 509058        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 522980        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 175509        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 8468          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 81227         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 657999        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 98703         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 491276        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 463314        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 548273        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 274934        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 623825        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 667601        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 61472         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 530855        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 369901        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 327349        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 396995        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 119085        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 207632        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 392991        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 442085        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 317758        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 673451       POWERCHART 2018-09-12  0.070212          NaN
# 261648       POWERCHART 2018-09-13  0.089830          NaN
# 48954        POWERCHART 2018-09-14  0.089884          NaN
# 394703       POWERCHART 2018-09-17  0.156930          NaN
# 332814       POWERCHART 2018-09-18  0.233025          NaN
# 641619       POWERCHART 2018-09-27  0.101519          NaN
# 383603       POWERCHART 2018-09-28  0.100805          NaN
# 399610       POWERCHART 2018-10-02  0.070028          NaN
# 392869       POWERCHART 2018-10-03  0.062836          NaN
# 571543       POWERCHART 2018-10-09  0.069858          NaN
# 2011         POWERCHART 2018-10-15  0.083543          NaN
# 438295       POWERCHART 2018-10-16  0.075542          NaN
# 240176       POWERCHART 2018-10-18  0.062809          NaN
# 255799       POWERCHART 2018-10-23  0.068284          NaN
# 491807       POWERCHART 2018-10-24  0.069277          NaN
# 445412       POWERCHART 2018-10-29  0.078902          NaN
# 545608       POWERCHART 2018-09-17  0.298399          NaN
# 400496       POWERCHART 2018-09-18  1.308079          NaN
# 662791       POWERCHART 2018-09-20  0.413173          NaN
# 526067       POWERCHART 2018-09-21  0.165633          NaN
# 371789       POWERCHART 2018-09-24  0.282050          NaN
# 303224       POWERCHART 2018-09-25  0.368174          NaN
# 388489       POWERCHART 2018-09-26  0.094260          NaN
# 471875       POWERCHART 2018-09-27  0.409663          NaN
# 480810       POWERCHART 2018-09-28  0.178580          NaN
# 338726       POWERCHART 2018-10-01       NaN          NaN
# 547527       POWERCHART 2018-10-03  0.265165          NaN
# 350641       POWERCHART 2018-10-04  0.420021          NaN
# 126451       POWERCHART 2018-10-05  0.238620          NaN
# 430226       POWERCHART 2018-10-09  0.066468          NaN
# ...                 ...        ...       ...          ...
# 602106       POWERCHART 2018-10-25  0.037541          NaN
# 527066       POWERCHART 2018-10-26  0.238071          NaN
# 274947       POWERCHART 2018-09-14  3.909331          NaN
# 349579       POWERCHART 2018-09-17  4.164425          NaN
# 622270       POWERCHART 2018-09-18  4.305383          NaN
# 592019       POWERCHART 2018-09-19  4.199626          NaN
# 650866       POWERCHART 2018-09-20  3.840833          NaN
# 509058       POWERCHART 2018-09-21  4.157388          NaN
# 522980       POWERCHART 2018-09-24  3.544378          NaN
# 175509       POWERCHART 2018-09-25  3.780417          NaN
# 8468         POWERCHART 2018-09-26  4.128597          NaN
# 81227        POWERCHART 2018-09-27  3.785608          NaN
# 657999       POWERCHART 2018-09-28  3.793539          NaN
# 98703        POWERCHART 2018-10-01  3.758748          NaN
# 491276       POWERCHART 2018-10-02  3.640664          NaN
# 463314       POWERCHART 2018-10-04  5.265499          NaN
# 548273       POWERCHART 2018-10-05  4.127223          NaN
# 274934       POWERCHART 2018-10-08  3.735527          NaN
# 623825       POWERCHART 2018-10-09  3.649069          NaN
# 667601       POWERCHART 2018-10-10  3.760897          NaN
# 61472        POWERCHART 2018-10-11  3.818554          NaN
# 530855       POWERCHART 2018-10-12  3.615590          NaN
# 369901       POWERCHART 2018-10-15  3.448499          NaN
# 327349       POWERCHART 2018-10-16  3.525056          NaN
# 396995       POWERCHART 2018-10-17  3.615882          NaN
# 119085       POWERCHART 2018-10-18  4.040581          NaN
# 207632       POWERCHART 2018-10-19  3.681307          NaN
# 392991       POWERCHART 2018-10-22  3.616620          NaN
# 442085       POWERCHART 2018-10-23  3.770722          NaN
# 317758       POWERCHART 2018-10-24  3.570586          NaN
#
#                                               timername    ...      t-2   t-3  \
# 673451                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 261648                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 48954                              DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 394703                             DMSM_GETMEDIACONTENT    ...     0.16  0.15
# 332814                             DMSM_GETMEDIACONTENT    ...     0.15  0.16
# 641619                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 383603                             DMSM_GETMEDIACONTENT    ...     0.14  0.15
# 399610                             DMSM_GETMEDIACONTENT    ...     0.15  0.14
# 392869                             DMSM_GETMEDIACONTENT    ...     0.15  0.15
# 571543                             DMSM_GETMEDIACONTENT    ...     0.14  0.15
# 2011                               DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 438295                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 240176                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 255799                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 491807                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 445412                             DMSM_GETMEDIACONTENT    ...     0.14  0.14
# 545608                          DMSM_GETMEDIAOBJECTLIST    ...     0.75  0.91
# 400496                          DMSM_GETMEDIAOBJECTLIST    ...     0.89  0.75
# 662791                          DMSM_GETMEDIAOBJECTLIST    ...     0.70  0.89
# 526067                          DMSM_GETMEDIAOBJECTLIST    ...     1.07  0.70
# 371789                          DMSM_GETMEDIAOBJECTLIST    ...     0.37  1.07
# 303224                          DMSM_GETMEDIAOBJECTLIST    ...     0.41  0.37
# 388489                          DMSM_GETMEDIAOBJECTLIST    ...     0.63  0.41
# 471875                          DMSM_GETMEDIAOBJECTLIST    ...     0.53  0.63
# 480810                          DMSM_GETMEDIAOBJECTLIST    ...     0.84  0.53
# 338726                          DMSM_GETMEDIAOBJECTLIST    ...     0.47  0.84
# 547527                          DMSM_GETMEDIAOBJECTLIST    ...     0.58  0.47
# 350641                          DMSM_GETMEDIAOBJECTLIST    ...     0.81  0.58
# 126451                          DMSM_GETMEDIAOBJECTLIST    ...     0.67  0.81
# 430226                          DMSM_GETMEDIAOBJECTLIST    ...     0.72  0.67
# ...                                                 ...    ...      ...   ...
# 602106  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME    ...     0.86  0.90
# 527066  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME    ...     0.93  0.86
# 274947            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.12  5.00
# 349579            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.96  4.12
# 622270            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.18  4.96
# 592019            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.72  4.18
# 650866            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.49  4.72
# 509058            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.95  4.49
# 522980            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.76  4.95
# 175509            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.38  4.76
# 8468              USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.60  4.38
# 81227             USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.29  4.60
# 657999            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.75  4.29
# 98703             USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.17  4.75
# 491276            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.89  4.17
# 463314            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.53  3.89
# 548273            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.89  4.53
# 274934            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.69  3.89
# 623825            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.75  4.69
# 667601            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.84  4.75
# 61472             USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.53  4.84
# 530855            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.06  4.53
# 369901            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.53  4.06
# 327349            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.99  4.53
# 396995            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.63  3.99
# 119085            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.44  4.63
# 207632            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     3.95  4.44
# 392991            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.32  3.95
# 442085            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.12  4.32
# 317758            USR:WH-DELIVERY RECORD-ENSURE RESULTS    ...     4.85  4.12
#
#          t-4   t-5   t-6   t-7   t-8  LCL_30  UCL_30    var_30
# 673451  0.14  0.15  0.14  0.15  0.15     NaN     NaN       NaN
# 261648  0.15  0.14  0.15  0.14  0.15     NaN     NaN       NaN
# 48954   0.15  0.15  0.14  0.15  0.14     NaN     NaN       NaN
# 394703  0.15  0.15  0.15  0.14  0.15     NaN     NaN       NaN
# 332814  0.15  0.15  0.15  0.15  0.14     NaN     NaN       NaN
# 641619  0.16  0.15  0.15  0.15  0.15     NaN     NaN       NaN
# 383603  0.15  0.16  0.15  0.15  0.15     NaN     NaN       NaN
# 399610  0.15  0.15  0.16  0.15  0.15     NaN     NaN       NaN
# 392869  0.14  0.15  0.15  0.16  0.15     NaN     NaN       NaN
# 571543  0.15  0.14  0.15  0.15  0.16     NaN     NaN       NaN
# 2011    0.15  0.15  0.14  0.15  0.15     NaN     NaN       NaN
# 438295  0.14  0.15  0.15  0.14  0.15     NaN     NaN       NaN
# 240176  0.14  0.14  0.15  0.15  0.14     NaN     NaN       NaN
# 255799  0.14  0.14  0.14  0.15  0.15     NaN     NaN       NaN
# 491807  0.14  0.14  0.14  0.14  0.15     NaN     NaN       NaN
# 445412  0.14  0.14  0.14  0.14  0.14     NaN     NaN       NaN
# 545608  0.78  0.90  0.70  1.14  0.67     NaN     NaN       NaN
# 400496  0.91  0.78  0.90  0.70  1.14     NaN     NaN       NaN
# 662791  0.75  0.91  0.78  0.90  0.70     NaN     NaN       NaN
# 526067  0.89  0.75  0.91  0.78  0.90     NaN     NaN       NaN
# 371789  0.70  0.89  0.75  0.91  0.78     NaN     NaN       NaN
# 303224  1.07  0.70  0.89  0.75  0.91     NaN     NaN       NaN
# 388489  0.37  1.07  0.70  0.89  0.75     NaN     NaN       NaN
# 471875  0.41  0.37  1.07  0.70  0.89     NaN     NaN       NaN
# 480810  0.63  0.41  0.37  1.07  0.70     NaN     NaN       NaN
# 338726  0.53  0.63  0.41  0.37  1.07     NaN     NaN       NaN
# 547527  0.84  0.53  0.63  0.41  0.37     NaN     NaN       NaN
# 350641  0.47  0.84  0.53  0.63  0.41     NaN     NaN       NaN
# 126451  0.58  0.47  0.84  0.53  0.63     NaN     NaN       NaN
# 430226  0.81  0.58  0.47  0.84  0.53    0.14    0.63  0.078031
# ...      ...   ...   ...   ...   ...     ...     ...       ...
# 602106  0.79  0.88  0.82  0.72  0.75    0.80    0.89  0.012973
# 527066  0.90  0.79  0.88  0.82  0.72    0.79    0.88  0.011360
# 274947  5.16  4.04  4.15  4.94  5.78    0.79    0.88  0.380256
# 349579  5.00  5.16  4.04  4.15  4.94    0.79    0.88  0.854860
# 622270  4.12  5.00  5.16  4.04  4.15    0.79    0.89  1.241556
# 592019  4.96  4.12  5.00  5.16  4.04    0.79    0.89  1.706412
# 650866  4.18  4.96  4.12  5.00  5.16    0.79    0.90  2.087688
# 509058  4.72  4.18  4.96  4.12  5.00    0.79    0.90  2.354754
# 522980  4.49  4.72  4.18  4.96  4.12    0.79    0.93  2.634038
# 175509  4.95  4.49  4.72  4.18  4.96    0.79    4.18  2.826246
# 8468    4.76  4.95  4.49  4.72  4.18    0.79    4.29  3.077470
# 81227   4.38  4.76  4.95  4.49  4.72    0.79    4.29  3.192950
# 657999  4.60  4.38  4.76  4.95  4.49    0.79    4.29  3.251177
# 98703   4.29  4.60  4.38  4.76  4.95    0.79    4.38  3.366464
# 491276  4.75  4.29  4.60  4.38  4.76    0.80    4.38  3.366249
# 463314  4.17  4.75  4.29  4.60  4.38    0.80    4.49  3.444787
# 548273  3.89  4.17  4.75  4.29  4.60    0.82    4.53  3.498226
# 274934  4.53  3.89  4.17  4.75  4.29    0.82    4.60  3.540314
# 623825  3.89  4.53  3.89  4.17  4.75    0.82    4.60  3.501420
# 667601  4.69  3.89  4.53  3.89  4.17    0.86    4.60  3.380626
# 61472   4.75  4.69  3.89  4.53  3.89    0.88    4.60  3.276229
# 530855  4.84  4.75  4.69  3.89  4.53    0.88    4.60  3.117024
# 369901  4.53  4.84  4.75  4.69  3.89    0.90    4.63  2.953529
# 327349  4.06  4.53  4.84  4.75  4.69    0.93    4.63  2.736059
# 396995  4.53  4.06  4.53  4.84  4.75    3.89    4.63  2.486342
# 119085  3.99  4.53  4.06  4.53  4.84    3.89    4.63  2.236922
# 207632  4.63  3.99  4.53  4.06  4.53    3.95    4.63  1.936265
# 392991  4.44  4.63  3.99  4.53  4.06    3.99    4.69  1.660991
# 442085  3.95  4.44  4.63  3.99  4.53    4.06    4.69  1.320104
# 317758  4.32  3.95  4.44  4.63  3.99    4.07    4.72  1.032095
#
# [64554 rows x 27 columns]

# %% [markdown]
# ### Signal detection:
#
# - when did the signal start?
# - what is the signal up/down shift or trend?
# - include "magnitude of change"
# - how about cumulative sum?
# - abs(t1-t2) + abs(t2-t3)
#
#
# **Questions**
#
# - How useful is identifying a spike if we don't have daily data?

# %%
df_pc_test = df_pc
df_pc_test

def signal_detect(df):

    if (df['t-8'] >= df['mavg30'] and (df['t-7'] >= df['mavg30'])):
        return 'Red'
    #elif (df['trigger2'] <= df['score'] < df['trigger3']) and (df['height'] < 8):
    #    return 'Yellow'
    #elif (df['trigger3'] <= df['score']) and (df['height'] < 8):
    #    return 'Orange'
    #elif (df['height'] > 8):
    #    return np.nan

df_pc_test['signal'] = df_pc_test.apply(signal_detect, axis = 1)
df_pc_test
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 673451  0.15                         0.00%                       100.00%
# 261648  0.16                         0.00%                        99.98%
# 48954   0.15                         0.00%                        99.96%
# 394703  0.15                         0.03%                        99.97%
# 332814  0.14                         0.03%                        99.95%
# 641619  0.15                         0.00%                        99.95%
# 383603  0.15                         0.00%                        99.98%
# 399610  0.14                         0.00%                       100.00%
# 392869  0.14                         0.00%                       100.00%
# 571543  0.14                         0.00%                       100.00%
# 2011    0.14                         0.00%                        99.98%
# 438295  0.14                         0.00%                       100.00%
# 240176  0.14                         0.00%                       100.00%
# 255799  0.14                         0.00%                       100.00%
# 491807  0.14                         0.00%                       100.00%
# 445412  0.14                         0.00%                       100.00%
# 545608  0.70                         0.00%                       100.00%
# 400496  1.07                         0.00%                        66.67%
# 662791  0.37                         0.00%                       100.00%
# 526067  0.41                         0.00%                       100.00%
# 371789  0.63                         0.00%                       100.00%
# 303224  0.53                         0.00%                       100.00%
# 388489  0.84                         0.00%                       100.00%
# 471875  0.47                         0.00%                       100.00%
# 480810  0.58                         0.00%                       100.00%
# 338726  0.81                         0.00%                       100.00%
# 547527  0.67                         0.00%                       100.00%
# 350641  0.72                         0.00%                       100.00%
# 126451  0.36                         0.00%                       100.00%
# 430226  0.64                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 602106  0.67                         0.00%                       100.00%
# 527066  0.78                         0.00%                       100.00%
# 274947  4.18                        43.04%                        46.84%
# 349579  4.72                        53.85%                        44.87%
# 622270  4.49                        48.28%                        50.00%
# 592019  4.95                        53.42%                        41.10%
# 650866  4.76                        52.33%                        38.37%
# 509058  4.38                        48.72%                        46.15%
# 522980  4.60                        53.03%                        37.88%
# 175509  4.29                        46.74%                        43.48%
# 8468    4.75                        52.63%                        44.74%
# 81227   4.17                        48.78%                        47.56%
# 657999  3.89                        41.57%                        53.93%
# 98703   4.53                        51.28%                        43.59%
# 491276  3.89                        43.30%                        50.52%
# 463314  4.69                        48.28%                        46.55%
# 548273  4.75                        52.94%                        43.14%
# 274934  4.84                        55.00%                        40.00%
# 623825  4.53                        51.47%                        39.71%
# 667601  4.06                        46.75%                        50.65%
# 61472   4.53                        55.41%                        44.59%
# 530855  3.99                        41.30%                        45.65%
# 369901  4.63                        57.41%                        37.04%
# 327349  4.44                        46.05%                        38.16%
# 396995  3.95                        47.44%                        51.28%
# 119085  4.32                        42.67%                        46.67%
# 207632  4.12                        45.59%                        45.59%
# 392991  4.85                        53.52%                        33.80%
# 442085  4.07                        46.97%                        48.48%
# 317758  5.52                        61.40%                        26.32%
#
#                                       Timer Subtimer Name  Number of Records  \
# 673451                         DMSM_GETMEDIACONTENT (N/A)                  1
# 261648                         DMSM_GETMEDIACONTENT (N/A)                  1
# 48954                          DMSM_GETMEDIACONTENT (N/A)                  1
# 394703                         DMSM_GETMEDIACONTENT (N/A)                  1
# 332814                         DMSM_GETMEDIACONTENT (N/A)                  1
# 641619                         DMSM_GETMEDIACONTENT (N/A)                  1
# 383603                         DMSM_GETMEDIACONTENT (N/A)                  1
# 399610                         DMSM_GETMEDIACONTENT (N/A)                  1
# 392869                         DMSM_GETMEDIACONTENT (N/A)                  1
# 571543                         DMSM_GETMEDIACONTENT (N/A)                  1
# 2011                           DMSM_GETMEDIACONTENT (N/A)                  1
# 438295                         DMSM_GETMEDIACONTENT (N/A)                  1
# 240176                         DMSM_GETMEDIACONTENT (N/A)                  1
# 255799                         DMSM_GETMEDIACONTENT (N/A)                  1
# 491807                         DMSM_GETMEDIACONTENT (N/A)                  1
# 445412                         DMSM_GETMEDIACONTENT (N/A)                  1
# 545608                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 400496                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 662791                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 526067                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 371789                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 303224                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 388489                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 471875                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 480810                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 338726                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 547527                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 350641                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 126451                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 430226                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# ...                                                   ...                ...
# 602106  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 527066  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 274947        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 349579        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 622270        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 592019        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 650866        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 509058        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 522980        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 175509        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 8468          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 81227         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 657999        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 98703         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 491276        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 463314        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 548273        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 274934        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 623825        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 667601        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 61472         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 530855        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 369901        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 327349        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 396995        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 119085        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 207632        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 392991        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 442085        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 317758        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 673451       POWERCHART 2018-09-12  0.070212          NaN
# 261648       POWERCHART 2018-09-13  0.089830          NaN
# 48954        POWERCHART 2018-09-14  0.089884          NaN
# 394703       POWERCHART 2018-09-17  0.156930          NaN
# 332814       POWERCHART 2018-09-18  0.233025          NaN
# 641619       POWERCHART 2018-09-27  0.101519          NaN
# 383603       POWERCHART 2018-09-28  0.100805          NaN
# 399610       POWERCHART 2018-10-02  0.070028          NaN
# 392869       POWERCHART 2018-10-03  0.062836          NaN
# 571543       POWERCHART 2018-10-09  0.069858          NaN
# 2011         POWERCHART 2018-10-15  0.083543          NaN
# 438295       POWERCHART 2018-10-16  0.075542          NaN
# 240176       POWERCHART 2018-10-18  0.062809          NaN
# 255799       POWERCHART 2018-10-23  0.068284          NaN
# 491807       POWERCHART 2018-10-24  0.069277          NaN
# 445412       POWERCHART 2018-10-29  0.078902          NaN
# 545608       POWERCHART 2018-09-17  0.298399          NaN
# 400496       POWERCHART 2018-09-18  1.308079          NaN
# 662791       POWERCHART 2018-09-20  0.413173          NaN
# 526067       POWERCHART 2018-09-21  0.165633          NaN
# 371789       POWERCHART 2018-09-24  0.282050          NaN
# 303224       POWERCHART 2018-09-25  0.368174          NaN
# 388489       POWERCHART 2018-09-26  0.094260          NaN
# 471875       POWERCHART 2018-09-27  0.409663          NaN
# 480810       POWERCHART 2018-09-28  0.178580          NaN
# 338726       POWERCHART 2018-10-01       NaN          NaN
# 547527       POWERCHART 2018-10-03  0.265165          NaN
# 350641       POWERCHART 2018-10-04  0.420021          NaN
# 126451       POWERCHART 2018-10-05  0.238620          NaN
# 430226       POWERCHART 2018-10-09  0.066468          NaN
# ...                 ...        ...       ...          ...
# 602106       POWERCHART 2018-10-25  0.037541          NaN
# 527066       POWERCHART 2018-10-26  0.238071          NaN
# 274947       POWERCHART 2018-09-14  3.909331          NaN
# 349579       POWERCHART 2018-09-17  4.164425          NaN
# 622270       POWERCHART 2018-09-18  4.305383          NaN
# 592019       POWERCHART 2018-09-19  4.199626          NaN
# 650866       POWERCHART 2018-09-20  3.840833          NaN
# 509058       POWERCHART 2018-09-21  4.157388          NaN
# 522980       POWERCHART 2018-09-24  3.544378          NaN
# 175509       POWERCHART 2018-09-25  3.780417          NaN
# 8468         POWERCHART 2018-09-26  4.128597          NaN
# 81227        POWERCHART 2018-09-27  3.785608          NaN
# 657999       POWERCHART 2018-09-28  3.793539          NaN
# 98703        POWERCHART 2018-10-01  3.758748          NaN
# 491276       POWERCHART 2018-10-02  3.640664          NaN
# 463314       POWERCHART 2018-10-04  5.265499          NaN
# 548273       POWERCHART 2018-10-05  4.127223          NaN
# 274934       POWERCHART 2018-10-08  3.735527          NaN
# 623825       POWERCHART 2018-10-09  3.649069          NaN
# 667601       POWERCHART 2018-10-10  3.760897          NaN
# 61472        POWERCHART 2018-10-11  3.818554          NaN
# 530855       POWERCHART 2018-10-12  3.615590          NaN
# 369901       POWERCHART 2018-10-15  3.448499          NaN
# 327349       POWERCHART 2018-10-16  3.525056          NaN
# 396995       POWERCHART 2018-10-17  3.615882          NaN
# 119085       POWERCHART 2018-10-18  4.040581          NaN
# 207632       POWERCHART 2018-10-19  3.681307          NaN
# 392991       POWERCHART 2018-10-22  3.616620          NaN
# 442085       POWERCHART 2018-10-23  3.770722          NaN
# 317758       POWERCHART 2018-10-24  3.570586          NaN
#
#                                               timername   ...     t-4   t-5  \
# 673451                             DMSM_GETMEDIACONTENT   ...    0.14  0.15
# 261648                             DMSM_GETMEDIACONTENT   ...    0.15  0.14
# 48954                              DMSM_GETMEDIACONTENT   ...    0.15  0.15
# 394703                             DMSM_GETMEDIACONTENT   ...    0.15  0.15
# 332814                             DMSM_GETMEDIACONTENT   ...    0.15  0.15
# 641619                             DMSM_GETMEDIACONTENT   ...    0.16  0.15
# 383603                             DMSM_GETMEDIACONTENT   ...    0.15  0.16
# 399610                             DMSM_GETMEDIACONTENT   ...    0.15  0.15
# 392869                             DMSM_GETMEDIACONTENT   ...    0.14  0.15
# 571543                             DMSM_GETMEDIACONTENT   ...    0.15  0.14
# 2011                               DMSM_GETMEDIACONTENT   ...    0.15  0.15
# 438295                             DMSM_GETMEDIACONTENT   ...    0.14  0.15
# 240176                             DMSM_GETMEDIACONTENT   ...    0.14  0.14
# 255799                             DMSM_GETMEDIACONTENT   ...    0.14  0.14
# 491807                             DMSM_GETMEDIACONTENT   ...    0.14  0.14
# 445412                             DMSM_GETMEDIACONTENT   ...    0.14  0.14
# 545608                          DMSM_GETMEDIAOBJECTLIST   ...    0.78  0.90
# 400496                          DMSM_GETMEDIAOBJECTLIST   ...    0.91  0.78
# 662791                          DMSM_GETMEDIAOBJECTLIST   ...    0.75  0.91
# 526067                          DMSM_GETMEDIAOBJECTLIST   ...    0.89  0.75
# 371789                          DMSM_GETMEDIAOBJECTLIST   ...    0.70  0.89
# 303224                          DMSM_GETMEDIAOBJECTLIST   ...    1.07  0.70
# 388489                          DMSM_GETMEDIAOBJECTLIST   ...    0.37  1.07
# 471875                          DMSM_GETMEDIAOBJECTLIST   ...    0.41  0.37
# 480810                          DMSM_GETMEDIAOBJECTLIST   ...    0.63  0.41
# 338726                          DMSM_GETMEDIAOBJECTLIST   ...    0.53  0.63
# 547527                          DMSM_GETMEDIAOBJECTLIST   ...    0.84  0.53
# 350641                          DMSM_GETMEDIAOBJECTLIST   ...    0.47  0.84
# 126451                          DMSM_GETMEDIAOBJECTLIST   ...    0.58  0.47
# 430226                          DMSM_GETMEDIAOBJECTLIST   ...    0.81  0.58
# ...                                                 ...   ...     ...   ...
# 602106  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME   ...    0.79  0.88
# 527066  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME   ...    0.90  0.79
# 274947            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    5.16  4.04
# 349579            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    5.00  5.16
# 622270            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.12  5.00
# 592019            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.96  4.12
# 650866            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.18  4.96
# 509058            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.72  4.18
# 522980            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.49  4.72
# 175509            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.95  4.49
# 8468              USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.76  4.95
# 81227             USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.38  4.76
# 657999            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.60  4.38
# 98703             USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.29  4.60
# 491276            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.75  4.29
# 463314            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.17  4.75
# 548273            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    3.89  4.17
# 274934            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.53  3.89
# 623825            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    3.89  4.53
# 667601            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.69  3.89
# 61472             USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.75  4.69
# 530855            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.84  4.75
# 369901            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.53  4.84
# 327349            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.06  4.53
# 396995            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.53  4.06
# 119085            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    3.99  4.53
# 207632            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.63  3.99
# 392991            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.44  4.63
# 442085            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    3.95  4.44
# 317758            USR:WH-DELIVERY RECORD-ENSURE RESULTS   ...    4.32  3.95
#
#          t-6   t-7   t-8  LCL_30  UCL_30    var_30  cusum  signal
# 673451  0.14  0.15  0.15     NaN     NaN       NaN   0.00    None
# 261648  0.15  0.14  0.15     NaN     NaN       NaN   0.00    None
# 48954   0.14  0.15  0.14     NaN     NaN       NaN   0.01    None
# 394703  0.15  0.14  0.15     NaN     NaN       NaN   0.01    None
# 332814  0.15  0.15  0.14     NaN     NaN       NaN   0.00    None
# 641619  0.15  0.15  0.15     NaN     NaN       NaN   0.01    None
# 383603  0.15  0.15  0.15     NaN     NaN       NaN   0.01    None
# 399610  0.16  0.15  0.15     NaN     NaN       NaN   0.00    None
# 392869  0.15  0.16  0.15     NaN     NaN       NaN   0.01     Red
# 571543  0.15  0.15  0.16     NaN     NaN       NaN   0.00     Red
# 2011    0.14  0.15  0.15     NaN     NaN       NaN   0.00     Red
# 438295  0.15  0.14  0.15     NaN     NaN       NaN   0.00    None
# 240176  0.15  0.15  0.14     NaN     NaN       NaN   0.00    None
# 255799  0.14  0.15  0.15     NaN     NaN       NaN   0.00     Red
# 491807  0.14  0.14  0.15     NaN     NaN       NaN   0.00    None
# 445412  0.14  0.14  0.14     NaN     NaN       NaN   0.00    None
# 545608  0.70  1.14  0.67     NaN     NaN       NaN   0.14    None
# 400496  0.90  0.70  1.14     NaN     NaN       NaN   0.19    None
# 662791  0.78  0.90  0.70     NaN     NaN       NaN   0.37    None
# 526067  0.91  0.78  0.90     NaN     NaN       NaN   0.70     Red
# 371789  0.75  0.91  0.78     NaN     NaN       NaN   0.04     Red
# 303224  0.89  0.75  0.91     NaN     NaN       NaN   0.22    None
# 388489  0.70  0.89  0.75     NaN     NaN       NaN   0.10    None
# 471875  1.07  0.70  0.89     NaN     NaN       NaN   0.31    None
# 480810  0.37  1.07  0.70     NaN     NaN       NaN   0.37    None
# 338726  0.41  0.37  1.07     NaN     NaN       NaN   0.11    None
# 547527  0.63  0.41  0.37     NaN     NaN       NaN   0.23    None
# 350641  0.53  0.63  0.41     NaN     NaN       NaN   0.14    None
# 126451  0.84  0.53  0.63     NaN     NaN       NaN   0.05    None
# 430226  0.47  0.84  0.53    0.14    0.63  0.078031   0.36    None
# ...      ...   ...   ...     ...     ...       ...    ...     ...
# 602106  0.82  0.72  0.75    0.80    0.89  0.012973   0.07    None
# 527066  0.88  0.82  0.72    0.79    0.88  0.011360   0.26    None
# 274947  4.15  4.94  5.78    0.79    0.88  0.380256   0.84     Red
# 349579  4.04  4.15  4.94    0.79    0.88  0.854860   0.78    None
# 622270  5.16  4.04  4.15    0.79    0.89  1.241556   0.54    None
# 592019  5.00  5.16  4.04    0.79    0.89  1.706412   0.23    None
# 650866  4.12  5.00  5.16    0.79    0.90  2.087688   0.46     Red
# 509058  4.96  4.12  5.00    0.79    0.90  2.354754   0.19    None
# 522980  4.18  4.96  4.12    0.79    0.93  2.634038   0.38    None
# 175509  4.72  4.18  4.96    0.79    4.18  2.826246   0.22    None
# 8468    4.49  4.72  4.18    0.79    4.29  3.077470   0.31    None
# 81227   4.95  4.49  4.72    0.79    4.29  3.192950   0.46    None
# 657999  4.76  4.95  4.49    0.79    4.29  3.251177   0.58    None
# 98703   4.38  4.76  4.95    0.79    4.38  3.366464   0.28     Red
# 491276  4.60  4.38  4.76    0.80    4.38  3.366249   0.64    None
# 463314  4.29  4.60  4.38    0.80    4.49  3.444787   0.64    None
# 548273  4.75  4.29  4.60    0.82    4.53  3.498226   0.80    None
# 274934  4.17  4.75  4.29    0.82    4.60  3.540314   0.06    None
# 623825  3.89  4.17  4.75    0.82    4.60  3.501420   0.09    None
# 667601  4.53  3.89  4.17    0.86    4.60  3.380626   0.31    None
# 61472   3.89  4.53  3.89    0.88    4.60  3.276229   0.47    None
# 530855  4.69  3.89  4.53    0.88    4.60  3.117024   0.47    None
# 369901  4.75  4.69  3.89    0.90    4.63  2.953529   0.54    None
# 327349  4.84  4.75  4.69    0.93    4.63  2.736059   0.64     Red
# 396995  4.53  4.84  4.75    3.89    4.63  2.486342   0.19     Red
# 119085  4.06  4.53  4.84    3.89    4.63  2.236922   0.49     Red
# 207632  4.53  4.06  4.53    3.95    4.63  1.936265   0.37    None
# 392991  3.99  4.53  4.06    3.99    4.69  1.660991   0.20    None
# 442085  4.63  3.99  4.53    4.06    4.69  1.320104   0.73    None
# 317758  4.44  4.63  3.99    4.07    4.72  1.032095   0.78    None
#
# [64554 rows x 29 columns]

# %% [markdown]
# ### Investigate the data on a weekly basis
# Counts
# Sums
# Averages
# Variance

# %% [markdown]
# ### Write out to csv:

# %%
atrt_df_PC.to_csv('C:\\Users\\khickman1\\Desktop\\PCMavg30.csv', sep=',')

# %% [markdown]
# ### Stuff I learned:
#
# - Moving average example
# - Subsetting
# - Date and column filtering
# - Index by both date and by timer/subtimer using pandas 'set index'
# - Indexing
# - Sorting
# - Get unique values
# - grouping
# - filtering outliers (clipping, trimming, winsorizing)
# - moving data
#
# ```
# open_chart = atrt_df['Timer Subtimer Name' == "USR:PWR-OPEN CHART (DISCERNRPT/DISCERNPCTAB.DLL)"]
# open_chart = atrt_df[atrt_df['Timer Subtimer Name'] == 'USR:PWR-OPEN CHART (DISCERNRPT/DISCERNPCTAB.DLL)']
# open_chart = open_chart[open_chart['application_name']== 'POWERCHART']
# open_chart_post = open_chart[(open_chart['dt'] > '2018-07-01') & (open_chart['dt'] < '2018-09-30')]
# open_chart = open_chart.set_index(['Timer Subtimer Name', 'dt'])
# open_chart = open_chart.sort_index(axis=0)
# open_chart['moving_avg'] = open_chart['ATRT'].rolling(30).mean()
# atrt_df['dt'] = pd.to_datetime(atrt_df['dt'].dt.date)
# atrt_high_trans = atrt_df[atrt_df['transaction_cnt'] > 1000]
# atrt_high_trans.sort_values(by=['transaction_cnt'], ascending=False)
# len(atrt_high_trans)
# grp_high_trans = atrt_high_trans.groupby(["Timer Subtimer Name", "dt"])
# grp_high_trans.head()
# open_chart_post.groupby('Timer Subtimer Name').nunique()
# len(open_chart_post['Timer Subtimer Name'].unique())
# len(open_chart_post)
# open_chart_slim = open_chart_post[['ATRT', 'dt']]
# open_chart_slim.set_index('dt')
# open_chart_slim.sort_values('dt')
#
# Stuff that didn't work
# #atrt_df_PC = atrt_df_PC[['Timer Subtimer Name', 'dt', 'ATRT', 'application_name']]
# #atrt_df_PC['mavg30'] = atrt_df_PC['ATRT'].rolling(30).mean()
# #PC = atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])
# #atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name', 'dt'])
# #PC = atrt_df_PC
# #PC.head()
# #atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name'])
# #atrt_df_PC = atrt_df_PC.sort_index(axis=0)
# #atrt_df_PC = atrt_df_PC.groupby(['Timer Subtimer Name'])
# #atrt_df_PC = atrt_df_PC.sort(['Timer Subtimer Name', 'dt']).groupby('Timer Subtimer Name')
# #atrt_df_PC['mavg30'] = atrt_df_PC['ATRT'].rolling(30).mean()
# #atrt_df_PC[0:100]```

# %% [markdown]
# Getting csv from website example
# ```
# import csv
# import urllib3
# import requests
#
# #This URL will be the URL that your login form points to with the "action" tag.
# post_login_url = 'https://cernercare.com/accounts/login?returnTo=https%3A%2F%2Flightson.cerner.com%2Fsocial-auth%2Fcomplete%2Fprofessional%2F%3Fjanrain_nonce%3D2018-10-23T15%253A00%253A41ZYe3mOd'
#
# #This URL is the page you actually want to pull down with requests.
# request_url = 'https://lightson.cerner.com/clients/CHP_IN/domains/P1558/kpi/response-time/worst-timers.csv?dt=2018-10-22'
# #request_url = 'https://lightson.cerner.com/api/metrics/trend.csv?category_name=Performance&metrics%5B%5D=RT_2SEC&cdr_ids=95370&data_type=ENVIRONMENT&date_type=DAILY&days_of_week=1%2C2%2C3%2C4%2C5%2C6%2C7&doc_cuid=LONfa31c997c3d543768036e2941&end_date=2018-10-22&physician_rollup_flag=2&start_date=2018-07-25'
#
# payload = {
#     'username': 'khickman1',
#     'pass': '<password>'
# }
#
# with requests.Session() as session:
#     post = session.post(post_login_url, data=payload)
#     r = session.get(request_url)
#     decoded_content = r.content.decode('utf-8')
#     cr = csv.reader(decoded_content.splitlines(), delimiter=',')
#     my_list = list(cr)
#     for row in my_list:
#         print(row)
#
# for row in cr:
#     with open("daily.csv", "wb") as f:
#         writer = csv.writer(f)
#         writer.writerows(row)
# ```
