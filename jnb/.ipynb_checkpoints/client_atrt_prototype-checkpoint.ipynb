# %% [markdown]
# # Weekly Core Metric Analysis
#
# This notebook provides pre-processing, analysis, and visualization on weekly ATRT data provided by Cerner (Armand Kok) in a .csv dataset that includes daily (aggregated) timer data, transaction counts, etc... for a 90-day lookback period.
#
# 10/26:
# - **Business questions**:
#     - Which timers are negatively affecting ATRT?
#     - What is the makeup of ATRT for a given period, and how has that changed over the previous periods?
#     - When did a shift begin for a particular timer?
#     - What are the smoothed trends for our core metrics overall?
#     - What is our ATRT for relative dates (month to date, past 30/60/90, etc).
#
# **To-do**
# - [ ] consider moving to 120 day lookback period for control charts.
# - [ ] Joining most recent week's data:
#     - MySQL/postgres database that will index based on timer, date, application.
#     - run import job on .csv every week (Friday/Monday) to update with current week's data.

# %%
# Import libraries/packages
import csv
import pandas as pd
import datetime
import numpy as np
import os
from datetime import datetime 
from pandas.tseries.offsets import BDay
from scipy import stats
#from scipy.stats.mstats import winsorize
#import statsmodels.api as sm
#import seaborn as sns
#import matplotlib.pyplot as plt

# %% [markdown]
# ### Import dataset and make sure it's working.
# **To-do**:
# - 10/25 automate dataset generation. Use case for hook into Vertica: Armand is currently manually giving this ds weekly.
# - 10/25 find best place to store to capture history

# %%
#client_atrt = pd.read_csv('Z:\IUH\khickman1\Datasets\client_atrt10.15.18.csv')
client_atrt = pd.read_csv('C:\\Users\\khickman1\\Desktop\\client_atrt11.6.18.csv')
#client_atrt = client_atrt[['dt', 'application_name', 'Timer Subtimer Name', 'ATRT']]
client_atrt.head()
len(client_atrt) #should be around 650-680k rows
# Out:
# 898554

# %% [markdown]
# ## Preprocessing
#
#  - Dates
#  - Filtering
#  - Outlier removal
#  - moving average calculation
#  - window calculation
#  - if/else statement based on window
#  - calculate UCL/LCL
#  - feature selection
#
# **To-Do**
#  - [ ] remove subtimer name?
#
# ### Date column transformation

# %%
atrt_df = pd.DataFrame(client_atrt)
atrt_df['dt'] = pd.to_datetime(atrt_df['dt'])
print(atrt_df['dt'][0:10])
atrt_df.head()
# check to make sure the 'dt' column is type:datetime64
# Out:
# 0   2018-10-16
# 1   2018-10-18
# 2   2018-10-25
# 3   2018-09-22
# 4   2018-08-28
# 5   2018-11-02
# 6   2018-10-29
# 7   2018-09-04
# 8   2018-07-10
# 9   2018-08-17
# Name: dt, dtype: datetime64[ns]
#                         Component RecommendMPG?  ATRT  \
# 0          SR:MPG.DOCUMENTS.O2 -          Other  0.34
# 1        SR:MPG.CUSTOM_COMP.O1 -          Other  0.12
# 2  SR:MPG.CONSOLIDATED_HISTORY -          Other  1.05
# 3                             NaN         Other  0.49
# 4                             NaN         Other  0.19
#
#   % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 0                         0.00%                        99.25%
# 1                         0.00%                       100.00%
# 2                         0.00%                       100.00%
# 3                         0.00%                        99.79%
# 4                         0.00%                       100.00%
#
#                                  Timer Subtimer Name  Number of Records  \
# 0  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 1  USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT (VB_WO...                  1
# 2  USR:MPG.CONSOLIDATED_HISTORY - CHRONIC PROBLEM...                  1
# 3  USR: PDOC NAVIGATOR BAND CLICK (INITIAL NEWBOR...                  1
# 4  USR:SRG SNDOCDISP LOADING SEGMENT (TH MAIN OR ...                  1
#
#   application_name         dt      strt                  subtimername  \
# 0       POWERCHART 2018-10-16  0.202784   VB_WORKFLOWIPPEDSCARDIOLOGY
# 1       POWERCHART 2018-10-18  0.035197   VB_WORKFLOWAMBPEDSPULMONARY
# 2       POWERCHART 2018-10-25       NaN  VB_WORKFLOWAMBOTOLARYNGOLOGY
# 3       POWERCHART 2018-09-22  0.180901          INITIAL NEWBORN EXAM
# 4   SNSURGINET.EXE 2018-08-28  0.040112  TH MAIN OR GENERAL CASE DATA
#
#                                            timername  total_elapsed  \
# 0              USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT      44.998676
# 1            USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT       3.484803
# 2  USR:MPG.CONSOLIDATED_HISTORY - CHRONIC PROBLEM...       1.050656
# 3                     USR: PDOC NAVIGATOR BAND CLICK     235.320000
# 4                  USR:SRG SNDOCDISP LOADING SEGMENT       1.112261
#
#    transAbove5  transUnder2  transaction_cnt
# 0            0          132              133
# 1            0           28               28
# 2            0            1                1
# 3            0          484              485
# 4            0            6                6

# %% [markdown]
# ### Remove non-working days.
#
# Currently only removing weekends.
#
# **To-do**
# - remove federal/bank holidays?  E.g. sept 3 was labor day.
# - clean up is-bday column via subsetting or boolean

# %%
isBusinessDay = BDay().onOffset
match_series = atrt_df['dt'].map(isBusinessDay)
atrt_df['isBDay'] = atrt_df['dt'][match_series]
atrt_df
# Out:
#                              Component RecommendMPG?   ATRT  \
# 0               SR:MPG.DOCUMENTS.O2 -          Other   0.34
# 1             SR:MPG.CUSTOM_COMP.O1 -          Other   0.12
# 2       SR:MPG.CONSOLIDATED_HISTORY -          Other   1.05
# 3                                  NaN         Other   0.49
# 4                                  NaN         Other   0.19
# 5                                  NaN         Other   0.16
# 6                                  NaN         Other   0.11
# 7                                  NaN         Other   0.06
# 8                                  NaN         Other   0.08
# 9               SR:MPG.HOME_MEDS.O2 -          Other   2.10
# 10                                 NaN         Other   0.57
# 11                   SR:MPG.LABS.O1 -          Other   1.21
# 12       SR:MPG.DOCUMENTATION_PE.O1 -          Other   0.26
# 13                                 NaN         Other   1.81
# 14                                 NaN         Other   0.20
# 15                                 NaN         Other  35.42
# 16                                 NaN         Other   0.15
# 17                                 NaN         Other   0.69
# 18            SR:MPG.CONSOL_PROB.O1 -          Other   0.52
# 19                                 NaN         Other   0.00
# 20                     SR:MPG.IO.O2 -          Other   0.67
# 21              SR:MPG.DOCUMENTS.O2 -          Other   0.55
# 22              SR:MPG.DOCUMENTS.O1 -          Other   0.46
# 23                            USR:RWL-         Other   0.20
# 24                                 NaN         Other   0.06
# 25                                 NaN         Other   0.88
# 26                   SR:MPG.MEDS.O2 -          Other   0.71
# 27       SR:MPG.PATIENTEDUCATION.O2 -          Other   2.27
# 28                                 NaN         Other   0.06
# 29           SR:MPG.ORDERPROFILE.O1 -          Other   1.60
# ...                                ...           ...    ...
# 898524       SR:MPG.CONSOL_PROBS.O3 -          Other   2.12
# 898525                       USR: ICU-         Other   0.74
# 898526                             NaN         Other   0.97
# 898527                             NaN         Other   1.39
# 898528                             NaN         Other   0.68
# 898529    SR:MPG.CHIEF_COMPLAINT.O1 -          Other   0.28
# 898530             SR:MPG.VISITS.O1 -          Other   0.14
# 898531                       USR: ICU-         Other   0.59
# 898532  SR:MPG.DOCUMENTATION_ROS.O1 -          Other   0.23
# 898533                             NaN         Other   0.16
# 898534  SR:MPG.DOCUMENTATION_HPI.O1 -          Other   0.23
# 898535                             NaN         Other   0.23
# 898536                       USR: ICU-         Other   0.55
# 898537     SR:MPG.FAMILY_HISTORY.O1 -          Other   0.10
# 898538                             NaN         Other   0.92
# 898539                             NaN         Other   0.36
# 898540                             NaN         Other   0.83
# 898541                             NaN         Other   0.21
# 898542  SR:MPG.DOCUMENTATION_ROS.O1 -          Other   0.27
# 898543                             NaN         Other   0.41
# 898544  SR:MPG.DOCUMENTATION_HPI.O1 -          Other   0.30
# 898545             SR:MPG.ORDERS.O2 -          Other   0.24
# 898546                             NaN         Other   0.19
# 898547                             NaN         Other   0.25
# 898548                        USR:PWR-         Other   3.22
# 898549       SR:MPG.IMMUNIZATION.O1 -          Other   0.11
# 898550                             NaN         Other   0.59
# 898551  SR:MPG.DOCUMENTATION_ROS.O1 -          Other   0.20
# 898552                             NaN         Other   0.06
# 898553                             NaN         Other   0.30
#
#        % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 0                              0.00%                        99.25%
# 1                              0.00%                       100.00%
# 2                              0.00%                       100.00%
# 3                              0.00%                        99.79%
# 4                              0.00%                       100.00%
# 5                              0.00%                       100.00%
# 6                              0.00%                       100.00%
# 7                              0.00%                       100.00%
# 8                              0.00%                       100.00%
# 9                              4.26%                        68.09%
# 10                             0.00%                       100.00%
# 11                             0.00%                        90.00%
# 12                             0.00%                       100.00%
# 13                             1.96%                        70.32%
# 14                             0.00%                       100.00%
# 15                           100.00%                         0.00%
# 16                             0.00%                       100.00%
# 17                             0.00%                       100.00%
# 18                             0.00%                       100.00%
# 19                             0.00%                       100.00%
# 20                             0.00%                        94.74%
# 21                             0.49%                        97.20%
# 22                             0.00%                        88.89%
# 23                             0.75%                        99.25%
# 24                             0.00%                       100.00%
# 25                             0.00%                        94.52%
# 26                             0.26%                        95.21%
# 27                             0.00%                         0.00%
# 28                             0.00%                       100.00%
# 29                             0.00%                        75.56%
# ...                              ...                           ...
# 898524                         2.48%                        58.82%
# 898525                         0.00%                       100.00%
# 898526                         0.00%                        95.00%
# 898527                         0.00%                       100.00%
# 898528                         0.00%                       100.00%
# 898529                         0.00%                       100.00%
# 898530                         0.00%                       100.00%
# 898531                         0.00%                       100.00%
# 898532                         0.00%                       100.00%
# 898533                         0.00%                       100.00%
# 898534                         0.00%                       100.00%
# 898535                         0.00%                       100.00%
# 898536                         0.00%                       100.00%
# 898537                         0.00%                       100.00%
# 898538                         0.00%                       100.00%
# 898539                         0.17%                        99.33%
# 898540                         0.00%                       100.00%
# 898541                         0.00%                       100.00%
# 898542                         0.02%                        99.54%
# 898543                         0.00%                       100.00%
# 898544                         0.00%                       100.00%
# 898545                         0.00%                       100.00%
# 898546                         0.00%                       100.00%
# 898547                         0.00%                        99.80%
# 898548                         0.00%                        16.67%
# 898549                         0.00%                       100.00%
# 898550                         0.00%                       100.00%
# 898551                         0.00%                       100.00%
# 898552                         0.00%                       100.00%
# 898553                         0.00%                       100.00%
#
#                                       Timer Subtimer Name  Number of Records  \
# 0       USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 1       USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT (VB_WO...                  1
# 2       USR:MPG.CONSOLIDATED_HISTORY - CHRONIC PROBLEM...                  1
# 3       USR: PDOC NAVIGATOR BAND CLICK (INITIAL NEWBOR...                  1
# 4       USR:SRG SNDOCDISP LOADING SEGMENT (TH MAIN OR ...                  1
# 5       USR:SRG SNDOCDISP LOADING SEGMENT (RI CL SKIN ...                  1
# 6       USR:SRG SNDOCDISP LOADING SEGMENT (GL ENDO DEP...                  1
# 7          USR: PDOC NAVIGATOR DOC SET CLICK (POSTPARTUM)                  1
# 8       USR:SRG SNDOCDISP LOADING SEGMENT (UN PACU PHA...                  1
# 9       USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 10      USR:SRG SNDOCDISP SAVING SEGMENT (BMH CHARTABL...                  1
# 11      USR:MPG.LABS.O1 - LOAD COMPONENT (VB_EDSUMMARY...                  1
# 12      USR:MPG.DOCUMENTATION_PE.O1 - LOAD COMPONENT (...                  1
# 13               USR:CARECOMPASS.CHANGEPATIENTLISTS (N/A)                  1
# 14      USR:SRG SNDOCDISP LOADING SEGMENT (BMH CASE TI...                  1
# 15      USR:SRG SNDOCDISP SAVE ELECTRONIC SIGNATURE (N/A)                  1
# 16      USR:SRG SNDOCDISP LOADING SEGMENT (MH ENDO IMP...                  1
# 17      USR: PDOC NAVIGATOR BAND CLICK (WITHDRAWAL PRO...                  1
# 18      USR:MPG.CONSOL_PROB.O1 - LOAD COMPONENT (VB_QU...                  1
# 19                USR:ORM.ENHANCEDDETAILSTABCREATED (N/A)                  1
# 20      USR:MPG.IO.O2 - LOAD COMPONENT (VB_WORKFLOWIPP...                  1
# 21      USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 22      USR:MPG.DOCUMENTS.O1 - LOAD COMPONENT (VB_CMRE...                  1
# 23                               USR:RWL-COLUMNLOAD (N/A)                  1
# 24      USR:SRG SNDOCDISP LOADING SEGMENT (BLH ENDO EX...                  1
# 25      USR:SRG SNDOCDISP SAVING SEGMENT (BMH SURGICAL...                  1
# 26      USR:MPG.MEDS.O2 - LOAD COMPONENT (VB_WORKFLOWI...                  1
# 27      USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT (...                  1
# 28      USR:SRG SNDOCDISP LOADING SEGMENT (SSSC PACU P...                  1
# 29      USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT (VB_W...                  1
# ...                                                   ...                ...
# 898524  USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT (VB_W...                  1
# 898525  USR: ICU-OPENING-BAND (ADULT SS PHYSICAL ASSES...                  1
# 898526        USR:HIM.REQUESTMANAGEMENT.SAVEINVOICE (N/A)                  1
# 898527  USR:SRG SNDOCDISP SAVING SEGMENT (SM IMPLANT B...                  1
# 898528  USR:SRG SNDOCDISP SAVING SEGMENT (BOSC TOURNIQ...                  1
# 898529  USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT (V...                  1
# 898530  USR:MPG.VISITS.O1 - LOAD COMPONENT (VB_SUMMARY...                  1
# 898531    USR: ICU-OPENING-BAND (PEDS MS ADLS AND SAFETY)                  1
# 898532  USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT ...                  1
# 898533  USR:SRG SNDOCDISP LOADING SEGMENT (UN OB PACU ...                  1
# 898534  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 898535      USR:PCS.LOAD COMMENTS IN COMMENT VIEWER (N/A)                  1
# 898536  USR: ICU-OPENING-BAND (ADULT ICU INTAKE AND OU...                  1
# 898537  USR:MPG.FAMILY_HISTORY.O1 - LOAD COMPONENT (VB...                  1
# 898538  USR: PDOC NAVIGATOR BAND CLICK (ADULT SS MEAL ...                  1
# 898539  USR: PDOC NAVIGATOR BAND CLICK (DRAINS AND TUBES)                  1
# 898540  USR:SRG SNDOCDISP SAVING SEGMENT (WH OB PACU P...                  1
# 898541  USR:SRG SNDOCDISP LOADING SEGMENT (MHIEC CASE ...                  1
# 898542  USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT ...                  1
# 898543  USR:SRG SNDOCDISP LOADING SEGMENT (BOSC PAIN M...                  1
# 898544  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 898545  USR:MPG.ORDERS.O2 - LOAD COMPONENT (VB_WORKFLO...                  1
# 898546  USR:SRG SNDOCDISP SAVING SEGMENT (BMH ENDO SKI...                  1
# 898547                            USR:MICLOGIN.SAVE (N/A)                  1
# 898548  USR:PWR-CREATE VIEW (INVITATIONS/PVINVITATION....                  1
# 898549  USR:MPG.IMMUNIZATION.O1 - LOAD COMPONENT (VB_E...                  1
# 898550  USR:SRG SNDOCDISP SAVING SEGMENT (SASC HEMOSTA...                  1
# 898551  USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT ...                  1
# 898552         USR:RESULTENTRYBLDBNK.RETRIEVE CELLS (N/A)                  1
# 898553        USR:MPG.WORKLIST.PATIENT_DATA_MANAGER (N/A)                  1
#
#                 application_name         dt       strt  \
# 0                     POWERCHART 2018-10-16   0.202784
# 1                     POWERCHART 2018-10-18   0.035197
# 2                     POWERCHART 2018-10-25        NaN
# 3                     POWERCHART 2018-09-22   0.180901
# 4                 SNSURGINET.EXE 2018-08-28   0.040112
# 5                 SNSURGINET.EXE 2018-11-02   0.122711
# 6                 SNSURGINET.EXE 2018-10-29   0.033585
# 7                     POWERCHART 2018-09-04   0.062499
# 8                 POWERCHART.EXE 2018-07-10   0.067187
# 9                     POWERCHART 2018-08-17   1.653173
# 10                SNSURGINET.EXE 2018-10-16   0.356674
# 11                    POWERCHART 2018-10-31   0.610367
# 12                    POWERCHART 2018-07-25   0.175106
# 13                    POWERCHART 2018-10-02   1.055255
# 14                SNSURGINET.EXE 2018-11-06   0.187444
# 15                SNSURGINET.EXE 2018-11-03  40.318672
# 16                SNSURGINET.EXE 2018-10-24   0.104212
# 17                    SNSURGINET 2018-10-25        NaN
# 18                    POWERCHART 2018-10-23   0.097461
# 19                      FIRSTNET 2018-07-21   0.000165
# 20                    POWERCHART 2018-09-30   0.513538
# 21                    SNSURGINET 2018-09-20   0.574173
# 22                    POWERCHART 2018-09-15   0.614478
# 23                      FIRSTNET 2018-10-16   2.250849
# 24                SNSURGINET.EXE 2018-08-22   0.034168
# 25                SNSURGINET.EXE 2018-08-31   0.664015
# 26                    POWERCHART 2018-10-06   0.861090
# 27                    POWERCHART 2018-09-30   0.049106
# 28                SNSURGINET.EXE 2018-07-19   0.027203
# 29                    POWERCHART 2018-08-11   0.844688
# ...                          ...        ...        ...
# 898524                POWERCHART 2018-08-28   1.078800
# 898525                  FIRSTNET 2018-08-02   0.076033
# 898526                 ACCESSHIM 2018-09-17   0.656829
# 898527            SNSURGINET.EXE 2018-10-16   0.428977
# 898528            SNSURGINET.EXE 2018-09-18   0.274378
# 898529                SNSURGINET 2018-10-29   0.070594
# 898530                POWERCHART 2018-09-21   0.085401
# 898531                  FIRSTNET 2018-10-08        NaN
# 898532                POWERCHART 2018-10-20   0.083847
# 898533            POWERCHART.EXE 2018-10-18   0.128227
# 898534                POWERCHART 2018-10-29        NaN
# 898535  ACCESSIONRESULTENTRY.EXE 2018-09-30   0.048169
# 898536                SNSURGINET 2018-09-16   0.053674
# 898537                POWERCHART 2018-09-03   0.054981
# 898538                  FIRSTNET 2018-08-31        NaN
# 898539                SNSURGINET 2018-10-30   0.471612
# 898540            POWERCHART.EXE 2018-08-24        NaN
# 898541            SNSURGINET.EXE 2018-10-09   0.145389
# 898542                POWERCHART 2018-07-30   0.265650
# 898543            SNSURGINET.EXE 2018-10-31   0.067137
# 898544                POWERCHART 2018-09-24   0.205024
# 898545                POWERCHART 2018-11-01   0.087319
# 898546            SNSURGINET.EXE 2018-10-29   0.100032
# 898547         SPECIMENLOGIN.EXE 2018-08-21   0.353960
# 898548                POWERCHART 2018-09-21   1.593105
# 898549                  FIRSTNET 2018-08-02   0.024355
# 898550            SNSURGINET.EXE 2018-10-23   0.394408
# 898551                SNSURGINET 2018-10-15   0.030770
# 898552     RESULTENTRYBLDBNK.EXE 2018-08-06   0.029559
# 898553                POWERCHART 2018-08-11   0.322558
#
#                                 subtimername  \
# 0                VB_WORKFLOWIPPEDSCARDIOLOGY
# 1                VB_WORKFLOWAMBPEDSPULMONARY
# 2               VB_WORKFLOWAMBOTOLARYNGOLOGY
# 3                       INITIAL NEWBORN EXAM
# 4               TH MAIN OR GENERAL CASE DATA
# 5                            RI CL SKIN PREP
# 6                  GL ENDO DEPARTURE FROM OR
# 7                                 POSTPARTUM
# 8                  UN PACU PHASE 2 ATTENDEES
# 9             VB_WORKFLOWAMBCLINICALPHARMACI
# 10                  BMH CHARTABLE ACTIVITIES
# 11                  VB_EDSUMMARYVIEWPOINT001
# 12                    VB_WORKFLOWIPNEUROLOGY
# 13                                       NaN
# 14                            BMH CASE TIMES
# 15                                       NaN
# 16                    MH ENDO IMPLANT RECORD
# 17             WITHDRAWAL PROTOCOLS CIWA OWA
# 18                      VB_QUICKORDERSPEDSGI
# 19                                       NaN
# 20                VB_WORKFLOWIPPREGNANCYVIEW
# 21                     VB_WORKFLOWIPSTANDARD
# 22                         VB_CMREADMISSIONS
# 23                                       NaN
# 24                   BLH ENDO EXPLANT RECORD
# 25                    BMH SURGICAL PROCEDURE
# 26                 VB_WORKFLOWIPNURSEHANDOFF
# 27            VB_WORKFLOWAMBPEDSENDOCRINOLOG
# 28              SSSC PACU PHASE 2 CASE TIMES
# 29             VB_WORKFLOWIPPEDSCRITICALCARE
# ...                                      ...
# 898524               VB_WORKFLOWAMBNEUROLOGY
# 898525          ADULT SS PHYSICAL ASSESSMENT
# 898526                                   NaN
# 898527              SM IMPLANT BONE & TISSUE
# 898528                       BOSC TOURNIQUET
# 898529                 VB_WORKFLOWAMBSURGERY
# 898530                       VB_SUMMARYORTHO
# 898531               PEDS MS ADLS AND SAFETY
# 898532        VB_WORKFLOWIPMANAGENEONATOLOGY
# 898533              UN OB PACU PHASE 3 TIMES
# 898534         VB_WORKFLOWAMBSURGERYVASCULAR
# 898535                                   NaN
# 898536  ADULT ICU INTAKE AND OUTPUT REALTIME
# 898537                       VB_SUMMARYORTHO
# 898538           ADULT SS MEAL DOCUMENTATION
# 898539                      DRAINS AND TUBES
# 898540    WH OB PACU PHASE 1 CASE ATTENDANCE
# 898541                      MHIEC CASE TIMES
# 898542              VB_WORKFLOWIPHOSPITALIST
# 898543                        BOSC PAIN MGMT
# 898544        VB_WORKFLOWIPDEVELOPMENTALPEDS
# 898545           VB_WORKFLOWAMBADOLESCENTMED
# 898546                    BMH ENDO SKIN PREP
# 898547                                   NaN
# 898548          INVITATIONS/PVINVITATION.DLL
# 898549                 VB_EDSUMMARYVIEWPOINT
# 898550                       SASC HEMOSTASIS
# 898551              VB_WORKFLOWIPHOSPITALIST
# 898552                                   NaN
# 898553                                   NaN
#
#                                                 timername  total_elapsed  \
# 0                   USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT      44.998676
# 1                 USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT       3.484803
# 2       USR:MPG.CONSOLIDATED_HISTORY - CHRONIC PROBLEM...       1.050656
# 3                          USR: PDOC NAVIGATOR BAND CLICK     235.320000
# 4                       USR:SRG SNDOCDISP LOADING SEGMENT       1.112261
# 5                       USR:SRG SNDOCDISP LOADING SEGMENT       0.779940
# 6                       USR:SRG SNDOCDISP LOADING SEGMENT       6.600862
# 7                       USR: PDOC NAVIGATOR DOC SET CLICK      53.119000
# 8                       USR:SRG SNDOCDISP LOADING SEGMENT       0.842170
# 9                   USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT      98.820230
# 10                       USR:SRG SNDOCDISP SAVING SEGMENT      34.159176
# 11                       USR:MPG.LABS.O1 - LOAD COMPONENT      72.637658
# 12           USR:MPG.DOCUMENTATION_PE.O1 - LOAD COMPONENT      60.518765
# 13                     USR:CARECOMPASS.CHANGEPATIENTLISTS    4239.784000
# 14                      USR:SRG SNDOCDISP LOADING SEGMENT      22.898764
# 15            USR:SRG SNDOCDISP SAVE ELECTRONIC SIGNATURE      70.844173
# 16                      USR:SRG SNDOCDISP LOADING SEGMENT       1.640951
# 17                         USR: PDOC NAVIGATOR BAND CLICK       0.685361
# 18                USR:MPG.CONSOL_PROB.O1 - LOAD COMPONENT       4.646506
# 19                      USR:ORM.ENHANCEDDETAILSTABCREATED      14.343727
# 20                         USR:MPG.IO.O2 - LOAD COMPONENT      63.305825
# 21                  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT     336.377035
# 22                  USR:MPG.DOCUMENTS.O1 - LOAD COMPONENT       4.096902
# 23                                     USR:RWL-COLUMNLOAD      53.467103
# 24                      USR:SRG SNDOCDISP LOADING SEGMENT       0.241504
# 25                       USR:SRG SNDOCDISP SAVING SEGMENT      64.503988
# 26                       USR:MPG.MEDS.O2 - LOAD COMPONENT    1653.646696
# 27           USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT       6.797030
# 28                      USR:SRG SNDOCDISP LOADING SEGMENT       7.691551
# 29               USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT      72.014827
# ...                                                   ...            ...
# 898524           USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT     685.108111
# 898525                              USR: ICU-OPENING-BAND      19.211364
# 898526              USR:HIM.REQUESTMANAGEMENT.SAVEINVOICE      19.419986
# 898527                   USR:SRG SNDOCDISP SAVING SEGMENT       5.541372
# 898528                   USR:SRG SNDOCDISP SAVING SEGMENT       3.408586
# 898529        USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT       0.836618
# 898530                 USR:MPG.VISITS.O1 - LOAD COMPONENT      12.055367
# 898531                              USR: ICU-OPENING-BAND       0.593249
# 898532      USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT       6.352218
# 898533                  USR:SRG SNDOCDISP LOADING SEGMENT       0.310780
# 898534      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT       0.228579
# 898535            USR:PCS.LOAD COMMENTS IN COMMENT VIEWER       1.381494
# 898536                              USR: ICU-OPENING-BAND       1.660151
# 898537         USR:MPG.FAMILY_HISTORY.O1 - LOAD COMPONENT       7.334552
# 898538                     USR: PDOC NAVIGATOR BAND CLICK       0.924000
# 898539                     USR: PDOC NAVIGATOR BAND CLICK     217.531964
# 898540                   USR:SRG SNDOCDISP SAVING SEGMENT       0.826651
# 898541                  USR:SRG SNDOCDISP LOADING SEGMENT      14.876990
# 898542      USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT    1777.788823
# 898543                  USR:SRG SNDOCDISP LOADING SEGMENT       3.267780
# 898544      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      42.995467
# 898545                 USR:MPG.ORDERS.O2 - LOAD COMPONENT       0.484427
# 898546                   USR:SRG SNDOCDISP SAVING SEGMENT       2.905740
# 898547                                  USR:MICLOGIN.SAVE     379.366270
# 898548                                USR:PWR-CREATE VIEW      19.299810
# 898549           USR:MPG.IMMUNIZATION.O1 - LOAD COMPONENT       0.452694
# 898550                   USR:SRG SNDOCDISP SAVING SEGMENT       8.781866
# 898551      USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT       0.397277
# 898552               USR:RESULTENTRYBLDBNK.RETRIEVE CELLS       0.169168
# 898553              USR:MPG.WORKLIST.PATIENT_DATA_MANAGER      15.352905
#
#         transAbove5  transUnder2  transaction_cnt     isBDay
# 0                 0          132              133 2018-10-16
# 1                 0           28               28 2018-10-18
# 2                 0            1                1 2018-10-25
# 3                 0          484              485        NaT
# 4                 0            6                6 2018-08-28
# 5                 0            5                5 2018-11-02
# 6                 0           58               58 2018-10-29
# 7                 0          842              842 2018-09-04
# 8                 0           11               11 2018-07-10
# 9                 2           32               47 2018-08-17
# 10                0           60               60 2018-10-16
# 11                0           54               60 2018-10-31
# 12                0          229              229 2018-07-25
# 13               46         1651             2348 2018-10-02
# 14                0          117              117 2018-11-06
# 15                2            0                2        NaT
# 16                0           11               11 2018-10-24
# 17                0            1                1 2018-10-25
# 18                0            9                9 2018-10-23
# 19                0        20399            20399        NaT
# 20                0           90               95        NaT
# 21                3          591              608 2018-09-20
# 22                0            8                9        NaT
# 23                2          265              267 2018-10-16
# 24                0            4                4 2018-08-22
# 25                0           69               73 2018-08-31
# 26                6         2227             2339        NaT
# 27                0            0                3        NaT
# 28                0          139              139 2018-07-19
# 29                0           34               45        NaT
# ...             ...          ...              ...        ...
# 898524            8          190              323 2018-08-28
# 898525            0           26               26 2018-08-02
# 898526            0           19               20 2018-09-17
# 898527            0            4                4 2018-10-16
# 898528            0            5                5 2018-09-18
# 898529            0            3                3 2018-10-29
# 898530            0           84               84 2018-09-21
# 898531            0            1                1 2018-10-08
# 898532            0           28               28        NaT
# 898533            0            2                2 2018-10-18
# 898534            0            1                1 2018-10-29
# 898535            0            6                6        NaT
# 898536            0            3                3        NaT
# 898537            0           73               73 2018-09-03
# 898538            0            1                1 2018-08-31
# 898539            1          596              600 2018-10-30
# 898540            0            1                1 2018-08-24
# 898541            0           72               72 2018-10-09
# 898542            1         6558             6588 2018-07-30
# 898543            0            8                8 2018-10-31
# 898544            0          143              143 2018-09-24
# 898545            0            2                2 2018-11-01
# 898546            0           15               15 2018-10-29
# 898547            0         1531             1534 2018-08-21
# 898548            0            1                6 2018-09-21
# 898549            0            4                4 2018-08-02
# 898550            0           15               15 2018-10-23
# 898551            0            2                2 2018-10-15
# 898552            0            3                3 2018-08-06
# 898553            0           51               51        NaT
#
# [898554 rows x 17 columns]

# %% [markdown]
# ### Filter dataset by application - e.g. Powerchart, firstnet, surginet.
# (Actually apply the weekend/weekday filter here as well).
#
# **to-do**
# - [ ] are there differences between timers in the different applications?
# - [X]clean up the workflow to do one step at a time

# %%
atrt_df_PC = atrt_df[atrt_df['application_name']== 'POWERCHART']
atrt_df_PC = atrt_df_PC[atrt_df_PC.isBDay.notnull()]
atrt_df_PC
# Out:
#                                  Component RecommendMPG?  ATRT  \
# 0                   SR:MPG.DOCUMENTS.O2 -          Other  0.34
# 1                 SR:MPG.CUSTOM_COMP.O1 -          Other  0.12
# 2           SR:MPG.CONSOLIDATED_HISTORY -          Other  1.05
# 7                                      NaN         Other  0.06
# 9                   SR:MPG.HOME_MEDS.O2 -          Other  2.10
# 11                       SR:MPG.LABS.O1 -          Other  1.21
# 12           SR:MPG.DOCUMENTATION_PE.O1 -          Other  0.26
# 13                                     NaN         Other  1.81
# 18                SR:MPG.CONSOL_PROB.O1 -          Other  0.52
# 31                                     NaN         Other  0.44
# 32                                USR:PWR-         Other  2.50
# 36                 SR:MPG.LABORATORY.WF -          Other  0.34
# 37                                USR:PWR-         Other  1.58
# 38           SR:MPG.DOCUMENTATION_PE.O1 -          Other  0.38
# 39                SR:MPG.CONSOL_PROB.O1 -          Other  0.64
# 40                       SR:MPG.MEDS.O2 -          Other  1.48
# 41                  SR:MPG.PATHOLOGY.O2 -          Other  0.32
# 42                               USR: ICU-         Other  0.48
# 45                                     NaN         Other  0.03
# 50                                     NaN         Other  0.09
# 51                         SR:MPG.IO.O2 -          Other  1.28
# 67               SR:MPG.ORDERPROFILE.O1 -          Other  1.09
# 68                                USR:BSC-         Other  0.45
# 77                                     NaN         Other  0.27
# 80          SR:MPG.DOCUMENTATION_HPI.O1 -          Other  0.23
# 82          SR:MPG.CONSOLIDATED_HISTORY -          Other  0.05
# 83                                     NaN         Other  0.10
# 84            SR:MPG.CHIEF_COMPLAINT.O1 -          Other  0.59
# 85                 SR:MPG.VITALSIGNS.WF -          Other  0.76
# 86                                USR:PWR-         Other  0.39
# ...                                    ...           ...   ...
# 898461      SR:MPG.DOCUMENTATION_ROS.O1 -          Other  0.28
# 898463              SR:MPG.REMINDERS.O2 -          Other  0.40
# 898465            SR:MPG.DIAGNOSTICS.O2 -          Other  0.22
# 898467       SR:MPG.RCM.CLINICAL_REVIEW -          Other  0.30
# 898470                                 NaN         Other  0.10
# 898472      SR:MPG.DOCUMENTATION_HPI.O1 -          Other  0.21
# 898473                            USR:PWR-         Other  0.35
# 898476                            USR:ICU-         Other  0.08
# 898477                 SR:MPG.ORDERS.O2 -          Other  0.79
# 898478  SR:MPG.ACTIONS_SIT_AWARENESS.O1 -          Other  0.19
# 898480              SR:MPG.CARE_TEAM.O2 -          Other  0.50
# 898488        SR:MPG.CHIEF_COMPLAINT.O1 -          Other  0.36
# 898491        SR:MPG.CHIEF_COMPLAINT.O1 -          Other  0.52
# 898492      SR:MPG.CONSOLIDATED_HISTORY -          Other  0.09
# 898493           SR:MPG.ORDERPROFILE.O1 -          Other  0.81
# 898503                            USR:PWR-         Other  0.26
# 898504                                 NaN         Other  0.18
# 898505                                 NaN         Other  0.03
# 898510         SR:MPG.DISCHARGE_PLAN.O1 -          Other  0.01
# 898514              SR:MPG.DOCUMENTS.O2 -          Other  0.37
# 898519             SR:MPG.LABORATORY.WF -          Other  0.91
# 898523              SR:MPG.CARE_TEAM.O2 -          Other  0.30
# 898524           SR:MPG.CONSOL_PROBS.O3 -          Other  2.12
# 898530                 SR:MPG.VISITS.O1 -          Other  0.14
# 898534      SR:MPG.DOCUMENTATION_HPI.O1 -          Other  0.23
# 898537         SR:MPG.FAMILY_HISTORY.O1 -          Other  0.10
# 898542      SR:MPG.DOCUMENTATION_ROS.O1 -          Other  0.27
# 898544      SR:MPG.DOCUMENTATION_HPI.O1 -          Other  0.30
# 898545                 SR:MPG.ORDERS.O2 -          Other  0.24
# 898548                            USR:PWR-         Other  3.22
#
#        % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 0                              0.00%                        99.25%
# 1                              0.00%                       100.00%
# 2                              0.00%                       100.00%
# 7                              0.00%                       100.00%
# 9                              4.26%                        68.09%
# 11                             0.00%                        90.00%
# 12                             0.00%                       100.00%
# 13                             1.96%                        70.32%
# 18                             0.00%                       100.00%
# 31                             0.00%                       100.00%
# 32                             5.88%                        47.06%
# 36                             0.00%                       100.00%
# 37                             0.00%                        87.50%
# 38                             0.00%                        98.40%
# 39                             0.00%                       100.00%
# 40                            10.00%                        90.00%
# 41                             0.00%                        98.11%
# 42                             0.00%                       100.00%
# 45                             0.02%                        99.92%
# 50                             0.02%                        99.78%
# 51                             1.46%                        92.23%
# 67                             0.71%                        97.16%
# 68                             0.00%                       100.00%
# 77                             0.10%                        99.47%
# 80                             0.00%                       100.00%
# 82                             0.00%                       100.00%
# 83                             0.00%                       100.00%
# 84                             0.49%                        97.06%
# 85                             0.00%                       100.00%
# 86                             0.02%                        99.72%
# ...                              ...                           ...
# 898461                         0.00%                       100.00%
# 898463                         0.00%                       100.00%
# 898465                         0.00%                       100.00%
# 898467                         0.00%                       100.00%
# 898470                         0.00%                       100.00%
# 898472                         0.00%                       100.00%
# 898473                         0.00%                        99.82%
# 898476                         0.00%                       100.00%
# 898477                         0.00%                       100.00%
# 898478                         0.00%                        99.60%
# 898480                         0.00%                        93.33%
# 898488                         0.14%                        98.86%
# 898491                         0.09%                        97.28%
# 898492                         0.00%                       100.00%
# 898493                         0.88%                        95.61%
# 898503                         0.02%                        99.82%
# 898504                         0.00%                       100.00%
# 898505                         0.00%                       100.00%
# 898510                         0.00%                       100.00%
# 898514                         0.00%                       100.00%
# 898519                         0.55%                        93.21%
# 898523                         0.23%                        99.40%
# 898524                         2.48%                        58.82%
# 898530                         0.00%                       100.00%
# 898534                         0.00%                       100.00%
# 898537                         0.00%                       100.00%
# 898542                         0.02%                        99.54%
# 898544                         0.00%                       100.00%
# 898545                         0.00%                       100.00%
# 898548                         0.00%                        16.67%
#
#                                       Timer Subtimer Name  Number of Records  \
# 0       USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 1       USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT (VB_WO...                  1
# 2       USR:MPG.CONSOLIDATED_HISTORY - CHRONIC PROBLEM...                  1
# 7          USR: PDOC NAVIGATOR DOC SET CLICK (POSTPARTUM)                  1
# 9       USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 11      USR:MPG.LABS.O1 - LOAD COMPONENT (VB_EDSUMMARY...                  1
# 12      USR:MPG.DOCUMENTATION_PE.O1 - LOAD COMPONENT (...                  1
# 13               USR:CARECOMPASS.CHANGEPATIENTLISTS (N/A)                  1
# 18      USR:MPG.CONSOL_PROB.O1 - LOAD COMPONENT (VB_QU...                  1
# 31      USR: PDOC NAVIGATOR BAND CLICK (CLINICAL OPIAT...                  1
# 32                USR:PWR-OPEN CHART (PPRSUMM/PVDEMOGPPR)                  1
# 36      USR:MPG.LABORATORY.WF - LOAD COMPONENT (VB_WOR...                  1
# 37               USR:PWR-OPEN CHART (FAMILY/KIAFHXUI.DLL)                  1
# 38      USR:MPG.DOCUMENTATION_PE.O1 - LOAD COMPONENT (...                  1
# 39      USR:MPG.CONSOL_PROB.O1 - LOAD COMPONENT (VB_QU...                  1
# 40      USR:MPG.MEDS.O2 - LOAD COMPONENT (VB_WORKFLOWI...                  1
# 41      USR:MPG.PATHOLOGY.O2 - LOAD COMPONENT (VB_WORK...                  1
# 42      USR: ICU-OPENING-BAND (PSYCH RESTRAINTS AND SE...                  1
# 45              USR:ORM.GETTHERAPEUTICSUBSTITUTIONS (N/A)                  1
# 50                         USR: DOC INSERT AUTOTEXT (N/A)                  1
# 51      USR:MPG.IO.O2 - LOAD COMPONENT (VB_WORKFLOWIPM...                  1
# 67      USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT (VB_W...                  1
# 68              USR:BSC-DISPLAY MED CHARTING (POWERFORMS)                  1
# 77          USR:PWR.LOAD AND DISPLAY PATIENT LIST (RELTN)                  1
# 80      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 82      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 83      USR: PDOC NAVIGATOR DOC SET CLICK (PROCEDURAL ...                  1
# 84      USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT (V...                  1
# 85      USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 86                        USR:PWR-CREATE VIEW (PIP/PVPIP)                  1
# ...                                                   ...                ...
# 898461  USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT ...                  1
# 898463  USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 898465  USR:MPG.DIAGNOSTICS.O2 - LOAD COMPONENT (VB_WO...                  1
# 898467  USR:MPG.RCM.CLINICAL_REVIEW - ADD CLINICAL REV...                  1
# 898470  USR: PDOC NAVIGATOR DOC SET CLICK (RESPIRATORY...                  1
# 898472  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 898473            USR:PWR-CREATE VIEW (OBGYN/PVPHXUI.DLL)                  1
# 898476  USR:ICU-IVIEW-ADDING OR REMOVING SECTIONS AND ...                  1
# 898477  USR:MPG.ORDERS.O2 - LOAD COMPONENT (VB_WORKFLO...                  1
# 898478  USR:MPG.ACTIONS_SIT_AWARENESS.O1 - LOAD COMPON...                  1
# 898480  USR:MPG.CARE_TEAM.O2 - LOAD COMPONENT (VB_WORK...                  1
# 898488  USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT (V...                  1
# 898491  USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT (V...                  1
# 898492  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 898493  USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT (VB_W...                  1
# 898503        USR:PWR-CREATE VIEW (SPTASKLIST/PVTASKLIST)                  1
# 898504  USR: PDOC NAVIGATOR BAND CLICK (PROCEDURAL VIT...                  1
# 898505  USR: PDOC NAVIGATOR BAND CLICK (CM COMPREHENSI...                  1
# 898510  USR:MPG.DISCHARGE_PLAN.O1 - LOAD COMPONENT (VB...                  1
# 898514  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 898519  USR:MPG.LABORATORY.WF - LOAD COMPONENT (VB_WOR...                  1
# 898523  USR:MPG.CARE_TEAM.O2 - LOAD COMPONENT (VB_WORK...                  1
# 898524  USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT (VB_W...                  1
# 898530  USR:MPG.VISITS.O1 - LOAD COMPONENT (VB_SUMMARY...                  1
# 898534  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 898537  USR:MPG.FAMILY_HISTORY.O1 - LOAD COMPONENT (VB...                  1
# 898542  USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT ...                  1
# 898544  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 898545  USR:MPG.ORDERS.O2 - LOAD COMPONENT (VB_WORKFLO...                  1
# 898548  USR:PWR-CREATE VIEW (INVITATIONS/PVINVITATION....                  1
#
#        application_name         dt      strt  \
# 0            POWERCHART 2018-10-16  0.202784
# 1            POWERCHART 2018-10-18  0.035197
# 2            POWERCHART 2018-10-25       NaN
# 7            POWERCHART 2018-09-04  0.062499
# 9            POWERCHART 2018-08-17  1.653173
# 11           POWERCHART 2018-10-31  0.610367
# 12           POWERCHART 2018-07-25  0.175106
# 13           POWERCHART 2018-10-02  1.055255
# 18           POWERCHART 2018-10-23  0.097461
# 31           POWERCHART 2018-09-05  0.035360
# 32           POWERCHART 2018-09-21  1.484004
# 36           POWERCHART 2018-10-19       NaN
# 37           POWERCHART 2018-10-01  0.465325
# 38           POWERCHART 2018-10-25  0.415368
# 39           POWERCHART 2018-08-10  0.166138
# 40           POWERCHART 2018-09-06  2.546040
# 41           POWERCHART 2018-10-08  0.453679
# 42           POWERCHART 2018-07-20  0.009448
# 45           POWERCHART 2018-09-04  0.237902
# 50           POWERCHART 2018-10-03  0.212345
# 51           POWERCHART 2018-08-21  0.975837
# 67           POWERCHART 2018-09-18  4.444013
# 68           POWERCHART 2018-08-01  0.103174
# 77           POWERCHART 2018-07-26  0.379896
# 80           POWERCHART 2018-08-07  0.121350
# 82           POWERCHART 2018-09-05  0.019247
# 83           POWERCHART 2018-09-10  0.055077
# 84           POWERCHART 2018-10-11  1.273310
# 85           POWERCHART 2018-11-06  0.241588
# 86           POWERCHART 2018-07-16  0.343165
# ...                 ...        ...       ...
# 898461       POWERCHART 2018-08-30  0.191200
# 898463       POWERCHART 2018-09-17  0.181319
# 898465       POWERCHART 2018-08-01  0.032725
# 898467       POWERCHART 2018-07-09  0.139284
# 898470       POWERCHART 2018-09-11  0.145661
# 898472       POWERCHART 2018-08-02  0.057864
# 898473       POWERCHART 2018-09-24  0.221550
# 898476       POWERCHART 2018-08-15  0.036975
# 898477       POWERCHART 2018-09-21  0.728748
# 898478       POWERCHART 2018-08-24  0.260435
# 898480       POWERCHART 2018-09-14  0.476739
# 898488       POWERCHART 2018-07-27  0.414697
# 898491       POWERCHART 2018-11-05  1.080215
# 898492       POWERCHART 2018-11-02  0.019798
# 898493       POWERCHART 2018-09-28  0.559228
# 898503       POWERCHART 2018-08-09  0.293704
# 898504       POWERCHART 2018-08-28  0.242157
# 898505       POWERCHART 2018-08-13       NaN
# 898510       POWERCHART 2018-10-04  0.049494
# 898514       POWERCHART 2018-07-31  0.066728
# 898519       POWERCHART 2018-09-19  1.096769
# 898523       POWERCHART 2018-10-31  0.469694
# 898524       POWERCHART 2018-08-28  1.078800
# 898530       POWERCHART 2018-09-21  0.085401
# 898534       POWERCHART 2018-10-29       NaN
# 898537       POWERCHART 2018-09-03  0.054981
# 898542       POWERCHART 2018-07-30  0.265650
# 898544       POWERCHART 2018-09-24  0.205024
# 898545       POWERCHART 2018-11-01  0.087319
# 898548       POWERCHART 2018-09-21  1.593105
#
#                               subtimername  \
# 0              VB_WORKFLOWIPPEDSCARDIOLOGY
# 1              VB_WORKFLOWAMBPEDSPULMONARY
# 2             VB_WORKFLOWAMBOTOLARYNGOLOGY
# 7                               POSTPARTUM
# 9           VB_WORKFLOWAMBCLINICALPHARMACI
# 11                VB_EDSUMMARYVIEWPOINT001
# 12                  VB_WORKFLOWIPNEUROLOGY
# 13                                     NaN
# 18                    VB_QUICKORDERSPEDSGI
# 31        CLINICAL OPIATE WITHDRAWAL SCALE
# 32                      PPRSUMM/PVDEMOGPPR
# 36           VB_WORKFLOWAMBSURGERYPLASTICS
# 37                     FAMILY/KIAFHXUI.DLL
# 38          VB_WORKFLOWIPMANAGENEONATOLOGY
# 39            VB_QUICKORDERSGENERALSURGERY
# 40                 VB_WORKFLOWIPPSYCHOLOGY
# 41                VB_WORKFLOWIPHOSPITALIST
# 42          PSYCH RESTRAINTS AND SECLUSION
# 45                                     NaN
# 50                                     NaN
# 51          VB_WORKFLOWIPMANAGEPEDSPULMONA
# 67                 VB_WORKFLOWAMBPULMONARY
# 68                              POWERFORMS
# 77                                   RELTN
# 80          VB_WORKFLOWAMBPEDSENDOCRINOLOG
# 82          VB_WORKFLOWAMBOBCLINICSUPPORTU
# 83      PROCEDURAL ROUTINE CARE AND SAFETY
# 84          VB_WORKFLOWIPINFECTIOUSDISEASE
# 85           VB_WORKFLOWIPGASTROENTEROLOGY
# 86                               PIP/PVPIP
# ...                                    ...
# 898461         VB_WORKFLOWAMBPEDSPULMONARY
# 898463        VB_WORKFLOWAMBOBPRENATALPPUN
# 898465           VB_WORKFLOWAMBPEDSALLERGY
# 898467                                 NaN
# 898470                 RESPIRATORY THERAPY
# 898472      VB_WORKFLOWIPINFECTIOUSDISEASE
# 898473                   OBGYN/PVPHXUI.DLL
# 898476                                 NaN
# 898477      VB_WORKFLOWAMBPEDSENDOCRINOLOG
# 898478      VB_WORKFLOWAMBOBPRENATALPOSTPA
# 898480      VB_WORKFLOWAMBGASTROENTEROLOGY
# 898488                   VB_AMBGYNWORKFLOW
# 898491      VB_WORKFLOWAMBCLINICALPHARMACI
# 898492             VB_WORKFLOWIPPSYCHOLOGY
# 898493      VB_WORKFLOWAMBOBPRENATALPOSTPA
# 898503               SPTASKLIST/PVTASKLIST
# 898504          PROCEDURAL VITALS AND PAIN
# 898505   CM COMPREHENSIVE EVALUATION ADULT
# 898510                VB_IUHNEONATESUMMARY
# 898514               VB_WORKFLOWAMBINSIDER
# 898519         VB_WORKFLOWAMBCARDIOLOGY001
# 898523      VB_WORKFLOWAMBPCPROVIDERFAMILY
# 898524             VB_WORKFLOWAMBNEUROLOGY
# 898530                     VB_SUMMARYORTHO
# 898534       VB_WORKFLOWAMBSURGERYVASCULAR
# 898537                     VB_SUMMARYORTHO
# 898542            VB_WORKFLOWIPHOSPITALIST
# 898544      VB_WORKFLOWIPDEVELOPMENTALPEDS
# 898545         VB_WORKFLOWAMBADOLESCENTMED
# 898548        INVITATIONS/PVINVITATION.DLL
#
#                                                 timername  total_elapsed  \
# 0                   USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT      44.998676
# 1                 USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT       3.484803
# 2       USR:MPG.CONSOLIDATED_HISTORY - CHRONIC PROBLEM...       1.050656
# 7                       USR: PDOC NAVIGATOR DOC SET CLICK      53.119000
# 9                   USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT      98.820230
# 11                       USR:MPG.LABS.O1 - LOAD COMPONENT      72.637658
# 12           USR:MPG.DOCUMENTATION_PE.O1 - LOAD COMPONENT      60.518765
# 13                     USR:CARECOMPASS.CHANGEPATIENTLISTS    4239.784000
# 18                USR:MPG.CONSOL_PROB.O1 - LOAD COMPONENT       4.646506
# 31                         USR: PDOC NAVIGATOR BAND CLICK       1.310000
# 32                                     USR:PWR-OPEN CHART      42.430985
# 36                 USR:MPG.LABORATORY.WF - LOAD COMPONENT       0.344424
# 37                                     USR:PWR-OPEN CHART      25.267897
# 38           USR:MPG.DOCUMENTATION_PE.O1 - LOAD COMPONENT      70.491940
# 39                USR:MPG.CONSOL_PROB.O1 - LOAD COMPONENT       7.628957
# 40                       USR:MPG.MEDS.O2 - LOAD COMPONENT      14.803425
# 41                  USR:MPG.PATHOLOGY.O2 - LOAD COMPONENT     255.773842
# 42                                  USR: ICU-OPENING-BAND       0.955065
# 45                    USR:ORM.GETTHERAPEUTICSUBSTITUTIONS     264.446410
# 50                               USR: DOC INSERT AUTOTEXT    1863.894340
# 51                         USR:MPG.IO.O2 - LOAD COMPONENT     264.144577
# 67               USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT     153.670836
# 68                           USR:BSC-DISPLAY MED CHARTING     809.352000
# 77                  USR:PWR.LOAD AND DISPLAY PATIENT LIST     560.050000
# 80          USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      22.706534
# 82          USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT       0.145006
# 83                      USR: PDOC NAVIGATOR DOC SET CLICK       9.887000
# 84            USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT     121.126575
# 85                 USR:MPG.VITALSIGNS.WF - LOAD COMPONENT      25.122052
# 86                                    USR:PWR-CREATE VIEW    2076.469671
# ...                                                   ...            ...
# 898461      USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT      71.466296
# 898463              USR:MPG.REMINDERS.O2 - LOAD COMPONENT       3.955868
# 898465            USR:MPG.DIAGNOSTICS.O2 - LOAD COMPONENT       0.877993
# 898467  USR:MPG.RCM.CLINICAL_REVIEW - ADD CLINICAL REV...      11.827283
# 898470                  USR: PDOC NAVIGATOR DOC SET CLICK      22.692000
# 898472      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT       1.025875
# 898473                                USR:PWR-CREATE VIEW     397.876502
# 898476  USR:ICU-IVIEW-ADDING OR REMOVING SECTIONS AND ...       5.662000
# 898477                 USR:MPG.ORDERS.O2 - LOAD COMPONENT       1.570057
# 898478  USR:MPG.ACTIONS_SIT_AWARENESS.O1 - LOAD COMPONENT     137.691797
# 898480              USR:MPG.CARE_TEAM.O2 - LOAD COMPONENT       7.497358
# 898488        USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT     252.622499
# 898491        USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT     569.855270
# 898492      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT       1.505460
# 898493           USR:MPG.ORDERPROFILE.O1 - LOAD COMPONENT      92.671492
# 898503                                USR:PWR-CREATE VIEW   14104.775028
# 898504                     USR: PDOC NAVIGATOR BAND CLICK      20.041000
# 898505                     USR: PDOC NAVIGATOR BAND CLICK       0.029000
# 898510         USR:MPG.DISCHARGE_PLAN.O1 - LOAD COMPONENT      11.354090
# 898514              USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT       0.749529
# 898519             USR:MPG.LABORATORY.WF - LOAD COMPONENT     660.161611
# 898523              USR:MPG.CARE_TEAM.O2 - LOAD COMPONENT     900.257886
# 898524           USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT     685.108111
# 898530                 USR:MPG.VISITS.O1 - LOAD COMPONENT      12.055367
# 898534      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT       0.228579
# 898537         USR:MPG.FAMILY_HISTORY.O1 - LOAD COMPONENT       7.334552
# 898542      USR:MPG.DOCUMENTATION_ROS.O1 - LOAD COMPONENT    1777.788823
# 898544      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      42.995467
# 898545                 USR:MPG.ORDERS.O2 - LOAD COMPONENT       0.484427
# 898548                                USR:PWR-CREATE VIEW      19.299810
#
#         transAbove5  transUnder2  transaction_cnt     isBDay
# 0                 0          132              133 2018-10-16
# 1                 0           28               28 2018-10-18
# 2                 0            1                1 2018-10-25
# 7                 0          842              842 2018-09-04
# 9                 2           32               47 2018-08-17
# 11                0           54               60 2018-10-31
# 12                0          229              229 2018-07-25
# 13               46         1651             2348 2018-10-02
# 18                0            9                9 2018-10-23
# 31                0            3                3 2018-09-05
# 32                1            8               17 2018-09-21
# 36                0            1                1 2018-10-19
# 37                0           14               16 2018-10-01
# 38                0          184              187 2018-10-25
# 39                0           12               12 2018-08-10
# 40                1            9               10 2018-09-06
# 41                0          778              793 2018-10-08
# 42                0            2                2 2018-07-20
# 45                2         8371             8378 2018-09-04
# 50                5        21756            21805 2018-10-03
# 51                3          190              206 2018-08-21
# 67                1          137              141 2018-09-18
# 68                0         1792             1792 2018-08-01
# 77                2         2046             2057 2018-07-26
# 80                0           97               97 2018-08-07
# 82                0            3                3 2018-09-05
# 83                0          100              100 2018-09-10
# 84                1          198              204 2018-10-11
# 85                0           33               33 2018-11-06
# 86                1         5302             5317 2018-07-16
# ...             ...          ...              ...        ...
# 898461            0          254              254 2018-08-30
# 898463            0           10               10 2018-09-17
# 898465            0            4                4 2018-08-01
# 898467            0           40               40 2018-07-09
# 898470            0          233              233 2018-09-11
# 898472            0            5                5 2018-08-02
# 898473            0         1133             1135 2018-09-24
# 898476            0           75               75 2018-08-15
# 898477            0            2                2 2018-09-21
# 898478            0          739              742 2018-08-24
# 898480            0           14               15 2018-09-14
# 898488            1          696              704 2018-07-27
# 898491            1         1074             1104 2018-11-05
# 898492            0           17               17 2018-11-02
# 898493            1          109              114 2018-09-28
# 898503           11        53953            54050 2018-08-09
# 898504            0          111              111 2018-08-28
# 898505            0            1                1 2018-08-13
# 898510            0         1087             1087 2018-10-04
# 898514            0            2                2 2018-07-31
# 898519            4          673              722 2018-09-19
# 898523            7         2967             2985 2018-10-31
# 898524            8          190              323 2018-08-28
# 898530            0           84               84 2018-09-21
# 898534            0            1                1 2018-10-29
# 898537            0           73               73 2018-09-03
# 898542            1         6558             6588 2018-07-30
# 898544            0          143              143 2018-09-24
# 898545            0            2                2 2018-11-01
# 898548            0            1                6 2018-09-21
#
# [269210 rows x 17 columns]

# %% [markdown]
# ## Anomaly detection/Handling

# %% [markdown]
# #### Applying quantiles:
#
# Apply 5th and 95th quantiles to each timer for the entire 90 day period.
# Then we can lookup the values using ```loc``` and ```filter```
#
#
# **To-do**
# - Investigate outliers/anomalies by timer. Replace with mean/remove altogether.
# - Use KNN?
# - Complete - remove outliers by timer.
#
# Sample outlier removal calculation by group.
# ```atrt_df_PC[np.abs(atrt_df_PC.ATRT-atrt_df_PC.ATRT.mean()) <= (3*atrt_df_PC.ATRT.std())]```
#
# Takes the absolute value of standardized value for each datapoint, then removes it if it's less than 3 standard deviations from the mean.
# - I need to do this by group!
# - Group first, then pass in group calculation.

# %%
#find outliers
outliers = atrt_df_PC.groupby(["Timer Subtimer Name"])['ATRT'].quantile([0.05, 0.95]).unstack(level=1)
#filter outliers
atrt_df_PC = atrt_df_PC.loc[((outliers.loc[atrt_df_PC['Timer Subtimer Name'], .05] < atrt_df_PC.ATRT.values) & (atrt_df_PC.ATRT.values < outliers.loc[atrt_df_PC['Timer Subtimer Name'], .95])).values]

# %% [markdown]
# ### Rolling average notes
# Lambda function for applying rolling average to a group:
# The groupby statement can be in an earlier variable, but I've chosen to include it here.
#
# **To-do**
# - [ ] Find out exactly what reset_index does - reset the average calculation to the beginning of each group?
# - [ ] Remove outliers/anomalies by timer. Replace with mean/remove altogether.
# - [ ] Use KNN for clustering timers...analyze what timers that have shifted up have in common.
# - [ ] Establish control chart:
#     - UCL = .75 quartile + 1.5x IQR
#     - LCL = .25 quartile - 1.5x IQR
#     - mean = 60-day mean
#     - median = 60-day median (use with outliers included)
# ```
# atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])['ATRT'].rolling(30).mean().reset_index(0,drop=True)
# ```
# Pass into dataset feature with ```atrt_df_PC['mavg30'] = (above statement)```
#
# ```atrt_df_PC['mavg30'] = atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])['ATRT'].rolling(30).mean().reset_index(0,drop=True)```

# %%
#Setting index appears to cause issues when outputting to csv: 
#atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name', 'dt'])

atrt_df_PC = atrt_df_PC.sort_values(['Timer Subtimer Name', 'dt'])
atrt_df_PC['mavg30'] = atrt_df_PC.groupby('Timer Subtimer Name')['ATRT'].apply(lambda x:x.rolling(center=False,window=30).mean())

#check to make sure that everything looks correct: 
atrt_df_PC
# Out:
#        Component RecommendMPG?  ATRT % of Transactions > 5 seconds  \
# 575619       NaN         Other  0.14                         0.00%
# 57225        NaN         Other  0.15                         0.00%
# 283640       NaN         Other  0.15                         0.00%
# 296879       NaN         Other  0.15                         0.00%
# 33734        NaN         Other  0.15                         0.00%
# 203636       NaN         Other  0.15                         0.00%
# 861989       NaN         Other  0.14                         0.00%
# 771402       NaN         Other  0.14                         0.00%
# 20249        NaN         Other  0.14                         0.00%
# 562782       NaN         Other  0.14                         0.00%
# 162609       NaN         Other  0.14                         0.02%
# 390676       NaN         Other  0.14                         0.02%
# 769198       NaN         Other  0.15                         0.00%
# 472433       NaN         Other  0.15                         0.00%
# 166299       NaN         Other  0.15                         0.00%
# 403686       NaN         Other  0.15                         0.00%
# 810383       NaN         Other  0.15                         0.00%
# 207584       NaN         Other  0.15                         0.02%
# 832203       NaN         Other  0.15                         0.00%
# 750535       NaN         Other  0.15                         0.00%
# 855234       NaN         Other  0.15                         0.00%
# 605211       NaN         Other  0.15                         0.00%
# 82971        NaN         Other  0.15                         0.00%
# 186885       NaN         Other  0.15                         0.00%
# 797172       NaN         Other  0.15                         0.00%
# 804455       NaN         Other  0.15                         0.00%
# 141612       NaN         Other  0.14                         0.00%
# 302464       NaN         Other  0.15                         0.00%
# 878629       NaN         Other  0.14                         0.00%
# 791584       NaN         Other  0.15                         0.00%
# ...          ...           ...   ...                           ...
# 810565   USR:WH-         Other  4.95                        53.42%
# 847346   USR:WH-         Other  4.76                        52.33%
# 189161   USR:WH-         Other  4.38                        48.72%
# 516153   USR:WH-         Other  4.60                        53.03%
# 860239   USR:WH-         Other  4.29                        46.74%
# 227464   USR:WH-         Other  4.75                        52.63%
# 97113    USR:WH-         Other  4.17                        48.78%
# 868093   USR:WH-         Other  3.89                        41.57%
# 165996   USR:WH-         Other  4.53                        51.28%
# 455897   USR:WH-         Other  3.89                        43.30%
# 356724   USR:WH-         Other  4.69                        48.28%
# 815195   USR:WH-         Other  4.75                        52.94%
# 634190   USR:WH-         Other  4.84                        55.00%
# 229247   USR:WH-         Other  4.53                        51.47%
# 502863   USR:WH-         Other  4.06                        46.75%
# 727313   USR:WH-         Other  4.53                        55.41%
# 336519   USR:WH-         Other  3.99                        41.30%
# 649366   USR:WH-         Other  4.63                        57.41%
# 824110   USR:WH-         Other  4.44                        46.05%
# 145788   USR:WH-         Other  3.95                        47.44%
# 574515   USR:WH-         Other  4.32                        42.67%
# 710666   USR:WH-         Other  4.12                        45.59%
# 681614   USR:WH-         Other  4.85                        53.52%
# 185451   USR:WH-         Other  4.07                        46.97%
# 121450   USR:WH-         Other  5.52                        61.40%
# 100962   USR:WH-         Other  5.35                        60.42%
# 781193   USR:WH-         Other  5.46                        69.01%
# 746727   USR:WH-         Other  5.70                        68.29%
# 173941   USR:WH-         Other  5.12                        58.00%
# 876190   USR:WH-         Other  5.13                        58.97%
#
#        % of Transactions < 2 seconds  \
# 575619                       100.00%
# 57225                         99.95%
# 283640                       100.00%
# 296879                       100.00%
# 33734                         99.98%
# 203636                       100.00%
# 861989                       100.00%
# 771402                        99.98%
# 20249                        100.00%
# 562782                       100.00%
# 162609                        99.98%
# 390676                        99.98%
# 769198                       100.00%
# 472433                       100.00%
# 166299                        99.98%
# 403686                       100.00%
# 810383                       100.00%
# 207584                        99.98%
# 832203                       100.00%
# 750535                       100.00%
# 855234                        99.98%
# 605211                       100.00%
# 82971                         99.98%
# 186885                       100.00%
# 797172                        99.98%
# 804455                        99.98%
# 141612                       100.00%
# 302464                       100.00%
# 878629                       100.00%
# 791584                        99.96%
# ...                              ...
# 810565                        41.10%
# 847346                        38.37%
# 189161                        46.15%
# 516153                        37.88%
# 860239                        43.48%
# 227464                        44.74%
# 97113                         47.56%
# 868093                        53.93%
# 165996                        43.59%
# 455897                        50.52%
# 356724                        46.55%
# 815195                        43.14%
# 634190                        40.00%
# 229247                        39.71%
# 502863                        50.65%
# 727313                        44.59%
# 336519                        45.65%
# 649366                        37.04%
# 824110                        38.16%
# 145788                        51.28%
# 574515                        46.67%
# 710666                        45.59%
# 681614                        33.80%
# 185451                        48.48%
# 121450                        26.32%
# 100962                        29.17%
# 781193                        23.94%
# 746727                        17.07%
# 173941                        26.00%
# 876190                        33.33%
#
#                                 Timer Subtimer Name  Number of Records  \
# 575619                   DMSM_GETMEDIACONTENT (N/A)                  1
# 57225                    DMSM_GETMEDIACONTENT (N/A)                  1
# 283640                   DMSM_GETMEDIACONTENT (N/A)                  1
# 296879                   DMSM_GETMEDIACONTENT (N/A)                  1
# 33734                    DMSM_GETMEDIACONTENT (N/A)                  1
# 203636                   DMSM_GETMEDIACONTENT (N/A)                  1
# 861989                   DMSM_GETMEDIACONTENT (N/A)                  1
# 771402                   DMSM_GETMEDIACONTENT (N/A)                  1
# 20249                    DMSM_GETMEDIACONTENT (N/A)                  1
# 562782                   DMSM_GETMEDIACONTENT (N/A)                  1
# 162609                   DMSM_GETMEDIACONTENT (N/A)                  1
# 390676                   DMSM_GETMEDIACONTENT (N/A)                  1
# 769198                   DMSM_GETMEDIACONTENT (N/A)                  1
# 472433                   DMSM_GETMEDIACONTENT (N/A)                  1
# 166299                   DMSM_GETMEDIACONTENT (N/A)                  1
# 403686                   DMSM_GETMEDIACONTENT (N/A)                  1
# 810383                   DMSM_GETMEDIACONTENT (N/A)                  1
# 207584                   DMSM_GETMEDIACONTENT (N/A)                  1
# 832203                   DMSM_GETMEDIACONTENT (N/A)                  1
# 750535                   DMSM_GETMEDIACONTENT (N/A)                  1
# 855234                   DMSM_GETMEDIACONTENT (N/A)                  1
# 605211                   DMSM_GETMEDIACONTENT (N/A)                  1
# 82971                    DMSM_GETMEDIACONTENT (N/A)                  1
# 186885                   DMSM_GETMEDIACONTENT (N/A)                  1
# 797172                   DMSM_GETMEDIACONTENT (N/A)                  1
# 804455                   DMSM_GETMEDIACONTENT (N/A)                  1
# 141612                   DMSM_GETMEDIACONTENT (N/A)                  1
# 302464                   DMSM_GETMEDIACONTENT (N/A)                  1
# 878629                   DMSM_GETMEDIACONTENT (N/A)                  1
# 791584                   DMSM_GETMEDIACONTENT (N/A)                  1
# ...                                             ...                ...
# 810565  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 847346  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 189161  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 516153  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 860239  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 227464  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 97113   USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 868093  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 165996  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 455897  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 356724  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 815195  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 634190  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 229247  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 502863  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 727313  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 336519  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 649366  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 824110  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 145788  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 574515  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 710666  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 681614  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 185451  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 121450  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 100962  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 781193  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 746727  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 173941  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 876190  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 575619       POWERCHART 2018-07-09  0.076104          NaN
# 57225        POWERCHART 2018-07-10  0.099533          NaN
# 283640       POWERCHART 2018-07-13  0.074018          NaN
# 296879       POWERCHART 2018-07-16  0.078706          NaN
# 33734        POWERCHART 2018-07-17  0.077647          NaN
# 203636       POWERCHART 2018-07-23  0.072386          NaN
# 861989       POWERCHART 2018-07-24  0.068667          NaN
# 771402       POWERCHART 2018-07-25  0.077925          NaN
# 20249        POWERCHART 2018-07-27  0.069255          NaN
# 562782       POWERCHART 2018-07-30  0.071464          NaN
# 162609       POWERCHART 2018-07-31  0.273690          NaN
# 390676       POWERCHART 2018-08-01  0.143897          NaN
# 769198       POWERCHART 2018-08-02  0.074053          NaN
# 472433       POWERCHART 2018-08-06  0.080803          NaN
# 166299       POWERCHART 2018-08-07  0.085864          NaN
# 403686       POWERCHART 2018-08-14  0.070129          NaN
# 810383       POWERCHART 2018-08-15  0.081760          NaN
# 207584       POWERCHART 2018-08-16  0.109795          NaN
# 832203       POWERCHART 2018-08-17  0.073036          NaN
# 750535       POWERCHART 2018-08-22  0.074734          NaN
# 855234       POWERCHART 2018-08-24  0.085955          NaN
# 605211       POWERCHART 2018-08-27  0.079786          NaN
# 82971        POWERCHART 2018-08-28  0.105092          NaN
# 186885       POWERCHART 2018-08-29  0.077442          NaN
# 797172       POWERCHART 2018-08-30  0.104720          NaN
# 804455       POWERCHART 2018-08-31  0.096848          NaN
# 141612       POWERCHART 2018-09-04  0.079725          NaN
# 302464       POWERCHART 2018-09-05  0.077272          NaN
# 878629       POWERCHART 2018-09-06  0.075886          NaN
# 791584       POWERCHART 2018-09-07  0.100203          NaN
# ...                 ...        ...       ...          ...
# 810565       POWERCHART 2018-09-19  4.199626          NaN
# 847346       POWERCHART 2018-09-20  3.840833          NaN
# 189161       POWERCHART 2018-09-21  4.157388          NaN
# 516153       POWERCHART 2018-09-24  3.544378          NaN
# 860239       POWERCHART 2018-09-25  3.780417          NaN
# 227464       POWERCHART 2018-09-26  4.128597          NaN
# 97113        POWERCHART 2018-09-27  3.785608          NaN
# 868093       POWERCHART 2018-09-28  3.793539          NaN
# 165996       POWERCHART 2018-10-01  3.758748          NaN
# 455897       POWERCHART 2018-10-02  3.640664          NaN
# 356724       POWERCHART 2018-10-04  5.265499          NaN
# 815195       POWERCHART 2018-10-05  4.127223          NaN
# 634190       POWERCHART 2018-10-08  3.735527          NaN
# 229247       POWERCHART 2018-10-09  3.649069          NaN
# 502863       POWERCHART 2018-10-10  3.760897          NaN
# 727313       POWERCHART 2018-10-11  3.818554          NaN
# 336519       POWERCHART 2018-10-12  3.615590          NaN
# 649366       POWERCHART 2018-10-15  3.448499          NaN
# 824110       POWERCHART 2018-10-16  3.525056          NaN
# 145788       POWERCHART 2018-10-17  3.615882          NaN
# 574515       POWERCHART 2018-10-18  4.040581          NaN
# 710666       POWERCHART 2018-10-19  3.681307          NaN
# 681614       POWERCHART 2018-10-22  3.616620          NaN
# 185451       POWERCHART 2018-10-23  3.770722          NaN
# 121450       POWERCHART 2018-10-24  3.570586          NaN
# 100962       POWERCHART 2018-10-29  3.642358          NaN
# 781193       POWERCHART 2018-10-31  3.018684          NaN
# 746727       POWERCHART 2018-11-01  2.880376          NaN
# 173941       POWERCHART 2018-11-02  3.247114          NaN
# 876190       POWERCHART 2018-11-05  3.755319          NaN
#
#                                     timername  total_elapsed  transAbove5  \
# 575619                   DMSM_GETMEDIACONTENT        866.287            0
# 57225                    DMSM_GETMEDIACONTENT        925.562            0
# 283640                   DMSM_GETMEDIACONTENT        750.560            0
# 296879                   DMSM_GETMEDIACONTENT        974.322            0
# 33734                    DMSM_GETMEDIACONTENT        928.780            0
# 203636                   DMSM_GETMEDIACONTENT        904.326            0
# 861989                   DMSM_GETMEDIACONTENT        837.677            0
# 771402                   DMSM_GETMEDIACONTENT        850.282            0
# 20249                    DMSM_GETMEDIACONTENT        703.502            0
# 562782                   DMSM_GETMEDIACONTENT        856.344            0
# 162609                   DMSM_GETMEDIACONTENT        880.955            1
# 390676                   DMSM_GETMEDIACONTENT        900.327            1
# 769198                   DMSM_GETMEDIACONTENT        889.563            0
# 472433                   DMSM_GETMEDIACONTENT        908.990            0
# 166299                   DMSM_GETMEDIACONTENT        931.508            0
# 403686                   DMSM_GETMEDIACONTENT        921.509            0
# 810383                   DMSM_GETMEDIACONTENT        900.628            0
# 207584                   DMSM_GETMEDIACONTENT        939.268            1
# 832203                   DMSM_GETMEDIACONTENT        762.252            0
# 750535                   DMSM_GETMEDIACONTENT        902.111            0
# 855234                   DMSM_GETMEDIACONTENT        737.080            0
# 605211                   DMSM_GETMEDIACONTENT        956.114            0
# 82971                    DMSM_GETMEDIACONTENT        971.635            0
# 186885                   DMSM_GETMEDIACONTENT        873.157            0
# 797172                   DMSM_GETMEDIACONTENT        916.814            0
# 804455                   DMSM_GETMEDIACONTENT        763.421            0
# 141612                   DMSM_GETMEDIACONTENT        901.130            0
# 302464                   DMSM_GETMEDIACONTENT        946.879            0
# 878629                   DMSM_GETMEDIACONTENT        899.205            0
# 791584                   DMSM_GETMEDIACONTENT        753.307            0
# ...                                       ...            ...          ...
# 810565  USR:WH-DELIVERY RECORD-ENSURE RESULTS        361.667           39
# 847346  USR:WH-DELIVERY RECORD-ENSURE RESULTS        409.504           45
# 189161  USR:WH-DELIVERY RECORD-ENSURE RESULTS        341.620           38
# 516153  USR:WH-DELIVERY RECORD-ENSURE RESULTS        303.532           35
# 860239  USR:WH-DELIVERY RECORD-ENSURE RESULTS        394.814           43
# 227464  USR:WH-DELIVERY RECORD-ENSURE RESULTS        361.065           40
# 97113   USR:WH-DELIVERY RECORD-ENSURE RESULTS        342.199           40
# 868093  USR:WH-DELIVERY RECORD-ENSURE RESULTS        346.592           37
# 165996  USR:WH-DELIVERY RECORD-ENSURE RESULTS        353.719           40
# 455897  USR:WH-DELIVERY RECORD-ENSURE RESULTS        377.708           42
# 356724  USR:WH-DELIVERY RECORD-ENSURE RESULTS        271.731           28
# 815195  USR:WH-DELIVERY RECORD-ENSURE RESULTS        242.042           27
# 634190  USR:WH-DELIVERY RECORD-ENSURE RESULTS        290.554           33
# 229247  USR:WH-DELIVERY RECORD-ENSURE RESULTS        307.879           35
# 502863  USR:WH-DELIVERY RECORD-ENSURE RESULTS        312.688           36
# 727313  USR:WH-DELIVERY RECORD-ENSURE RESULTS        335.575           41
# 336519  USR:WH-DELIVERY RECORD-ENSURE RESULTS        367.508           38
# 649366  USR:WH-DELIVERY RECORD-ENSURE RESULTS        249.905           31
# 824110  USR:WH-DELIVERY RECORD-ENSURE RESULTS        337.612           35
# 145788  USR:WH-DELIVERY RECORD-ENSURE RESULTS        308.293           37
# 574515  USR:WH-DELIVERY RECORD-ENSURE RESULTS        323.917           32
# 710666  USR:WH-DELIVERY RECORD-ENSURE RESULTS        280.380           31
# 681614  USR:WH-DELIVERY RECORD-ENSURE RESULTS        344.570           38
# 185451  USR:WH-DELIVERY RECORD-ENSURE RESULTS        268.883           31
# 121450  USR:WH-DELIVERY RECORD-ENSURE RESULTS        314.919           35
# 100962  USR:WH-DELIVERY RECORD-ENSURE RESULTS        256.904           29
# 781193  USR:WH-DELIVERY RECORD-ENSURE RESULTS        387.741           49
# 746727  USR:WH-DELIVERY RECORD-ENSURE RESULTS        233.624           28
# 173941  USR:WH-DELIVERY RECORD-ENSURE RESULTS        255.844           29
# 876190  USR:WH-DELIVERY RECORD-ENSURE RESULTS        200.121           23
#
#         transUnder2  transaction_cnt     isBDay    mavg30
# 575619         5988             5988 2018-07-09       NaN
# 57225          6266             6269 2018-07-10       NaN
# 283640         5022             5022 2018-07-13       NaN
# 296879         6340             6340 2018-07-16       NaN
# 33734          6062             6063 2018-07-17       NaN
# 203636         6217             6217 2018-07-23       NaN
# 861989         5890             5890 2018-07-24       NaN
# 771402         5897             5898 2018-07-25       NaN
# 20249          4993             4993 2018-07-27       NaN
# 562782         6038             6038 2018-07-30       NaN
# 162609         6210             6211 2018-07-31       NaN
# 390676         6230             6231 2018-08-01       NaN
# 769198         6090             6090 2018-08-02       NaN
# 472433         6021             6021 2018-08-06       NaN
# 166299         6202             6203 2018-08-07       NaN
# 403686         6318             6318 2018-08-14       NaN
# 810383         6110             6110 2018-08-15       NaN
# 207584         6180             6181 2018-08-16       NaN
# 832203         5042             5042 2018-08-17       NaN
# 750535         5971             5971 2018-08-22       NaN
# 855234         4960             4961 2018-08-24       NaN
# 605211         6325             6325 2018-08-27       NaN
# 82971          6498             6499 2018-08-28       NaN
# 186885         6017             6017 2018-08-29       NaN
# 797172         5953             5954 2018-08-30       NaN
# 804455         5262             5263 2018-08-31       NaN
# 141612         6253             6253 2018-09-04       NaN
# 302464         6437             6437 2018-09-05       NaN
# 878629         6291             6291 2018-09-06       NaN
# 791584         5039             5041 2018-09-07  0.147000
# ...             ...              ...        ...       ...
# 810565           30               73 2018-09-19  4.520333
# 847346           33               86 2018-09-20  4.538000
# 189161           36               78 2018-09-21  4.530667
# 516153           25               66 2018-09-24  4.523667
# 860239           40               92 2018-09-25  4.533000
# 227464           34               76 2018-09-26  4.563000
# 97113            39               82 2018-09-27  4.555667
# 868093           48               89 2018-09-28  4.538333
# 165996           34               78 2018-10-01  4.550333
# 455897           49               97 2018-10-02  4.543333
# 356724           27               58 2018-10-04  4.523667
# 815195           22               51 2018-10-05  4.517000
# 634190           24               60 2018-10-08  4.535333
# 229247           27               68 2018-10-09  4.551333
# 502863           39               77 2018-10-10  4.539667
# 727313           33               74 2018-10-11  4.532333
# 336519           42               92 2018-10-12  4.539333
# 649366           20               54 2018-10-15  4.528333
# 824110           29               76 2018-10-16  4.540333
# 145788           40               78 2018-10-17  4.479333
# 574515           35               75 2018-10-18  4.458667
# 710666           31               68 2018-10-19  4.457667
# 681614           24               71 2018-10-22  4.484667
# 185451           32               66 2018-10-23  4.448333
# 121450           15               57 2018-10-24  4.465667
# 100962           14               48 2018-10-29  4.506667
# 781193           17               71 2018-10-31  4.523333
# 746727            7               41 2018-11-01  4.574000
# 173941           13               50 2018-11-02  4.587333
# 876190           13               39 2018-11-05  4.608667
#
# [214119 rows x 18 columns]

# %% [markdown]
# ### Windows
#
# Add window - 7/8 day window using pandas shift().
#
# Difference between Trend and Shift
# - trend = "7 days in a row"
# - shift = "8 days above median"
#
# **to-do**
# - [x] start with shift/window.
# - [x] establish how to identify trends and shifts using elif statements.
#
# **questions**
# - what happens when I compare something with a NaN value? - e.g. I compare days 1-7 with NaN?
# - do I need to drop rows with NaN, or return a null value?

# %%
# dataframe var is atrt_df_PC

atrt_df_PC['t-1'] = atrt_df_PC['ATRT'].shift(1)
atrt_df_PC['t-2'] = atrt_df_PC['ATRT'].shift(2)
atrt_df_PC['t-3'] = atrt_df_PC['ATRT'].shift(3)
atrt_df_PC['t-4'] = atrt_df_PC['ATRT'].shift(4)
atrt_df_PC['t-5'] = atrt_df_PC['ATRT'].shift(5)
atrt_df_PC['t-6'] = atrt_df_PC['ATRT'].shift(6)
atrt_df_PC['t-7'] = atrt_df_PC['ATRT'].shift(7)
atrt_df_PC['t-8'] = atrt_df_PC['ATRT'].shift(8)

df_pc = atrt_df_PC
df_pc.head()
# Out:
#        Component RecommendMPG?  ATRT % of Transactions > 5 seconds  \
# 575619       NaN         Other  0.14                         0.00%
# 57225        NaN         Other  0.15                         0.00%
# 283640       NaN         Other  0.15                         0.00%
# 296879       NaN         Other  0.15                         0.00%
# 33734        NaN         Other  0.15                         0.00%
#
#        % of Transactions < 2 seconds         Timer Subtimer Name  \
# 575619                       100.00%  DMSM_GETMEDIACONTENT (N/A)
# 57225                         99.95%  DMSM_GETMEDIACONTENT (N/A)
# 283640                       100.00%  DMSM_GETMEDIACONTENT (N/A)
# 296879                       100.00%  DMSM_GETMEDIACONTENT (N/A)
# 33734                         99.98%  DMSM_GETMEDIACONTENT (N/A)
#
#         Number of Records application_name         dt      strt ...   \
# 575619                  1       POWERCHART 2018-07-09  0.076104 ...
# 57225                   1       POWERCHART 2018-07-10  0.099533 ...
# 283640                  1       POWERCHART 2018-07-13  0.074018 ...
# 296879                  1       POWERCHART 2018-07-16  0.078706 ...
# 33734                   1       POWERCHART 2018-07-17  0.077647 ...
#
#            isBDay mavg30   t-1   t-2   t-3   t-4 t-5  t-6  t-7  t-8
# 575619 2018-07-09    NaN   NaN   NaN   NaN   NaN NaN  NaN  NaN  NaN
# 57225  2018-07-10    NaN  0.14   NaN   NaN   NaN NaN  NaN  NaN  NaN
# 283640 2018-07-13    NaN  0.15  0.14   NaN   NaN NaN  NaN  NaN  NaN
# 296879 2018-07-16    NaN  0.15  0.15  0.14   NaN NaN  NaN  NaN  NaN
# 33734  2018-07-17    NaN  0.15  0.15  0.15  0.14 NaN  NaN  NaN  NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Control Charts
# Set upper and lower control limits, 60-day mean, signal detection.
# - Upper and lower control limits.
#     - Upper OUTLIER = .75 qt + 1.5x IQR??
#     - [x] Upper CONTROL = .75 qt
#     - [ ] Lower Outlier = .25 qt - 1.5x IQR
#     - [x] Lower control = .25 qt
#     - [x] Obtain IQR (on 60 day mean) for each timer.
#     - [ ] Multiply that by 1.5, set as variable
#     - [x] Then calculate UCL and LCL for each timer.
#
# - Shift detection:
#     - When t-n 8 of the previous N days above/below the median/mean
#     - elif statement?
#
# - Trend detection:
#     - When t-n (7) days in a row are higher than the previous day.
#
# **To-Do**
#
# - [x] interquartile range - loc lookup to ds? running calc? pandas has quartile built into running package
# - [x] drop NA values after creating all relevant metrics.
# - [ ] plotting control charts for timer.
# - [ ] investigate using actual IQR for control limits. What about when NOR shifts up/down?
#
#
# **Questions**
#
# Does it make sense to aggregate by week for smoother trends and less volatility?
# Which timers gave consistent up/down trend/shift signals for that week? Month?
# Which timers were outside the control limits more than N times during the previous period?
#
# ### Quantiles
# Play with the different values of what's an outlier. Currently set at anything below the bottom 10, above upper 90.

# %%
df_pc['LCL_30'] = df_pc['ATRT'].rolling(30).quantile(.25, interpolation='lower')
df_pc['UCL_30'] = df_pc['ATRT'].rolling(30).quantile(.75, interpolation='higher')
df_pc['var_30'] = df_pc['ATRT'].rolling(30).var(ddof=1)

#IQR for future outlier removal
#df_pc['IQR'] = df_pc['.75'] - df_pc['.25']

df_pc
# Out:
# C:\Users\khickman1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\khickman1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\khickman1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 224889  0.15                         0.03%                        99.97%
# 517425  0.14                         0.03%                        99.95%
# 372849  0.15                         0.00%                        99.95%
# 19242   0.15                         0.00%                        99.98%
# 290846  0.14                         0.00%                       100.00%
# 223081  0.14                         0.00%                       100.00%
# 379310  0.14                         0.00%                       100.00%
# 53862   0.14                         0.00%                        99.98%
# 364756  0.14                         0.00%                       100.00%
# 261106  0.14                         0.00%                       100.00%
# 176764  0.14                         0.00%                       100.00%
# 133083  0.14                         0.00%                       100.00%
# 345014  0.14                         0.00%                       100.00%
# 87142   0.14                         0.00%                       100.00%
# 402246  0.15                         0.03%                        99.97%
# 647464  0.41                         0.00%                       100.00%
# 323603  0.63                         0.00%                       100.00%
# 612303  0.53                         0.00%                       100.00%
# 194527  0.84                         0.00%                       100.00%
# 296372  0.47                         0.00%                       100.00%
# 84678   0.58                         0.00%                       100.00%
# 522874  0.81                         0.00%                       100.00%
# 143704  1.18                         0.00%                       100.00%
# 662668  0.67                         0.00%                       100.00%
# 674645  0.72                         0.00%                       100.00%
# 97865   0.36                         0.00%                       100.00%
# 295219  0.64                         0.00%                       100.00%
# 15518   0.39                         0.00%                       100.00%
# 100562  0.30                         0.00%                       100.00%
# 47650   1.00                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 398598  0.83                         0.00%                       100.00%
# 11834   0.87                         0.00%                       100.00%
# 628953  4.95                        53.42%                        41.10%
# 442180  4.76                        52.33%                        38.37%
# 637841  4.38                        48.72%                        46.15%
# 2247    4.60                        53.03%                        37.88%
# 517566  4.29                        46.74%                        43.48%
# 571478  4.75                        52.63%                        44.74%
# 101274  4.17                        48.78%                        47.56%
# 448045  3.89                        41.57%                        53.93%
# 163177  4.53                        51.28%                        43.59%
# 111217  3.89                        43.30%                        50.52%
# 574483  4.69                        48.28%                        46.55%
# 408335  4.75                        52.94%                        43.14%
# 237476  4.84                        55.00%                        40.00%
# 186598  4.53                        51.47%                        39.71%
# 402151  4.06                        46.75%                        50.65%
# 150145  4.53                        55.41%                        44.59%
# 652283  3.99                        41.30%                        45.65%
# 353997  4.63                        57.41%                        37.04%
# 511490  4.44                        46.05%                        38.16%
# 78587   3.95                        47.44%                        51.28%
# 68672   4.32                        42.67%                        46.67%
# 6689    4.12                        45.59%                        45.59%
# 223206  4.85                        53.52%                        33.80%
# 368593  4.07                        46.97%                        48.48%
# 485708  5.52                        61.40%                        26.32%
# 105152  5.35                        60.42%                        29.17%
# 354001  5.46                        69.01%                        23.94%
# 383247  5.24                        61.11%                        16.67%
#
#                                       Timer Subtimer Name  Number of Records  \
# 224889                         DMSM_GETMEDIACONTENT (N/A)                  1
# 517425                         DMSM_GETMEDIACONTENT (N/A)                  1
# 372849                         DMSM_GETMEDIACONTENT (N/A)                  1
# 19242                          DMSM_GETMEDIACONTENT (N/A)                  1
# 290846                         DMSM_GETMEDIACONTENT (N/A)                  1
# 223081                         DMSM_GETMEDIACONTENT (N/A)                  1
# 379310                         DMSM_GETMEDIACONTENT (N/A)                  1
# 53862                          DMSM_GETMEDIACONTENT (N/A)                  1
# 364756                         DMSM_GETMEDIACONTENT (N/A)                  1
# 261106                         DMSM_GETMEDIACONTENT (N/A)                  1
# 176764                         DMSM_GETMEDIACONTENT (N/A)                  1
# 133083                         DMSM_GETMEDIACONTENT (N/A)                  1
# 345014                         DMSM_GETMEDIACONTENT (N/A)                  1
# 87142                          DMSM_GETMEDIACONTENT (N/A)                  1
# 402246                         DMSM_GETMEDIACONTENT (N/A)                  1
# 647464                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 323603                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 612303                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 194527                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 296372                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 84678                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 522874                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 143704                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 662668                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 674645                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 97865                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 295219                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 15518                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 100562                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 47650                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# ...                                                   ...                ...
# 398598  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 11834   USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 628953        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 442180        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 637841        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 2247          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 517566        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 571478        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 101274        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 448045        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 163177        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 111217        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 574483        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 408335        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 237476        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 186598        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 402151        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 150145        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 652283        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 353997        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 511490        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 78587         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 68672         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 6689          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 223206        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 368593        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 485708        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 105152        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 354001        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 383247        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 224889       POWERCHART 2018-09-17  0.156930          NaN
# 517425       POWERCHART 2018-09-18  0.233025          NaN
# 372849       POWERCHART 2018-09-27  0.101519          NaN
# 19242        POWERCHART 2018-09-28  0.100805          NaN
# 290846       POWERCHART 2018-10-02  0.070028          NaN
# 223081       POWERCHART 2018-10-03  0.062836          NaN
# 379310       POWERCHART 2018-10-09  0.069858          NaN
# 53862        POWERCHART 2018-10-15  0.083543          NaN
# 364756       POWERCHART 2018-10-16  0.075542          NaN
# 261106       POWERCHART 2018-10-18  0.062809          NaN
# 176764       POWERCHART 2018-10-23  0.068284          NaN
# 133083       POWERCHART 2018-10-24  0.069277          NaN
# 345014       POWERCHART 2018-10-30  0.066100          NaN
# 87142        POWERCHART 2018-10-31  0.067762          NaN
# 402246       POWERCHART 2018-11-01  0.509535          NaN
# 647464       POWERCHART 2018-09-21  0.165633          NaN
# 323603       POWERCHART 2018-09-24  0.282050          NaN
# 612303       POWERCHART 2018-09-25  0.368174          NaN
# 194527       POWERCHART 2018-09-26  0.094260          NaN
# 296372       POWERCHART 2018-09-27  0.409663          NaN
# 84678        POWERCHART 2018-09-28  0.178580          NaN
# 522874       POWERCHART 2018-10-01       NaN          NaN
# 143704       POWERCHART 2018-10-02  0.895904          NaN
# 662668       POWERCHART 2018-10-03  0.265165          NaN
# 674645       POWERCHART 2018-10-04  0.420021          NaN
# 97865        POWERCHART 2018-10-05  0.238620          NaN
# 295219       POWERCHART 2018-10-09  0.066468          NaN
# 15518        POWERCHART 2018-10-10  0.228766          NaN
# 100562       POWERCHART 2018-10-11  0.375474          NaN
# 47650        POWERCHART 2018-10-12  0.530330          NaN
# ...                 ...        ...       ...          ...
# 398598       POWERCHART 2018-10-31  0.198602          NaN
# 11834        POWERCHART 2018-11-01  0.196154          NaN
# 628953       POWERCHART 2018-09-19  4.199626          NaN
# 442180       POWERCHART 2018-09-20  3.840833          NaN
# 637841       POWERCHART 2018-09-21  4.157388          NaN
# 2247         POWERCHART 2018-09-24  3.544378          NaN
# 517566       POWERCHART 2018-09-25  3.780417          NaN
# 571478       POWERCHART 2018-09-26  4.128597          NaN
# 101274       POWERCHART 2018-09-27  3.785608          NaN
# 448045       POWERCHART 2018-09-28  3.793539          NaN
# 163177       POWERCHART 2018-10-01  3.758748          NaN
# 111217       POWERCHART 2018-10-02  3.640664          NaN
# 574483       POWERCHART 2018-10-04  5.265499          NaN
# 408335       POWERCHART 2018-10-05  4.127223          NaN
# 237476       POWERCHART 2018-10-08  3.735527          NaN
# 186598       POWERCHART 2018-10-09  3.649069          NaN
# 402151       POWERCHART 2018-10-10  3.760897          NaN
# 150145       POWERCHART 2018-10-11  3.818554          NaN
# 652283       POWERCHART 2018-10-12  3.615590          NaN
# 353997       POWERCHART 2018-10-15  3.448499          NaN
# 511490       POWERCHART 2018-10-16  3.525056          NaN
# 78587        POWERCHART 2018-10-17  3.615882          NaN
# 68672        POWERCHART 2018-10-18  4.040581          NaN
# 6689         POWERCHART 2018-10-19  3.681307          NaN
# 223206       POWERCHART 2018-10-22  3.616620          NaN
# 368593       POWERCHART 2018-10-23  3.770722          NaN
# 485708       POWERCHART 2018-10-24  3.570586          NaN
# 105152       POWERCHART 2018-10-29  3.642358          NaN
# 354001       POWERCHART 2018-10-31  3.018684          NaN
# 383247       POWERCHART 2018-11-01  2.705905          NaN
#
#                                               timername  ...     t-5   t-6  \
# 224889                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 517425                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 372849                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 19242                              DMSM_GETMEDIACONTENT  ...    0.16  0.15
# 290846                             DMSM_GETMEDIACONTENT  ...    0.15  0.16
# 223081                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 379310                             DMSM_GETMEDIACONTENT  ...    0.14  0.15
# 53862                              DMSM_GETMEDIACONTENT  ...    0.15  0.14
# 364756                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 261106                             DMSM_GETMEDIACONTENT  ...    0.14  0.15
# 176764                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 133083                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 345014                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 87142                              DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 402246                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 647464                          DMSM_GETMEDIAOBJECTLIST  ...    0.75  0.91
# 323603                          DMSM_GETMEDIAOBJECTLIST  ...    0.89  0.75
# 612303                          DMSM_GETMEDIAOBJECTLIST  ...    0.70  0.89
# 194527                          DMSM_GETMEDIAOBJECTLIST  ...    1.07  0.70
# 296372                          DMSM_GETMEDIAOBJECTLIST  ...    0.37  1.07
# 84678                           DMSM_GETMEDIAOBJECTLIST  ...    0.41  0.37
# 522874                          DMSM_GETMEDIAOBJECTLIST  ...    0.63  0.41
# 143704                          DMSM_GETMEDIAOBJECTLIST  ...    0.53  0.63
# 662668                          DMSM_GETMEDIAOBJECTLIST  ...    0.84  0.53
# 674645                          DMSM_GETMEDIAOBJECTLIST  ...    0.47  0.84
# 97865                           DMSM_GETMEDIAOBJECTLIST  ...    0.58  0.47
# 295219                          DMSM_GETMEDIAOBJECTLIST  ...    0.81  0.58
# 15518                           DMSM_GETMEDIAOBJECTLIST  ...    1.18  0.81
# 100562                          DMSM_GETMEDIAOBJECTLIST  ...    0.67  1.18
# 47650                           DMSM_GETMEDIAOBJECTLIST  ...    0.72  0.67
# ...                                                 ...  ...     ...   ...
# 398598  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME  ...    0.86  0.90
# 11834   USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME  ...    0.93  0.86
# 628953            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.12  5.00
# 442180            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.96  4.12
# 637841            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.18  4.96
# 2247              USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.72  4.18
# 517566            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.49  4.72
# 571478            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.95  4.49
# 101274            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.76  4.95
# 448045            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.38  4.76
# 163177            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.60  4.38
# 111217            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.29  4.60
# 574483            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.75  4.29
# 408335            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.17  4.75
# 237476            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.89  4.17
# 186598            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  3.89
# 402151            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.89  4.53
# 150145            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.69  3.89
# 652283            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.75  4.69
# 353997            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.84  4.75
# 511490            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  4.84
# 78587             USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.06  4.53
# 68672             USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  4.06
# 6689              USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.99  4.53
# 223206            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.63  3.99
# 368593            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.44  4.63
# 485708            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.95  4.44
# 105152            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.32  3.95
# 354001            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.12  4.32
# 383247            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.85  4.12
#
#          t-7   t-8 LCL_30  UCL_30    var_30  signal  trend  shift
# 224889  0.14  0.15    NaN     NaN       NaN    None   None   None
# 517425  0.15  0.14    NaN     NaN       NaN    None   None   None
# 372849  0.15  0.15    NaN     NaN       NaN    None   None   None
# 19242   0.15  0.15    NaN     NaN       NaN    None   None   None
# 290846  0.15  0.15    NaN     NaN       NaN    None   None   None
# 223081  0.16  0.15    NaN     NaN       NaN    None   None   None
# 379310  0.15  0.16    NaN     NaN       NaN    None   None   None
# 53862   0.15  0.15    NaN     NaN       NaN    None   None   None
# 364756  0.14  0.15    NaN     NaN       NaN    None   None   None
# 261106  0.15  0.14    NaN     NaN       NaN    None   None   None
# 176764  0.15  0.15    NaN     NaN       NaN    None   None   None
# 133083  0.14  0.15    NaN     NaN       NaN    None   None   None
# 345014  0.14  0.14    NaN     NaN       NaN    None   None   None
# 87142   0.14  0.14    NaN     NaN       NaN    None   None   None
# 402246  0.14  0.14    NaN     NaN       NaN    None   None   None
# 647464  0.78  0.90    NaN     NaN       NaN    None   None   None
# 323603  0.91  0.78    NaN     NaN       NaN    None   None   None
# 612303  0.75  0.91    NaN     NaN       NaN    None   None   None
# 194527  0.89  0.75    NaN     NaN       NaN    None   None   None
# 296372  0.70  0.89    NaN     NaN       NaN    None   None   None
# 84678   1.07  0.70    NaN     NaN       NaN    None   None   None
# 522874  0.37  1.07    NaN     NaN       NaN    None   None   None
# 143704  0.41  0.37    NaN     NaN       NaN    None   None   None
# 662668  0.63  0.41    NaN     NaN       NaN    None   None   None
# 674645  0.53  0.63    NaN     NaN       NaN    None   None   None
# 97865   0.84  0.53    NaN     NaN       NaN    None   None   None
# 295219  0.47  0.84    NaN     NaN       NaN    None   None   None
# 15518   0.58  0.47    NaN     NaN       NaN    None   None   None
# 100562  0.81  0.58    NaN     NaN       NaN    None   None   None
# 47650   1.18  0.81   0.14    0.84  0.092133    None   None   None
# ...      ...   ...    ...     ...       ...     ...    ...    ...
# 398598  0.79  0.88   0.75    1.08  0.011389    None   None   None
# 11834   0.90  0.79   0.75    0.93  0.007580    None   None   None
# 628953  5.16  4.04   0.75    0.93  0.570341    None   None   None
# 442180  5.00  5.16   0.75    0.93  1.049587    None   None   None
# 637841  4.12  5.00   0.75    4.38  1.405281    None   None   None
# 2247    4.96  4.12   0.75    4.60  1.779184    None   None   None
# 517566  4.18  4.96   0.75    4.60  2.057524    None   None   None
# 571478  4.72  4.18   0.75    4.75  2.404864    None   None   None
# 101274  4.49  4.72   0.75    4.75  2.603729    None   None   None
# 448045  4.95  4.49   0.75    4.75  2.737103    None   None   None
# 163177  4.76  4.95   0.75    4.75  2.945511    None   None   None
# 111217  4.38  4.76   0.75    4.75  3.023189    None   None   None
# 574483  4.60  4.38   0.75    4.75  3.199092    None   None   None
# 408335  4.29  4.60   0.75    4.75  3.351144    None   None   None
# 237476  4.75  4.29   0.75    4.76  3.491846    None   None   None
# 186598  4.17  4.75   0.75    4.76  3.545075    None   None   None
# 402151  3.89  4.17   0.75    4.76  3.506168    None   None   None
# 150145  4.53  3.89   0.75    4.76  3.494892    None   None   None
# 652283  3.89  4.53   0.75    4.76  3.413081    None   None   None
# 353997  4.69  3.89   0.78    4.76  3.346452    None   None   None
# 511490  4.75  4.69   0.79    4.76  3.221853    None   None   None
# 78587   4.84  4.75   0.79    4.76  3.050279    None   None   None
# 68672   4.53  4.84   0.79    4.76  2.886740    None   None   None
# 6689    4.06  4.53   0.83    4.76  2.669219    None   None   None
# 223206  4.53  4.06   0.83    4.84  2.492558    None   None   None
# 368593  3.99  4.53   0.83    4.84  2.231810    None   None   None
# 485708  4.63  3.99   0.83    4.85  2.058393    None   None   None
# 105152  4.44  4.63   0.83    4.95  1.762315    None   None   None
# 354001  3.95  4.44   0.87    5.35  1.451391    None   None   None
# 383247  4.32  3.95   3.89    5.35  1.086476    None   None   None
#
# [65465 rows x 30 columns]

# %% [markdown]
# ### Remove missing values
# Removing any values without the 30 day moving average.
# Use ```np.isfinite``` instead of dropping na values.
#
# **ToDo**
#
#     [ ] should we instead just use a dummy var if any value isna?

# %%
df_pc = df_pc[np.isfinite(df_pc['mavg30'])]
df_pc
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 224889  0.15                         0.03%                        99.97%
# 517425  0.14                         0.03%                        99.95%
# 372849  0.15                         0.00%                        99.95%
# 19242   0.15                         0.00%                        99.98%
# 290846  0.14                         0.00%                       100.00%
# 223081  0.14                         0.00%                       100.00%
# 379310  0.14                         0.00%                       100.00%
# 53862   0.14                         0.00%                        99.98%
# 364756  0.14                         0.00%                       100.00%
# 261106  0.14                         0.00%                       100.00%
# 176764  0.14                         0.00%                       100.00%
# 133083  0.14                         0.00%                       100.00%
# 345014  0.14                         0.00%                       100.00%
# 87142   0.14                         0.00%                       100.00%
# 402246  0.15                         0.03%                        99.97%
# 647464  0.41                         0.00%                       100.00%
# 323603  0.63                         0.00%                       100.00%
# 612303  0.53                         0.00%                       100.00%
# 194527  0.84                         0.00%                       100.00%
# 296372  0.47                         0.00%                       100.00%
# 84678   0.58                         0.00%                       100.00%
# 522874  0.81                         0.00%                       100.00%
# 143704  1.18                         0.00%                       100.00%
# 662668  0.67                         0.00%                       100.00%
# 674645  0.72                         0.00%                       100.00%
# 97865   0.36                         0.00%                       100.00%
# 295219  0.64                         0.00%                       100.00%
# 15518   0.39                         0.00%                       100.00%
# 100562  0.30                         0.00%                       100.00%
# 47650   1.00                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 398598  0.83                         0.00%                       100.00%
# 11834   0.87                         0.00%                       100.00%
# 628953  4.95                        53.42%                        41.10%
# 442180  4.76                        52.33%                        38.37%
# 637841  4.38                        48.72%                        46.15%
# 2247    4.60                        53.03%                        37.88%
# 517566  4.29                        46.74%                        43.48%
# 571478  4.75                        52.63%                        44.74%
# 101274  4.17                        48.78%                        47.56%
# 448045  3.89                        41.57%                        53.93%
# 163177  4.53                        51.28%                        43.59%
# 111217  3.89                        43.30%                        50.52%
# 574483  4.69                        48.28%                        46.55%
# 408335  4.75                        52.94%                        43.14%
# 237476  4.84                        55.00%                        40.00%
# 186598  4.53                        51.47%                        39.71%
# 402151  4.06                        46.75%                        50.65%
# 150145  4.53                        55.41%                        44.59%
# 652283  3.99                        41.30%                        45.65%
# 353997  4.63                        57.41%                        37.04%
# 511490  4.44                        46.05%                        38.16%
# 78587   3.95                        47.44%                        51.28%
# 68672   4.32                        42.67%                        46.67%
# 6689    4.12                        45.59%                        45.59%
# 223206  4.85                        53.52%                        33.80%
# 368593  4.07                        46.97%                        48.48%
# 485708  5.52                        61.40%                        26.32%
# 105152  5.35                        60.42%                        29.17%
# 354001  5.46                        69.01%                        23.94%
# 383247  5.24                        61.11%                        16.67%
#
#                                       Timer Subtimer Name  Number of Records  \
# 224889                         DMSM_GETMEDIACONTENT (N/A)                  1
# 517425                         DMSM_GETMEDIACONTENT (N/A)                  1
# 372849                         DMSM_GETMEDIACONTENT (N/A)                  1
# 19242                          DMSM_GETMEDIACONTENT (N/A)                  1
# 290846                         DMSM_GETMEDIACONTENT (N/A)                  1
# 223081                         DMSM_GETMEDIACONTENT (N/A)                  1
# 379310                         DMSM_GETMEDIACONTENT (N/A)                  1
# 53862                          DMSM_GETMEDIACONTENT (N/A)                  1
# 364756                         DMSM_GETMEDIACONTENT (N/A)                  1
# 261106                         DMSM_GETMEDIACONTENT (N/A)                  1
# 176764                         DMSM_GETMEDIACONTENT (N/A)                  1
# 133083                         DMSM_GETMEDIACONTENT (N/A)                  1
# 345014                         DMSM_GETMEDIACONTENT (N/A)                  1
# 87142                          DMSM_GETMEDIACONTENT (N/A)                  1
# 402246                         DMSM_GETMEDIACONTENT (N/A)                  1
# 647464                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 323603                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 612303                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 194527                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 296372                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 84678                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 522874                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 143704                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 662668                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 674645                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 97865                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 295219                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 15518                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 100562                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 47650                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# ...                                                   ...                ...
# 398598  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 11834   USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 628953        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 442180        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 637841        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 2247          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 517566        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 571478        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 101274        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 448045        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 163177        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 111217        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 574483        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 408335        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 237476        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 186598        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 402151        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 150145        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 652283        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 353997        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 511490        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 78587         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 68672         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 6689          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 223206        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 368593        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 485708        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 105152        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 354001        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 383247        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 224889       POWERCHART 2018-09-17  0.156930          NaN
# 517425       POWERCHART 2018-09-18  0.233025          NaN
# 372849       POWERCHART 2018-09-27  0.101519          NaN
# 19242        POWERCHART 2018-09-28  0.100805          NaN
# 290846       POWERCHART 2018-10-02  0.070028          NaN
# 223081       POWERCHART 2018-10-03  0.062836          NaN
# 379310       POWERCHART 2018-10-09  0.069858          NaN
# 53862        POWERCHART 2018-10-15  0.083543          NaN
# 364756       POWERCHART 2018-10-16  0.075542          NaN
# 261106       POWERCHART 2018-10-18  0.062809          NaN
# 176764       POWERCHART 2018-10-23  0.068284          NaN
# 133083       POWERCHART 2018-10-24  0.069277          NaN
# 345014       POWERCHART 2018-10-30  0.066100          NaN
# 87142        POWERCHART 2018-10-31  0.067762          NaN
# 402246       POWERCHART 2018-11-01  0.509535          NaN
# 647464       POWERCHART 2018-09-21  0.165633          NaN
# 323603       POWERCHART 2018-09-24  0.282050          NaN
# 612303       POWERCHART 2018-09-25  0.368174          NaN
# 194527       POWERCHART 2018-09-26  0.094260          NaN
# 296372       POWERCHART 2018-09-27  0.409663          NaN
# 84678        POWERCHART 2018-09-28  0.178580          NaN
# 522874       POWERCHART 2018-10-01       NaN          NaN
# 143704       POWERCHART 2018-10-02  0.895904          NaN
# 662668       POWERCHART 2018-10-03  0.265165          NaN
# 674645       POWERCHART 2018-10-04  0.420021          NaN
# 97865        POWERCHART 2018-10-05  0.238620          NaN
# 295219       POWERCHART 2018-10-09  0.066468          NaN
# 15518        POWERCHART 2018-10-10  0.228766          NaN
# 100562       POWERCHART 2018-10-11  0.375474          NaN
# 47650        POWERCHART 2018-10-12  0.530330          NaN
# ...                 ...        ...       ...          ...
# 398598       POWERCHART 2018-10-31  0.198602          NaN
# 11834        POWERCHART 2018-11-01  0.196154          NaN
# 628953       POWERCHART 2018-09-19  4.199626          NaN
# 442180       POWERCHART 2018-09-20  3.840833          NaN
# 637841       POWERCHART 2018-09-21  4.157388          NaN
# 2247         POWERCHART 2018-09-24  3.544378          NaN
# 517566       POWERCHART 2018-09-25  3.780417          NaN
# 571478       POWERCHART 2018-09-26  4.128597          NaN
# 101274       POWERCHART 2018-09-27  3.785608          NaN
# 448045       POWERCHART 2018-09-28  3.793539          NaN
# 163177       POWERCHART 2018-10-01  3.758748          NaN
# 111217       POWERCHART 2018-10-02  3.640664          NaN
# 574483       POWERCHART 2018-10-04  5.265499          NaN
# 408335       POWERCHART 2018-10-05  4.127223          NaN
# 237476       POWERCHART 2018-10-08  3.735527          NaN
# 186598       POWERCHART 2018-10-09  3.649069          NaN
# 402151       POWERCHART 2018-10-10  3.760897          NaN
# 150145       POWERCHART 2018-10-11  3.818554          NaN
# 652283       POWERCHART 2018-10-12  3.615590          NaN
# 353997       POWERCHART 2018-10-15  3.448499          NaN
# 511490       POWERCHART 2018-10-16  3.525056          NaN
# 78587        POWERCHART 2018-10-17  3.615882          NaN
# 68672        POWERCHART 2018-10-18  4.040581          NaN
# 6689         POWERCHART 2018-10-19  3.681307          NaN
# 223206       POWERCHART 2018-10-22  3.616620          NaN
# 368593       POWERCHART 2018-10-23  3.770722          NaN
# 485708       POWERCHART 2018-10-24  3.570586          NaN
# 105152       POWERCHART 2018-10-29  3.642358          NaN
# 354001       POWERCHART 2018-10-31  3.018684          NaN
# 383247       POWERCHART 2018-11-01  2.705905          NaN
#
#                                               timername  ...     t-5   t-6  \
# 224889                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 517425                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 372849                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 19242                              DMSM_GETMEDIACONTENT  ...    0.16  0.15
# 290846                             DMSM_GETMEDIACONTENT  ...    0.15  0.16
# 223081                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 379310                             DMSM_GETMEDIACONTENT  ...    0.14  0.15
# 53862                              DMSM_GETMEDIACONTENT  ...    0.15  0.14
# 364756                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 261106                             DMSM_GETMEDIACONTENT  ...    0.14  0.15
# 176764                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 133083                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 345014                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 87142                              DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 402246                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 647464                          DMSM_GETMEDIAOBJECTLIST  ...    0.75  0.91
# 323603                          DMSM_GETMEDIAOBJECTLIST  ...    0.89  0.75
# 612303                          DMSM_GETMEDIAOBJECTLIST  ...    0.70  0.89
# 194527                          DMSM_GETMEDIAOBJECTLIST  ...    1.07  0.70
# 296372                          DMSM_GETMEDIAOBJECTLIST  ...    0.37  1.07
# 84678                           DMSM_GETMEDIAOBJECTLIST  ...    0.41  0.37
# 522874                          DMSM_GETMEDIAOBJECTLIST  ...    0.63  0.41
# 143704                          DMSM_GETMEDIAOBJECTLIST  ...    0.53  0.63
# 662668                          DMSM_GETMEDIAOBJECTLIST  ...    0.84  0.53
# 674645                          DMSM_GETMEDIAOBJECTLIST  ...    0.47  0.84
# 97865                           DMSM_GETMEDIAOBJECTLIST  ...    0.58  0.47
# 295219                          DMSM_GETMEDIAOBJECTLIST  ...    0.81  0.58
# 15518                           DMSM_GETMEDIAOBJECTLIST  ...    1.18  0.81
# 100562                          DMSM_GETMEDIAOBJECTLIST  ...    0.67  1.18
# 47650                           DMSM_GETMEDIAOBJECTLIST  ...    0.72  0.67
# ...                                                 ...  ...     ...   ...
# 398598  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME  ...    0.86  0.90
# 11834   USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME  ...    0.93  0.86
# 628953            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.12  5.00
# 442180            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.96  4.12
# 637841            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.18  4.96
# 2247              USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.72  4.18
# 517566            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.49  4.72
# 571478            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.95  4.49
# 101274            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.76  4.95
# 448045            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.38  4.76
# 163177            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.60  4.38
# 111217            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.29  4.60
# 574483            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.75  4.29
# 408335            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.17  4.75
# 237476            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.89  4.17
# 186598            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  3.89
# 402151            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.89  4.53
# 150145            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.69  3.89
# 652283            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.75  4.69
# 353997            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.84  4.75
# 511490            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  4.84
# 78587             USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.06  4.53
# 68672             USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  4.06
# 6689              USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.99  4.53
# 223206            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.63  3.99
# 368593            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.44  4.63
# 485708            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.95  4.44
# 105152            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.32  3.95
# 354001            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.12  4.32
# 383247            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.85  4.12
#
#          t-7   t-8 LCL_30  UCL_30    var_30  signal  trend  shift
# 224889  0.14  0.15    NaN     NaN       NaN    None   None   None
# 517425  0.15  0.14    NaN     NaN       NaN    None   None   None
# 372849  0.15  0.15    NaN     NaN       NaN    None   None   None
# 19242   0.15  0.15    NaN     NaN       NaN    None   None   None
# 290846  0.15  0.15    NaN     NaN       NaN    None   None   None
# 223081  0.16  0.15    NaN     NaN       NaN    None   None   None
# 379310  0.15  0.16    NaN     NaN       NaN    None   None   None
# 53862   0.15  0.15    NaN     NaN       NaN    None   None   None
# 364756  0.14  0.15    NaN     NaN       NaN    None   None   None
# 261106  0.15  0.14    NaN     NaN       NaN    None   None   None
# 176764  0.15  0.15    NaN     NaN       NaN    None   None   None
# 133083  0.14  0.15    NaN     NaN       NaN    None   None   None
# 345014  0.14  0.14    NaN     NaN       NaN    None   None   None
# 87142   0.14  0.14    NaN     NaN       NaN    None   None   None
# 402246  0.14  0.14    NaN     NaN       NaN    None   None   None
# 647464  0.78  0.90    NaN     NaN       NaN    None   None   None
# 323603  0.91  0.78    NaN     NaN       NaN    None   None   None
# 612303  0.75  0.91    NaN     NaN       NaN    None   None   None
# 194527  0.89  0.75    NaN     NaN       NaN    None   None   None
# 296372  0.70  0.89    NaN     NaN       NaN    None   None   None
# 84678   1.07  0.70    NaN     NaN       NaN    None   None   None
# 522874  0.37  1.07    NaN     NaN       NaN    None   None   None
# 143704  0.41  0.37    NaN     NaN       NaN    None   None   None
# 662668  0.63  0.41    NaN     NaN       NaN    None   None   None
# 674645  0.53  0.63    NaN     NaN       NaN    None   None   None
# 97865   0.84  0.53    NaN     NaN       NaN    None   None   None
# 295219  0.47  0.84    NaN     NaN       NaN    None   None   None
# 15518   0.58  0.47    NaN     NaN       NaN    None   None   None
# 100562  0.81  0.58    NaN     NaN       NaN    None   None   None
# 47650   1.18  0.81   0.14    0.84  0.092133    None   None   None
# ...      ...   ...    ...     ...       ...     ...    ...    ...
# 398598  0.79  0.88   0.75    1.08  0.011389    None   None   None
# 11834   0.90  0.79   0.75    0.93  0.007580    None   None   None
# 628953  5.16  4.04   0.75    0.93  0.570341    None   None   None
# 442180  5.00  5.16   0.75    0.93  1.049587    None   None   None
# 637841  4.12  5.00   0.75    4.38  1.405281    None   None   None
# 2247    4.96  4.12   0.75    4.60  1.779184    None   None   None
# 517566  4.18  4.96   0.75    4.60  2.057524    None   None   None
# 571478  4.72  4.18   0.75    4.75  2.404864    None   None   None
# 101274  4.49  4.72   0.75    4.75  2.603729    None   None   None
# 448045  4.95  4.49   0.75    4.75  2.737103    None   None   None
# 163177  4.76  4.95   0.75    4.75  2.945511    None   None   None
# 111217  4.38  4.76   0.75    4.75  3.023189    None   None   None
# 574483  4.60  4.38   0.75    4.75  3.199092    None   None   None
# 408335  4.29  4.60   0.75    4.75  3.351144    None   None   None
# 237476  4.75  4.29   0.75    4.76  3.491846    None   None   None
# 186598  4.17  4.75   0.75    4.76  3.545075    None   None   None
# 402151  3.89  4.17   0.75    4.76  3.506168    None   None   None
# 150145  4.53  3.89   0.75    4.76  3.494892    None   None   None
# 652283  3.89  4.53   0.75    4.76  3.413081    None   None   None
# 353997  4.69  3.89   0.78    4.76  3.346452    None   None   None
# 511490  4.75  4.69   0.79    4.76  3.221853    None   None   None
# 78587   4.84  4.75   0.79    4.76  3.050279    None   None   None
# 68672   4.53  4.84   0.79    4.76  2.886740    None   None   None
# 6689    4.06  4.53   0.83    4.76  2.669219    None   None   None
# 223206  4.53  4.06   0.83    4.84  2.492558    None   None   None
# 368593  3.99  4.53   0.83    4.84  2.231810    None   None   None
# 485708  4.63  3.99   0.83    4.85  2.058393    None   None   None
# 105152  4.44  4.63   0.83    4.95  1.762315    None   None   None
# 354001  3.95  4.44   0.87    5.35  1.451391    None   None   None
# 383247  4.32  3.95   3.89    5.35  1.086476    None   None   None
#
# [65465 rows x 30 columns]

# %% [markdown]
# ### Signal detection:
#
# - when did the signal start?
# - what is the signal up/down shift or trend?
# - include "magnitude of change"
# - how about cumulative sum?
# - abs(t1-t2) + abs(t2-t3)
# - **Trend**:
#     - look at scipy.stats.linregress module.
#
# **Questions**
#
# - How useful is identifying a spike if we don't have daily data?
# - See .loc access method vs. chained indexing, which I'm currently doing below:
#
# **To-Do**
# - [ ] fit line for last 8 days. Positive = upward trend.
# -

# %% [markdown]
# ### Trend Detection:
# Using linear regression over the last 8 days:
#
# ```pandas.rolling_corr(arg1, arg2=None, window=None, min_periods=None, freq=None, center=False, pairwise=None, how=None)```

# %%
#df_pc_test['roll_corr'] = pd.rolling.corr(df_pc_test['ATRT'], window=7, min_periods=7, freq=None, center=False, pairwise=None, how=None)

# %% [markdown]
# This doesn't work:
#
# ```df_pc_test = df_pc
#
# def lin_regress(df):
#     x = [1, 2, 3, 4, 5, 6, 7, 8]
#     y = df[['t-8', 't-7', 't-6', 't-5', 't-4', 't-3', 't-2', 't-1']]
#     slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#     return r_value**2
#
# df_pc_test['slope'] = df_pc_test.apply(lin_regress, axis=0)```

# %%
df_pc_test = df_pc
df_pc_test

def signal_detect(df):

    if ((df['t-1'] > df['t-2']) 
        and (df['t-2'] > (df['t-3'])
        and (df['t-3'] > (df['t-4'])
        and (df['t-4'] > (df['t-5']))))):
        return 'Upward Trend'

    elif ((df['t-2'] > df['t-3']) 
        and (df['t-3'] > (df['t-4'])
        and (df['t-4'] > (df['t-5'])
        and (df['t-5'] > (df['t-6']))))):
        return 'Upward Trend'
    
    elif ((df['t-2'] > df['t-3']) 
        and (df['t-3'] > (df['t-4'])
        and (df['t-4'] > (df['t-5'])
        and (df['t-5'] > (df['t-6']))))):
        return 'Upward Trend'
    
def shift_detect(df):
    # if 7 of 8 days are above the 30(60) day average, then signal else nothing
    if ((df['t-1'] > df['mavg30'])
        and (df['t-2'] > df['mavg30'])
        and (df['t-3'] > df['mavg30'])
        and (df['t-4'] > df['mavg30'])
        and (df['t-5'] > df['mavg30'])):
        return "Upward Shift"
    
    elif ((df['t-2'] > df['mavg30'])
        and (df['t-3'] > df['mavg30'])
        and (df['t-4'] > df['mavg30'])
        and (df['t-5'] > df['mavg30'])
        and (df['t-6'] > df['mavg30'])):
        return "Upward Shift"

    elif ((df['t-3'] > df['mavg30'])
        and (df['t-4'] > df['mavg30'])
        and (df['t-5'] > df['mavg30'])
        and (df['t-6'] > df['mavg30'])
        and (df['t-7'] > df['mavg30'])):
        return "Upward Shift"
    
df_pc_test['trend'] = df_pc_test.apply(signal_detect, axis=1)
df_pc_test['shift'] = df_pc_test.apply(shift_detect, axis=1)

df_pc_test
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 224889  0.15                         0.03%                        99.97%
# 517425  0.14                         0.03%                        99.95%
# 372849  0.15                         0.00%                        99.95%
# 19242   0.15                         0.00%                        99.98%
# 290846  0.14                         0.00%                       100.00%
# 223081  0.14                         0.00%                       100.00%
# 379310  0.14                         0.00%                       100.00%
# 53862   0.14                         0.00%                        99.98%
# 364756  0.14                         0.00%                       100.00%
# 261106  0.14                         0.00%                       100.00%
# 176764  0.14                         0.00%                       100.00%
# 133083  0.14                         0.00%                       100.00%
# 345014  0.14                         0.00%                       100.00%
# 87142   0.14                         0.00%                       100.00%
# 402246  0.15                         0.03%                        99.97%
# 647464  0.41                         0.00%                       100.00%
# 323603  0.63                         0.00%                       100.00%
# 612303  0.53                         0.00%                       100.00%
# 194527  0.84                         0.00%                       100.00%
# 296372  0.47                         0.00%                       100.00%
# 84678   0.58                         0.00%                       100.00%
# 522874  0.81                         0.00%                       100.00%
# 143704  1.18                         0.00%                       100.00%
# 662668  0.67                         0.00%                       100.00%
# 674645  0.72                         0.00%                       100.00%
# 97865   0.36                         0.00%                       100.00%
# 295219  0.64                         0.00%                       100.00%
# 15518   0.39                         0.00%                       100.00%
# 100562  0.30                         0.00%                       100.00%
# 47650   1.00                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 398598  0.83                         0.00%                       100.00%
# 11834   0.87                         0.00%                       100.00%
# 628953  4.95                        53.42%                        41.10%
# 442180  4.76                        52.33%                        38.37%
# 637841  4.38                        48.72%                        46.15%
# 2247    4.60                        53.03%                        37.88%
# 517566  4.29                        46.74%                        43.48%
# 571478  4.75                        52.63%                        44.74%
# 101274  4.17                        48.78%                        47.56%
# 448045  3.89                        41.57%                        53.93%
# 163177  4.53                        51.28%                        43.59%
# 111217  3.89                        43.30%                        50.52%
# 574483  4.69                        48.28%                        46.55%
# 408335  4.75                        52.94%                        43.14%
# 237476  4.84                        55.00%                        40.00%
# 186598  4.53                        51.47%                        39.71%
# 402151  4.06                        46.75%                        50.65%
# 150145  4.53                        55.41%                        44.59%
# 652283  3.99                        41.30%                        45.65%
# 353997  4.63                        57.41%                        37.04%
# 511490  4.44                        46.05%                        38.16%
# 78587   3.95                        47.44%                        51.28%
# 68672   4.32                        42.67%                        46.67%
# 6689    4.12                        45.59%                        45.59%
# 223206  4.85                        53.52%                        33.80%
# 368593  4.07                        46.97%                        48.48%
# 485708  5.52                        61.40%                        26.32%
# 105152  5.35                        60.42%                        29.17%
# 354001  5.46                        69.01%                        23.94%
# 383247  5.24                        61.11%                        16.67%
#
#                                       Timer Subtimer Name  Number of Records  \
# 224889                         DMSM_GETMEDIACONTENT (N/A)                  1
# 517425                         DMSM_GETMEDIACONTENT (N/A)                  1
# 372849                         DMSM_GETMEDIACONTENT (N/A)                  1
# 19242                          DMSM_GETMEDIACONTENT (N/A)                  1
# 290846                         DMSM_GETMEDIACONTENT (N/A)                  1
# 223081                         DMSM_GETMEDIACONTENT (N/A)                  1
# 379310                         DMSM_GETMEDIACONTENT (N/A)                  1
# 53862                          DMSM_GETMEDIACONTENT (N/A)                  1
# 364756                         DMSM_GETMEDIACONTENT (N/A)                  1
# 261106                         DMSM_GETMEDIACONTENT (N/A)                  1
# 176764                         DMSM_GETMEDIACONTENT (N/A)                  1
# 133083                         DMSM_GETMEDIACONTENT (N/A)                  1
# 345014                         DMSM_GETMEDIACONTENT (N/A)                  1
# 87142                          DMSM_GETMEDIACONTENT (N/A)                  1
# 402246                         DMSM_GETMEDIACONTENT (N/A)                  1
# 647464                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 323603                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 612303                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 194527                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 296372                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 84678                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 522874                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 143704                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 662668                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 674645                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 97865                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 295219                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 15518                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 100562                      DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# 47650                       DMSM_GETMEDIAOBJECTLIST (N/A)                  1
# ...                                                   ...                ...
# 398598  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 11834   USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAM...                  1
# 628953        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 442180        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 637841        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 2247          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 517566        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 571478        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 101274        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 448045        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 163177        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 111217        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 574483        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 408335        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 237476        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 186598        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 402151        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 150145        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 652283        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 353997        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 511490        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 78587         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 68672         USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 6689          USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 223206        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 368593        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 485708        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 105152        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 354001        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 383247        USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 224889       POWERCHART 2018-09-17  0.156930          NaN
# 517425       POWERCHART 2018-09-18  0.233025          NaN
# 372849       POWERCHART 2018-09-27  0.101519          NaN
# 19242        POWERCHART 2018-09-28  0.100805          NaN
# 290846       POWERCHART 2018-10-02  0.070028          NaN
# 223081       POWERCHART 2018-10-03  0.062836          NaN
# 379310       POWERCHART 2018-10-09  0.069858          NaN
# 53862        POWERCHART 2018-10-15  0.083543          NaN
# 364756       POWERCHART 2018-10-16  0.075542          NaN
# 261106       POWERCHART 2018-10-18  0.062809          NaN
# 176764       POWERCHART 2018-10-23  0.068284          NaN
# 133083       POWERCHART 2018-10-24  0.069277          NaN
# 345014       POWERCHART 2018-10-30  0.066100          NaN
# 87142        POWERCHART 2018-10-31  0.067762          NaN
# 402246       POWERCHART 2018-11-01  0.509535          NaN
# 647464       POWERCHART 2018-09-21  0.165633          NaN
# 323603       POWERCHART 2018-09-24  0.282050          NaN
# 612303       POWERCHART 2018-09-25  0.368174          NaN
# 194527       POWERCHART 2018-09-26  0.094260          NaN
# 296372       POWERCHART 2018-09-27  0.409663          NaN
# 84678        POWERCHART 2018-09-28  0.178580          NaN
# 522874       POWERCHART 2018-10-01       NaN          NaN
# 143704       POWERCHART 2018-10-02  0.895904          NaN
# 662668       POWERCHART 2018-10-03  0.265165          NaN
# 674645       POWERCHART 2018-10-04  0.420021          NaN
# 97865        POWERCHART 2018-10-05  0.238620          NaN
# 295219       POWERCHART 2018-10-09  0.066468          NaN
# 15518        POWERCHART 2018-10-10  0.228766          NaN
# 100562       POWERCHART 2018-10-11  0.375474          NaN
# 47650        POWERCHART 2018-10-12  0.530330          NaN
# ...                 ...        ...       ...          ...
# 398598       POWERCHART 2018-10-31  0.198602          NaN
# 11834        POWERCHART 2018-11-01  0.196154          NaN
# 628953       POWERCHART 2018-09-19  4.199626          NaN
# 442180       POWERCHART 2018-09-20  3.840833          NaN
# 637841       POWERCHART 2018-09-21  4.157388          NaN
# 2247         POWERCHART 2018-09-24  3.544378          NaN
# 517566       POWERCHART 2018-09-25  3.780417          NaN
# 571478       POWERCHART 2018-09-26  4.128597          NaN
# 101274       POWERCHART 2018-09-27  3.785608          NaN
# 448045       POWERCHART 2018-09-28  3.793539          NaN
# 163177       POWERCHART 2018-10-01  3.758748          NaN
# 111217       POWERCHART 2018-10-02  3.640664          NaN
# 574483       POWERCHART 2018-10-04  5.265499          NaN
# 408335       POWERCHART 2018-10-05  4.127223          NaN
# 237476       POWERCHART 2018-10-08  3.735527          NaN
# 186598       POWERCHART 2018-10-09  3.649069          NaN
# 402151       POWERCHART 2018-10-10  3.760897          NaN
# 150145       POWERCHART 2018-10-11  3.818554          NaN
# 652283       POWERCHART 2018-10-12  3.615590          NaN
# 353997       POWERCHART 2018-10-15  3.448499          NaN
# 511490       POWERCHART 2018-10-16  3.525056          NaN
# 78587        POWERCHART 2018-10-17  3.615882          NaN
# 68672        POWERCHART 2018-10-18  4.040581          NaN
# 6689         POWERCHART 2018-10-19  3.681307          NaN
# 223206       POWERCHART 2018-10-22  3.616620          NaN
# 368593       POWERCHART 2018-10-23  3.770722          NaN
# 485708       POWERCHART 2018-10-24  3.570586          NaN
# 105152       POWERCHART 2018-10-29  3.642358          NaN
# 354001       POWERCHART 2018-10-31  3.018684          NaN
# 383247       POWERCHART 2018-11-01  2.705905          NaN
#
#                                               timername  ...     t-5   t-6  \
# 224889                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 517425                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 372849                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 19242                              DMSM_GETMEDIACONTENT  ...    0.16  0.15
# 290846                             DMSM_GETMEDIACONTENT  ...    0.15  0.16
# 223081                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 379310                             DMSM_GETMEDIACONTENT  ...    0.14  0.15
# 53862                              DMSM_GETMEDIACONTENT  ...    0.15  0.14
# 364756                             DMSM_GETMEDIACONTENT  ...    0.15  0.15
# 261106                             DMSM_GETMEDIACONTENT  ...    0.14  0.15
# 176764                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 133083                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 345014                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 87142                              DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 402246                             DMSM_GETMEDIACONTENT  ...    0.14  0.14
# 647464                          DMSM_GETMEDIAOBJECTLIST  ...    0.75  0.91
# 323603                          DMSM_GETMEDIAOBJECTLIST  ...    0.89  0.75
# 612303                          DMSM_GETMEDIAOBJECTLIST  ...    0.70  0.89
# 194527                          DMSM_GETMEDIAOBJECTLIST  ...    1.07  0.70
# 296372                          DMSM_GETMEDIAOBJECTLIST  ...    0.37  1.07
# 84678                           DMSM_GETMEDIAOBJECTLIST  ...    0.41  0.37
# 522874                          DMSM_GETMEDIAOBJECTLIST  ...    0.63  0.41
# 143704                          DMSM_GETMEDIAOBJECTLIST  ...    0.53  0.63
# 662668                          DMSM_GETMEDIAOBJECTLIST  ...    0.84  0.53
# 674645                          DMSM_GETMEDIAOBJECTLIST  ...    0.47  0.84
# 97865                           DMSM_GETMEDIAOBJECTLIST  ...    0.58  0.47
# 295219                          DMSM_GETMEDIAOBJECTLIST  ...    0.81  0.58
# 15518                           DMSM_GETMEDIAOBJECTLIST  ...    1.18  0.81
# 100562                          DMSM_GETMEDIAOBJECTLIST  ...    0.67  1.18
# 47650                           DMSM_GETMEDIAOBJECTLIST  ...    0.72  0.67
# ...                                                 ...  ...     ...   ...
# 398598  USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME  ...    0.86  0.90
# 11834   USR:WH-DELIVERY RECORD-CHANGE RESULTS TIMEFRAME  ...    0.93  0.86
# 628953            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.12  5.00
# 442180            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.96  4.12
# 637841            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.18  4.96
# 2247              USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.72  4.18
# 517566            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.49  4.72
# 571478            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.95  4.49
# 101274            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.76  4.95
# 448045            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.38  4.76
# 163177            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.60  4.38
# 111217            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.29  4.60
# 574483            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.75  4.29
# 408335            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.17  4.75
# 237476            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.89  4.17
# 186598            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  3.89
# 402151            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.89  4.53
# 150145            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.69  3.89
# 652283            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.75  4.69
# 353997            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.84  4.75
# 511490            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  4.84
# 78587             USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.06  4.53
# 68672             USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.53  4.06
# 6689              USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.99  4.53
# 223206            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.63  3.99
# 368593            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.44  4.63
# 485708            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    3.95  4.44
# 105152            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.32  3.95
# 354001            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.12  4.32
# 383247            USR:WH-DELIVERY RECORD-ENSURE RESULTS  ...    4.85  4.12
#
#          t-7   t-8 LCL_30  UCL_30    var_30  signal  trend  shift
# 224889  0.14  0.15    NaN     NaN       NaN    None   None   None
# 517425  0.15  0.14    NaN     NaN       NaN    None   None   None
# 372849  0.15  0.15    NaN     NaN       NaN    None   None   None
# 19242   0.15  0.15    NaN     NaN       NaN    None   None   None
# 290846  0.15  0.15    NaN     NaN       NaN    None   None   None
# 223081  0.16  0.15    NaN     NaN       NaN    None   None   None
# 379310  0.15  0.16    NaN     NaN       NaN    None   None   None
# 53862   0.15  0.15    NaN     NaN       NaN    None   None   None
# 364756  0.14  0.15    NaN     NaN       NaN    None   None   None
# 261106  0.15  0.14    NaN     NaN       NaN    None   None   None
# 176764  0.15  0.15    NaN     NaN       NaN    None   None   None
# 133083  0.14  0.15    NaN     NaN       NaN    None   None   None
# 345014  0.14  0.14    NaN     NaN       NaN    None   None   None
# 87142   0.14  0.14    NaN     NaN       NaN    None   None   None
# 402246  0.14  0.14    NaN     NaN       NaN    None   None   None
# 647464  0.78  0.90    NaN     NaN       NaN    None   None   None
# 323603  0.91  0.78    NaN     NaN       NaN    None   None   None
# 612303  0.75  0.91    NaN     NaN       NaN    None   None   None
# 194527  0.89  0.75    NaN     NaN       NaN    None   None   None
# 296372  0.70  0.89    NaN     NaN       NaN    None   None   None
# 84678   1.07  0.70    NaN     NaN       NaN    None   None   None
# 522874  0.37  1.07    NaN     NaN       NaN    None   None   None
# 143704  0.41  0.37    NaN     NaN       NaN    None   None   None
# 662668  0.63  0.41    NaN     NaN       NaN    None   None   None
# 674645  0.53  0.63    NaN     NaN       NaN    None   None   None
# 97865   0.84  0.53    NaN     NaN       NaN    None   None   None
# 295219  0.47  0.84    NaN     NaN       NaN    None   None   None
# 15518   0.58  0.47    NaN     NaN       NaN    None   None   None
# 100562  0.81  0.58    NaN     NaN       NaN    None   None   None
# 47650   1.18  0.81   0.14    0.84  0.092133    None   None   None
# ...      ...   ...    ...     ...       ...     ...    ...    ...
# 398598  0.79  0.88   0.75    1.08  0.011389    None   None   None
# 11834   0.90  0.79   0.75    0.93  0.007580    None   None   None
# 628953  5.16  4.04   0.75    0.93  0.570341    None   None   None
# 442180  5.00  5.16   0.75    0.93  1.049587    None   None   None
# 637841  4.12  5.00   0.75    4.38  1.405281    None   None   None
# 2247    4.96  4.12   0.75    4.60  1.779184    None   None   None
# 517566  4.18  4.96   0.75    4.60  2.057524    None   None   None
# 571478  4.72  4.18   0.75    4.75  2.404864    None   None   None
# 101274  4.49  4.72   0.75    4.75  2.603729    None   None   None
# 448045  4.95  4.49   0.75    4.75  2.737103    None   None   None
# 163177  4.76  4.95   0.75    4.75  2.945511    None   None   None
# 111217  4.38  4.76   0.75    4.75  3.023189    None   None   None
# 574483  4.60  4.38   0.75    4.75  3.199092    None   None   None
# 408335  4.29  4.60   0.75    4.75  3.351144    None   None   None
# 237476  4.75  4.29   0.75    4.76  3.491846    None   None   None
# 186598  4.17  4.75   0.75    4.76  3.545075    None   None   None
# 402151  3.89  4.17   0.75    4.76  3.506168    None   None   None
# 150145  4.53  3.89   0.75    4.76  3.494892    None   None   None
# 652283  3.89  4.53   0.75    4.76  3.413081    None   None   None
# 353997  4.69  3.89   0.78    4.76  3.346452    None   None   None
# 511490  4.75  4.69   0.79    4.76  3.221853    None   None   None
# 78587   4.84  4.75   0.79    4.76  3.050279    None   None   None
# 68672   4.53  4.84   0.79    4.76  2.886740    None   None   None
# 6689    4.06  4.53   0.83    4.76  2.669219    None   None   None
# 223206  4.53  4.06   0.83    4.84  2.492558    None   None   None
# 368593  3.99  4.53   0.83    4.84  2.231810    None   None   None
# 485708  4.63  3.99   0.83    4.85  2.058393    None   None   None
# 105152  4.44  4.63   0.83    4.95  1.762315    None   None   None
# 354001  3.95  4.44   0.87    5.35  1.451391    None   None   None
# 383247  4.32  3.95   3.89    5.35  1.086476    None   None   None
#
# [65465 rows x 30 columns]

# %% [markdown]
# ### Investigate the data on a weekly basis
# Counts
# Sums
# Averages
# Variance

# %% [markdown]
# ### Write out to csv:

# %%
df_pc_test.to_csv('C:\\Users\\khickman1\\Desktop\\PCMavg30.csv', sep=',')

# %% [markdown]
# ### Stuff I learned:
#
# - Moving average example
# - Subsetting
# - Date and column filtering
# - Index by both date and by timer/subtimer using pandas 'set index'
# - Indexing
# - Sorting
# - Get unique values
# - grouping
# - filtering outliers (clipping, trimming, winsorizing)
# - moving data
#
# ```
# open_chart = atrt_df['Timer Subtimer Name' == "USR:PWR-OPEN CHART (DISCERNRPT/DISCERNPCTAB.DLL)"]
# open_chart = atrt_df[atrt_df['Timer Subtimer Name'] == 'USR:PWR-OPEN CHART (DISCERNRPT/DISCERNPCTAB.DLL)']
# open_chart = open_chart[open_chart['application_name']== 'POWERCHART']
# open_chart_post = open_chart[(open_chart['dt'] > '2018-07-01') & (open_chart['dt'] < '2018-09-30')]
# open_chart = open_chart.set_index(['Timer Subtimer Name', 'dt'])
# open_chart = open_chart.sort_index(axis=0)
# open_chart['moving_avg'] = open_chart['ATRT'].rolling(30).mean()
# atrt_df['dt'] = pd.to_datetime(atrt_df['dt'].dt.date)
# atrt_high_trans = atrt_df[atrt_df['transaction_cnt'] > 1000]
# atrt_high_trans.sort_values(by=['transaction_cnt'], ascending=False)
# len(atrt_high_trans)
# grp_high_trans = atrt_high_trans.groupby(["Timer Subtimer Name", "dt"])
# grp_high_trans.head()
# open_chart_post.groupby('Timer Subtimer Name').nunique()
# len(open_chart_post['Timer Subtimer Name'].unique())
# len(open_chart_post)
# open_chart_slim = open_chart_post[['ATRT', 'dt']]
# open_chart_slim.set_index('dt')
# open_chart_slim.sort_values('dt')
#
# Stuff that didn't work
# #atrt_df_PC = atrt_df_PC[['Timer Subtimer Name', 'dt', 'ATRT', 'application_name']]
# #atrt_df_PC['mavg30'] = atrt_df_PC['ATRT'].rolling(30).mean()
# #PC = atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])
# #atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name', 'dt'])
# #PC = atrt_df_PC
# #PC.head()
# #atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name'])
# #atrt_df_PC = atrt_df_PC.sort_index(axis=0)
# #atrt_df_PC = atrt_df_PC.groupby(['Timer Subtimer Name'])
# #atrt_df_PC = atrt_df_PC.sort(['Timer Subtimer Name', 'dt']).groupby('Timer Subtimer Name')
# #atrt_df_PC['mavg30'] = atrt_df_PC['ATRT'].rolling(30).mean()
# #atrt_df_PC[0:100]```

# %% [markdown]
# Getting csv from website example
# ```
# import csv
# import urllib3
# import requests
#
# #This URL will be the URL that your login form points to with the "action" tag.
# post_login_url = 'https://cernercare.com/accounts/login?returnTo=https%3A%2F%2Flightson.cerner.com%2Fsocial-auth%2Fcomplete%2Fprofessional%2F%3Fjanrain_nonce%3D2018-10-23T15%253A00%253A41ZYe3mOd'
#
# #This URL is the page you actually want to pull down with requests.
# request_url = 'https://lightson.cerner.com/clients/CHP_IN/domains/P1558/kpi/response-time/worst-timers.csv?dt=2018-10-22'
# #request_url = 'https://lightson.cerner.com/api/metrics/trend.csv?category_name=Performance&metrics%5B%5D=RT_2SEC&cdr_ids=95370&data_type=ENVIRONMENT&date_type=DAILY&days_of_week=1%2C2%2C3%2C4%2C5%2C6%2C7&doc_cuid=LONfa31c997c3d543768036e2941&end_date=2018-10-22&physician_rollup_flag=2&start_date=2018-07-25'
#
# payload = {
#     'username': 'khickman1',
#     'pass': '<password>'
# }
#
# with requests.Session() as session:
#     post = session.post(post_login_url, data=payload)
#     r = session.get(request_url)
#     decoded_content = r.content.decode('utf-8')
#     cr = csv.reader(decoded_content.splitlines(), delimiter=',')
#     my_list = list(cr)
#     for row in my_list:
#         print(row)
#
# for row in cr:
#     with open("daily.csv", "wb") as f:
#         writer = csv.writer(f)
#         writer.writerows(row)
# ```
