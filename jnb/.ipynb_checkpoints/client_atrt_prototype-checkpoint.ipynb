# %% [markdown]
# # Weekly Core Metric Analysis
#
# This notebook provides pre-processing, analysis, and visualization on weekly ATRT data provided by Cerner (Armand Kok) in a .csv dataset that includes daily (aggregated) timer data, transaction counts, etc... for a 90-day lookback period.
#
# 10/26:
# - **Business questions**:
#     - Which timers are negatively affecting ATRT?
#     - What is the makeup of ATRT for a given period, and how has that changed over the previous periods?
#     - When did a shift begin for a particular timer?
#     - What are the smoothed trends for our core metrics overall?
#     - What is our ATRT for relative dates (month to date, past 30/60/90, etc).
#
# **To-do**
# - consider moving to 120 day lookback period for control charts.

# %%
# Import libraries/packages

import csv
import pandas as pd
import datetime
import numpy as np
import os
from datetime import datetime 
from pandas.tseries.offsets import BDay
from scipy.stats.mstats import winsorize
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import dataset and make sure it's working.
# **To-do**:
# - 10/25 automate dataset generation. Use case for hook into Vertica: Armand is currently manually giving this ds weekly.
# - 10/25 find best place to store to capture history

# %%
#client_atrt = pd.read_csv('Z:\IUH\khickman1\Datasets\client_atrt10.15.18.csv')
client_atrt = pd.read_csv('C:\\Users\\khickman1\\Desktop\\client_atrt10.22.csv')
#client_atrt = client_atrt[['dt', 'application_name', 'Timer Subtimer Name', 'ATRT']]
client_atrt.head()
len(client_atrt) #should be around 650-680k rows
# Out:
# 672015

# %% [markdown]
# ## Preprocessing
#
#  - Dates
#  - Filtering
#  - Outlier removal
#  - moving average calculation
#
# ### Date column transformation

# %%
atrt_df = pd.DataFrame(client_atrt)
atrt_df['dt'] = pd.to_datetime(atrt_df['dt'])
print(atrt_df['dt'][0:10])
atrt_df.head()
# check to make sure the 'dt' column is type:datetime64
# Out:
# 0   2018-08-19
# 1   2018-07-27
# 2   2018-08-24
# 3   2018-09-14
# 4   2018-09-04
# 5   2018-09-27
# 6   2018-08-01
# 7   2018-08-04
# 8   2018-09-11
# 9   2018-10-04
# Name: dt, dtype: datetime64[ns]
#    ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 0  2.90                         0.08%                         7.57%
# 1  0.04                         0.00%                       100.00%
# 2  0.22                         0.00%                       100.00%
# 3  0.85                         0.02%                        99.88%
# 4  2.11                         0.00%                        66.67%
#
#                                  Timer Subtimer Name  Number of Records  \
# 0                    USR: PN AUTOPOPULATE DATA (N/A)                  1
# 1  USR:SRG SNDOCDISP DISCONTINUING SEGMENT (UN TO...                  1
# 2  USR:MPG.POC SUMMARY COMPONENT - LOAD COMPONENT...                  1
# 3                   USR:BSC-ENSURE MAW RESULTS (N/A)                  1
# 4  USR:MPG.NEW_ORDER_ENTRY.O2 - LOAD COMPONENT (V...                  1
#
#   application_name         dt      strt             subtimername  \
# 0         FIRSTNET 2018-08-19  0.562857                      NaN
# 1   POWERCHART.EXE 2018-07-27       NaN            UN TOURNIQUET
# 2         FIRSTNET 2018-08-24       NaN                      NaN
# 3       POWERCHART 2018-09-14  0.225968                      NaN
# 4       POWERCHART 2018-09-04  0.615354  VB_WORKFLOWAMBPEDSPSYCH
#
#                                         timername  total_elapsed  transAbove5  \
# 0                       USR: PN AUTOPOPULATE DATA    3482.946764            1
# 1         USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.035208            0
# 2  USR:MPG.POC SUMMARY COMPONENT - LOAD COMPONENT       0.221000            0
# 3                      USR:BSC-ENSURE MAW RESULTS   31670.881000            8
# 4     USR:MPG.NEW_ORDER_ENTRY.O2 - LOAD COMPONENT       6.338292            0
#
#    transUnder2  transaction_cnt
# 0           91             1202
# 1            1                1
# 2            1                1
# 3        37109            37153
# 4            2                3

# %% [markdown]
# ### Remove non-working days.
#
# Currently only removing weekends.
# **To-do**
# - remove federal/bank holidays?  E.g. sept 3 was labor day.

# %%
isBusinessDay = BDay().onOffset
match_series = atrt_df['dt'].map(isBusinessDay)
atrt_df['isBDay'] = atrt_df['dt'][match_series]
atrt_df
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 0       2.90                         0.08%                         7.57%
# 1       0.04                         0.00%                       100.00%
# 2       0.22                         0.00%                       100.00%
# 3       0.85                         0.02%                        99.88%
# 4       2.11                         0.00%                        66.67%
# 5       0.49                         0.07%                        98.56%
# 6       0.40                         0.00%                       100.00%
# 7       0.52                         0.00%                       100.00%
# 8       0.00                         0.00%                       100.00%
# 9       0.19                         0.00%                       100.00%
# 10      0.93                         0.00%                       100.00%
# 11      0.24                         0.00%                       100.00%
# 12      0.07                         0.00%                       100.00%
# 13      0.21                         0.00%                       100.00%
# 14      0.05                         0.00%                       100.00%
# 15      0.13                         0.00%                       100.00%
# 16      0.20                         0.00%                        99.84%
# 17      0.27                         0.00%                       100.00%
# 18      0.42                         0.00%                       100.00%
# 19      0.06                         0.00%                       100.00%
# 20      0.14                         0.00%                       100.00%
# 21      0.19                         0.00%                       100.00%
# 22      0.04                         0.00%                       100.00%
# 23      0.13                         0.00%                       100.00%
# 24      0.67                         0.00%                        92.98%
# 25      0.26                         0.00%                       100.00%
# 26      0.27                         0.00%                       100.00%
# 27      0.86                         0.00%                        91.18%
# 28      0.52                         0.00%                       100.00%
# 29      0.55                         0.40%                        96.39%
# ...      ...                           ...                           ...
# 671985  0.10                         0.00%                       100.00%
# 671986  0.49                         0.00%                       100.00%
# 671987  0.25                         0.00%                       100.00%
# 671988  0.08                         0.00%                       100.00%
# 671989  0.08                         0.02%                        99.98%
# 671990  0.93                         0.00%                        96.47%
# 671991  1.56                         0.00%                        80.00%
# 671992  0.49                         0.00%                       100.00%
# 671993  1.27                         1.08%                        94.84%
# 671994  1.79                         0.58%                        72.05%
# 671995  0.76                         0.00%                        95.16%
# 671996  0.60                         0.00%                        96.43%
# 671997  1.59                         1.00%                        72.00%
# 671998  0.08                         0.16%                        99.84%
# 671999  1.97                         0.00%                       100.00%
# 672000  1.17                         0.56%                        96.64%
# 672001  0.97                         0.00%                       100.00%
# 672002  0.31                         0.00%                        99.20%
# 672003  0.30                         0.00%                       100.00%
# 672004  0.56                         0.00%                       100.00%
# 672005  0.00                         0.00%                       100.00%
# 672006  0.04                         0.00%                       100.00%
# 672007  1.14                         5.00%                        85.00%
# 672008  0.04                         0.00%                       100.00%
# 672009  1.77                         7.25%                        85.51%
# 672010  0.03                         0.00%                       100.00%
# 672011  0.42                         0.24%                        96.91%
# 672012  0.10                         0.00%                       100.00%
# 672013  1.73                         1.44%                        75.00%
# 672014  1.20                         0.00%                        82.14%
#
#                                       Timer Subtimer Name  Number of Records  \
# 0                         USR: PN AUTOPOPULATE DATA (N/A)                  1
# 1       USR:SRG SNDOCDISP DISCONTINUING SEGMENT (UN TO...                  1
# 2       USR:MPG.POC SUMMARY COMPONENT - LOAD COMPONENT...                  1
# 3                        USR:BSC-ENSURE MAW RESULTS (N/A)                  1
# 4       USR:MPG.NEW_ORDER_ENTRY.O2 - LOAD COMPONENT (V...                  1
# 5       USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT (V...                  1
# 6       USR:SRG SNDOCDISP LOADING SEGMENT (WHIEC CASE ...                  1
# 7       USR:SRG SNDOCDISP SAVING SEGMENT (BLH ENDO CAS...                  1
# 8                 USR:ORM.SIGNORDERS-NONMEDDUPCHECK (N/A)                  1
# 9       USR:SRG SNDOCDISP LOADING SEGMENT (NH ENDO IMP...                  1
# 10      USR:SRG SNDOCDISP SAVING SEGMENT (AH ENDO PREO...                  1
# 11      USR:SRG SNDOCDISP LOADING SEGMENT (AH OB SKIN ...                  1
# 12                     USR:ORM.LOADORDERINFOADDINFO (N/A)                  1
# 13      USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 14      USR: PDOC NAVIGATOR DOC SET CLICK (PICU TREATM...                  1
# 15      USR:SRG SNDOCDISP SAVING SEGMENT (UN RAD MONIT...                  1
# 16      USR:MPG.IO.O1 - LOAD COMPONENT (VB_IUHINPATIEN...                  1
# 17      USR:SRG SNDOCDISP LOADING SEGMENT (WH MEDICATI...                  1
# 18      USR:ICU-IVIEW-ACTIVATE AN INACTIVE REPEATABLE ...                  1
# 19      USR:SRG SNDOCDISP LOADING SEGMENT (THERMOREGUL...                  1
# 20      USR:SRG SNDOCDISP SAVING SEGMENT (JC CHARTABLE...                  1
# 21      USR:SRG SNDOCDISP LOADING SEGMENT (SASC MEDICA...                  1
# 22      USR:SRG SNDOCDISP DISCONTINUING SEGMENT (AH HE...                  1
# 23      USR:SRG SNDOCDISP LOADING SEGMENT (NH OB HEMOS...                  1
# 24      USR:MPG.SCALEASSESS.WF - LOAD COMPONENT (VB_WO...                  1
# 25      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 26                   USR: CRADFDETAILFORM.FORM_LOAD (N/A)                  1
# 27      USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 28      USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT (V...                  1
# 29      USR:MPG.MEDS.O1 - LOAD COMPONENT (VB_IUHNEONAT...                  1
# ...                                                   ...                ...
# 671985      USR:SRG SNDOCDISP LOADING SEGMENT (UH COUNTS)                  1
# 671986  USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT (V...                  1
# 671987  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 671988  USR:SRG SNDOCDISP SAVING SEGMENT (BLH RAD IMPL...                  1
# 671989  USR:ERM PMACTION CLIENT/FACILITY SEARCH (FACIL...                  1
# 671990              USR: ICU-OPENING-BAND (ACTIVITY VIEW)                  1
# 671991  USR:ERM PMACTION SEARCH TO CONVERSATION READY ...                  1
# 671992  USR: PDOC NAVIGATOR BAND CLICK (ADULT ICU ADLS...                  1
# 671993  USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB (VB_WOR...                  1
# 671994                       USR:ORM.ACCEPTRXREFILL (N/A)                  1
# 671995  USR: PDOC NAVIGATOR BAND CLICK (ADULT SS PHYSI...                  1
# 671996  USR: PDOC NAVIGATOR BAND CLICK (ADULT MS PHYSI...                  1
# 671997  USR:MPG.LABORATORY.WF - LOAD COMPONENT (VB_WOR...                  1
# 671998  USR:ERM PMACTION CLIENT/FACILITY SEARCH (FACIL...                  1
# 671999  USR:ERM PMACTION SEARCH TO CONVERSATION READY ...                  1
# 672000  USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB (VB_WOR...                  1
# 672001  USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 672002  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 672003  USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT (V...                  1
# 672004  USR:SRG SNDOCDISP SAVING SEGMENT (WVSC SPECIME...                  1
# 672005              USR:ORM.CLAIMSHXSPREADCONVERTHX (N/A)                  1
# 672006  USR:SRG SNDOCDISP DISCONTINUING SEGMENT (AAS D...                  1
# 672007  USR:MPG.ALLERGY.O2 - LOAD COMPONENT (VB_WORKFL...                  1
# 672008  USR:SRG SNDOCDISP DISCONTINUING SEGMENT (BMH D...                  1
# 672009  USR:MPG.RECOMMENDATIONS.O2 - LOAD COMPONENT (V...                  1
# 672010  USR:SRG SNDOCDISP DISCONTINUING SEGMENT (WH IN...                  1
# 672011       USR:ORM.BATCHLOADFORMULARYINFOVERSION3 (N/A)                  1
# 672012  USR:SRG SNDOCDISP LOADING SEGMENT (AAS PACU PH...                  1
# 672013         USR:PWR-OPEN CHART (FLOWSHEET/PVFLOWSHEET)                  1
# 672014  USR:SRG SNDOCDISP SAVING SEGMENT (BLH CASE ATT...                  1
#
#                 application_name         dt      strt  \
# 0                       FIRSTNET 2018-08-19  0.562857
# 1                 POWERCHART.EXE 2018-07-27       NaN
# 2                       FIRSTNET 2018-08-24       NaN
# 3                     POWERCHART 2018-09-14  0.225968
# 4                     POWERCHART 2018-09-04  0.615354
# 5                     POWERCHART 2018-09-27  0.397299
# 6                 SNSURGINET.EXE 2018-08-01  0.049202
# 7                 SNSURGINET.EXE 2018-08-04  0.494043
# 8                     POWERCHART 2018-09-11  0.002295
# 9                 SNSURGINET.EXE 2018-10-04  0.013296
# 10                SNSURGINET.EXE 2018-09-25  0.237150
# 11                POWERCHART.EXE 2018-08-09  0.028213
# 12                    POWERCHART 2018-10-13  0.014620
# 13                    POWERCHART 2018-09-20  0.043101
# 14                    POWERCHART 2018-07-22       NaN
# 15                POWERCHART.EXE 2018-08-14  0.044752
# 16                    POWERCHART 2018-09-22  0.202711
# 17                SNSURGINET.EXE 2018-10-04  0.341903
# 18                    POWERCHART 2018-07-26  0.089713
# 19                SNSURGINET.EXE 2018-07-20  0.039932
# 20                SNSURGINET.EXE 2018-09-28  0.104317
# 21                SNSURGINET.EXE 2018-08-28  0.235191
# 22                SNSURGINET.EXE 2018-08-31  0.009852
# 23                POWERCHART.EXE 2018-09-06  0.023526
# 24                    POWERCHART 2018-09-23  0.761511
# 25                    POWERCHART 2018-07-29  0.183897
# 26      RADRADIOLOGISTTOTALS.EXE 2018-09-06       NaN
# 27                    POWERCHART 2018-09-19  0.806611
# 28                    POWERCHART 2018-08-21  0.130344
# 29                    POWERCHART 2018-08-20  0.750812
# ...                          ...        ...       ...
# 671985            SNSURGINET.EXE 2018-07-30  0.070166
# 671986                POWERCHART 2018-09-15  0.166105
# 671987                POWERCHART 2018-08-24  0.188118
# 671988            SNSURGINET.EXE 2018-09-17       NaN
# 671989                  PMOFFICE 2018-07-25  0.099116
# 671990                  FIRSTNET 2018-10-14  0.419962
# 671991                  PMOFFICE 2018-08-08  0.354032
# 671992                SNSURGINET 2018-08-16  0.268463
# 671993                POWERCHART 2018-09-17  0.784020
# 671994                POWERCHART 2018-07-23  0.942257
# 671995                  FIRSTNET 2018-08-22  0.732784
# 671996                  FIRSTNET 2018-08-25  0.668151
# 671997                POWERCHART 2018-10-12  1.325320
# 671998                  PMOFFICE 2018-08-18  0.292400
# 671999                  PMOFFICE 2018-09-28       NaN
# 672000                POWERCHART 2018-10-11  0.599969
# 672001                POWERCHART 2018-09-06  0.320734
# 672002                POWERCHART 2018-08-15  0.326089
# 672003                SNSURGINET 2018-07-28  0.077221
# 672004            POWERCHART.EXE 2018-09-06  0.500273
# 672005                POWERCHART 2018-09-28  0.000032
# 672006            SNSURGINET.EXE 2018-07-19  0.013553
# 672007                POWERCHART 2018-08-24  1.316103
# 672008            SNSURGINET.EXE 2018-09-22  0.005595
# 672009                POWERCHART 2018-09-16  1.678858
# 672010            SNSURGINET.EXE 2018-07-27       NaN
# 672011                SNSURGINET 2018-10-04  0.770833
# 672012            SNSURGINET.EXE 2018-09-18  0.035804
# 672013                SNSURGINET 2018-09-13  1.012844
# 672014            SNSURGINET.EXE 2018-07-25  0.913612
#
#                           subtimername  \
# 0                                  NaN
# 1                        UN TOURNIQUET
# 2                                  NaN
# 3                                  NaN
# 4              VB_WORKFLOWAMBPEDSPSYCH
# 5                   VB_ONCOLOGYSUMMARY
# 6                 WHIEC CASE ATTENDEES
# 7                  BLH ENDO CASE TIMES
# 8                                  NaN
# 9               NH ENDO IMPLANT RECORD
# 10            AH ENDO PREOP CASE TIMES
# 11                     AH OB SKIN PREP
# 12                                 NaN
# 13                 VB_WORKFLOWIPCHARIS
# 14      PICU TREATMENTS AND PROCEDURES
# 15             UN RAD MONITORING LINES
# 16             VB_IUHINPATIENTSUMMARY2
# 17                WH MEDICATION INTAKE
# 18                                 NaN
# 19                    THERMOREGULATION
# 20             JC CHARTABLE ACTIVITIES
# 21                    SASC MEDICATIONS
# 22                       AH HEMOSTASIS
# 23                    NH OB HEMOSTASIS
# 24              VB_WORKFLOWIPPULMONARY
# 25         VB_WORKFLOWAMBCARDIOLOGY001
# 26                                 NaN
# 27        VB_WORKFLOWAMBPEDSNEPHROLOGY
# 28                       VB_HCWORKLIST
# 29                VB_IUHNEONATESUMMARY
# ...                                ...
# 671985                       UH COUNTS
# 671986                 VB_SUMMARYORTHO
# 671987   VB_WORKFLOWIPGASTROENTEROLOGY
# 671988          BLH RAD IMPLANT RECORD
# 671989                  FACILITYSEARCH
# 671990                   ACTIVITY VIEW
# 671991                             102
# 671992       ADULT ICU ADLS AND SAFETY
# 671993    VB_WORKFLOWOBCLINICALSUPPORT
# 671994                             NaN
# 671995    ADULT SS PHYSICAL ASSESSMENT
# 671996    ADULT MS PHYSICAL ASSESSMENT
# 671997  VB_WORKFLOWAMBINFECTIOUSDISEAS
# 671998                  FACILITYSEARCH
# 671999                             203
# 672000    VB_WORKFLOWOBCLINICALSUPPORT
# 672001            VB_WORKFLOWIPSURGERY
# 672002  VB_WORKFLOWAMBPCPROVIDERINTERN
# 672003     VB_WORKFLOWAMBCARDIOLOGY001
# 672004       WVSC SPECIMENS & CULTURES
# 672005                             NaN
# 672006                      AAS DELAYS
# 672007            VB_WORKFLOWIPPEDSPMR
# 672008                      BMH DELAYS
# 672009              VB_AMBRHEUMATOLOGY
# 672010           WH INTRAOP ASSESSMENT
# 672011                             NaN
# 672012      AAS PACU PHASE 1 ATTENDEES
# 672013           FLOWSHEET/PVFLOWSHEET
# 672014              BLH CASE ATTENDEES
#
#                                                 timername  total_elapsed  \
# 0                               USR: PN AUTOPOPULATE DATA    3482.946764
# 1                 USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.035208
# 2          USR:MPG.POC SUMMARY COMPONENT - LOAD COMPONENT       0.221000
# 3                              USR:BSC-ENSURE MAW RESULTS   31670.881000
# 4             USR:MPG.NEW_ORDER_ENTRY.O2 - LOAD COMPONENT       6.338292
# 5             USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT    1355.636862
# 6                       USR:SRG SNDOCDISP LOADING SEGMENT       5.156083
# 7                        USR:SRG SNDOCDISP SAVING SEGMENT      10.919433
# 8                       USR:ORM.SIGNORDERS-NONMEDDUPCHECK     259.930018
# 9                       USR:SRG SNDOCDISP LOADING SEGMENT       0.757934
# 10                       USR:SRG SNDOCDISP SAVING SEGMENT      24.257073
# 11                      USR:SRG SNDOCDISP LOADING SEGMENT       0.957260
# 12                           USR:ORM.LOADORDERINFOADDINFO      17.690855
# 13                  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT       2.673216
# 14                      USR: PDOC NAVIGATOR DOC SET CLICK       0.053000
# 15                       USR:SRG SNDOCDISP SAVING SEGMENT       0.788902
# 16                         USR:MPG.IO.O1 - LOAD COMPONENT     128.218806
# 17                      USR:SRG SNDOCDISP LOADING SEGMENT      19.605136
# 18      USR:ICU-IVIEW-ACTIVATE AN INACTIVE REPEATABLE ...      39.155000
# 19                      USR:SRG SNDOCDISP LOADING SEGMENT       6.857716
# 20                       USR:SRG SNDOCDISP SAVING SEGMENT       0.288404
# 21                      USR:SRG SNDOCDISP LOADING SEGMENT       7.548787
# 22                USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.112857
# 23                      USR:SRG SNDOCDISP LOADING SEGMENT       0.523123
# 24                USR:MPG.SCALEASSESS.WF - LOAD COMPONENT      38.226568
# 25          USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      42.510329
# 26                         USR: CRADFDETAILFORM.FORM_LOAD       0.265116
# 27                  USR:MPG.REMINDERS.O2 - LOAD COMPONENT      29.397991
# 28            USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT     227.100146
# 29                       USR:MPG.MEDS.O1 - LOAD COMPONENT     679.916677
# ...                                                   ...            ...
# 671985                  USR:SRG SNDOCDISP LOADING SEGMENT      15.879675
# 671986        USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT      49.967592
# 671987      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      68.380047
# 671988                   USR:SRG SNDOCDISP SAVING SEGMENT       0.083449
# 671989            USR:ERM PMACTION CLIENT/FACILITY SEARCH     333.862000
# 671990                              USR: ICU-OPENING-BAND     157.953670
# 671991      USR:ERM PMACTION SEARCH TO CONVERSATION READY       7.811000
# 671992                     USR: PDOC NAVIGATOR BAND CLICK      42.168000
# 671993             USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB    1185.531946
# 671994                             USR:ORM.ACCEPTRXREFILL    5221.348871
# 671995                     USR: PDOC NAVIGATOR BAND CLICK      46.926000
# 671996                     USR: PDOC NAVIGATOR BAND CLICK      16.912000
# 671997             USR:MPG.LABORATORY.WF - LOAD COMPONENT     159.003811
# 671998            USR:ERM PMACTION CLIENT/FACILITY SEARCH      50.857000
# 671999      USR:ERM PMACTION SEARCH TO CONVERSATION READY       1.967000
# 672000             USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB    1252.311785
# 672001              USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT      49.674515
# 672002      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT     580.064963
# 672003        USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT       0.596648
# 672004                   USR:SRG SNDOCDISP SAVING SEGMENT      31.013927
# 672005                    USR:ORM.CLAIMSHXSPREADCONVERTHX       0.048142
# 672006            USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.692465
# 672007                USR:MPG.ALLERGY.O2 - LOAD COMPONENT      22.822446
# 672008            USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.260952
# 672009        USR:MPG.RECOMMENDATIONS.O2 - LOAD COMPONENT     121.940591
# 672010            USR:SRG SNDOCDISP DISCONTINUING SEGMENT       0.029942
# 672011             USR:ORM.BATCHLOADFORMULARYINFOVERSION3     874.108346
# 672012                  USR:SRG SNDOCDISP LOADING SEGMENT       1.192553
# 672013                                 USR:PWR-OPEN CHART     359.836406
# 672014                   USR:SRG SNDOCDISP SAVING SEGMENT     201.979506
#
#         transAbove5  transUnder2  transaction_cnt     isBDay
# 0                 1           91             1202        NaT
# 1                 0            1                1 2018-07-27
# 2                 0            1                1 2018-08-24
# 3                 8        37109            37153 2018-09-14
# 4                 0            2                3 2018-09-04
# 5                 2         2740             2780 2018-09-27
# 6                 0           13               13 2018-08-01
# 7                 0           21               21        NaT
# 8                 0        70146            70146 2018-09-11
# 9                 0            4                4 2018-10-04
# 10                0           26               26 2018-09-25
# 11                0            4                4 2018-08-09
# 12                0          245              245        NaT
# 13                0           13               13 2018-09-20
# 14                0            1                1        NaT
# 15                0            6                6 2018-08-14
# 16                0          638              639        NaT
# 17                0           73               73 2018-10-04
# 18                0           93               93 2018-07-26
# 19                0          124              124 2018-07-20
# 20                0            2                2 2018-09-28
# 21                0           40               40 2018-08-28
# 22                0            3                3 2018-08-31
# 23                0            4                4 2018-09-06
# 24                0           53               57        NaT
# 25                0          164              164        NaT
# 26                0            1                1 2018-09-06
# 27                0           31               34 2018-09-19
# 28                0          439              439 2018-08-21
# 29                5         1201             1246 2018-08-20
# ...             ...          ...              ...        ...
# 671985            0          159              159 2018-07-30
# 671986            0          101              101        NaT
# 671987            0          275              275 2018-08-24
# 671988            0            1                1 2018-09-17
# 671989            1         4331             4332 2018-07-25
# 671990            0          164              170        NaT
# 671991            0            4                5 2018-08-08
# 671992            0           86               86 2018-08-16
# 671993           10          882              930 2018-09-17
# 671994           17         2104             2920 2018-07-23
# 671995            0           59               62 2018-08-22
# 671996            0           27               28        NaT
# 671997            1           72              100 2018-10-12
# 671998            1          643              644        NaT
# 671999            0            1                1 2018-09-28
# 672000            6         1035             1071 2018-10-11
# 672001            0           51               51 2018-09-06
# 672002            0         1862             1877 2018-08-15
# 672003            0            2                2        NaT
# 672004            0           55               55 2018-09-06
# 672005            0          342              342 2018-09-28
# 672006            0           19               19 2018-07-19
# 672007            1           17               20 2018-08-24
# 672008            0            7                7        NaT
# 672009            5           59               69        NaT
# 672010            0            1                1 2018-07-27
# 672011            5         2009             2073 2018-10-04
# 672012            0           12               12 2018-09-18
# 672013            3          156              208 2018-09-13
# 672014            0          138              168 2018-07-25
#
# [672015 rows x 15 columns]

# %% [markdown]
# ### Filter dataset by application - e.g. Powerchart, firstnet, surginet.
# (Actually apply the weekend/weekday filter here as well).
# **to-do**
# - ?? are there differences between timers in the different datasets?
# - clean up the workflow to do one step at a time.

# %%
atrt_df_PC = atrt_df[atrt_df['application_name']== 'POWERCHART']
atrt_df_PC = atrt_df_PC[atrt_df_PC.isBDay.notnull()]
atrt_df_PC
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 3       0.85                         0.02%                        99.88%
# 4       2.11                         0.00%                        66.67%
# 5       0.49                         0.07%                        98.56%
# 8       0.00                         0.00%                       100.00%
# 13      0.21                         0.00%                       100.00%
# 18      0.42                         0.00%                       100.00%
# 27      0.86                         0.00%                        91.18%
# 28      0.52                         0.00%                       100.00%
# 29      0.55                         0.40%                        96.39%
# 36      0.21                         0.04%                        99.91%
# 37      0.29                         0.00%                       100.00%
# 38      0.71                         0.00%                        99.51%
# 44      1.44                         3.12%                        92.93%
# 49      0.35                         0.00%                        99.93%
# 52      0.46                         0.18%                        99.82%
# 54      0.08                         0.00%                       100.00%
# 58      0.39                         0.00%                       100.00%
# 60      0.12                         0.00%                       100.00%
# 66      0.90                         0.00%                       100.00%
# 72      1.92                         2.86%                        62.86%
# 84      0.78                         0.24%                        96.59%
# 89      1.96                         0.92%                        67.37%
# 90      0.62                         0.02%                        99.87%
# 91      0.86                         0.20%                        94.94%
# 94      0.04                         0.00%                       100.00%
# 97      0.55                         0.00%                       100.00%
# 100     0.02                         0.00%                       100.00%
# 101     0.47                         0.00%                        99.66%
# 102     1.06                         0.75%                        91.90%
# 104     0.12                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 671933  2.75                         0.91%                        13.28%
# 671935  0.13                         0.00%                       100.00%
# 671936  1.80                         3.57%                        89.29%
# 671937  2.48                         6.12%                        88.52%
# 671938  0.72                         0.00%                       100.00%
# 671940  0.39                         0.00%                       100.00%
# 671942  0.11                         0.00%                       100.00%
# 671948  0.12                         0.00%                       100.00%
# 671951  0.08                         0.00%                       100.00%
# 671953  2.82                         1.11%                        78.97%
# 671959  0.10                         0.00%                        99.94%
# 671960  0.74                         0.00%                        99.37%
# 671961  0.48                         0.00%                        99.81%
# 671962  0.59                         1.28%                        96.15%
# 671965  0.52                         0.00%                        99.50%
# 671969  1.54                         0.00%                        91.25%
# 671971  2.59                         0.00%                         0.00%
# 671974  0.03                         0.00%                       100.00%
# 671975  0.35                         0.00%                       100.00%
# 671978  0.10                         0.00%                        99.84%
# 671984  0.33                         0.00%                       100.00%
# 671987  0.25                         0.00%                       100.00%
# 671993  1.27                         1.08%                        94.84%
# 671994  1.79                         0.58%                        72.05%
# 671997  1.59                         1.00%                        72.00%
# 672000  1.17                         0.56%                        96.64%
# 672001  0.97                         0.00%                       100.00%
# 672002  0.31                         0.00%                        99.20%
# 672005  0.00                         0.00%                       100.00%
# 672007  1.14                         5.00%                        85.00%
#
#                                       Timer Subtimer Name  Number of Records  \
# 3                        USR:BSC-ENSURE MAW RESULTS (N/A)                  1
# 4       USR:MPG.NEW_ORDER_ENTRY.O2 - LOAD COMPONENT (V...                  1
# 5       USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT (V...                  1
# 8                 USR:ORM.SIGNORDERS-NONMEDDUPCHECK (N/A)                  1
# 13      USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 18      USR:ICU-IVIEW-ACTIVATE AN INACTIVE REPEATABLE ...                  1
# 27      USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 28      USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT (V...                  1
# 29      USR:MPG.MEDS.O1 - LOAD COMPONENT (VB_IUHNEONAT...                  1
# 36               USR:ORM.CONVERTTOINPATIENTMR-BEGIN (N/A)                  1
# 37      USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 38                   USR: ICU-OPENING-BAND (CRRT NXSTAGE)                  1
# 44            USR: PDOC NAVIGATOR BAND CLICK (POSTPARTUM)                  1
# 49      USR:MPG.VITALSIGNS.O1 - LOAD COMPONENT (VB_CMU...                  1
# 52      USR: PDOC NAVIGATOR BAND CLICK (NICU TREATMENT...                  1
# 54      USR:WH-DELIVERY RECORD-ACCESS CONFIRMATION WIN...                  1
# 58      USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 60      USR:MPG.PATHOLOGY.O2 - LOAD COMPONENT (VB_WORK...                  1
# 66      USR:MPG.FOLLOWUP.O2 - LOAD COMPONENT (VB_WORKF...                  1
# 72      USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT (VB_W...                  1
# 84                    USR:SCH SCHACTION ONOK CANCEL (N/A)                  1
# 89              USR:PWR-OPEN CHART (CLINDOCUMENT/PVNOTES)                  1
# 90      USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT (V...                  1
# 91      USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 94         USR:ORM.DISPLAYFUTUREORDERSCHEDULEDIALOG (N/A)                  1
# 97      USR: PDOC NAVIGATOR BAND CLICK (ED TREATMENTS ...                  1
# 100                       USR:POWERPLANS.SIGN PLANS (N/A)                  1
# 101           USR: PDOC NAVIGATOR BAND CLICK (CA OB ADLS)                  1
# 102     USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 104                    USR:FN.SAVE PROVIDER CHECKIN (N/A)                  1
# ...                                                   ...                ...
# 671933   USR:PWR.PVINBOX.OPEN ITEM.DISCRETE RESULTS (N/A)                  1
# 671935          USR: PDOC NAVIGATOR DOC SET CLICK (LINES)                  1
# 671936  USR:MPG.VITALSIGNS.WF - LOAD COMPONENT (VB_WOR...                  1
# 671937          USR:PWR-REFRESH VIEW (REFRESHING MAR TAB)                  1
# 671938  USR:MPG.LABORATORY.WF - LOAD COMPONENT (VB_EDP...                  1
# 671940  USR:MPG.REMINDERS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 671942  USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT (VB_WO...                  1
# 671948  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 671951  USR: PDOC NAVIGATOR DOC SET CLICK (NICU PHYSIC...                  1
# 671953           USR: DYNDOC OPEN EXISTING DOCUMENT (N/A)                  1
# 671959  USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT (VB_PR...                  1
# 671960  USR:MPG.PRENATALVISITS.O2 - LOAD COMPONENT (VB...                  1
# 671961  USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT (V...                  1
# 671962  USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT (V...                  1
# 671965  USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT (V...                  1
# 671969  USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT (VB_W...                  1
# 671971  USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT (...                  1
# 671974        USR: PDOC NAVIGATOR DOC SET CLICK (NEWBORN)                  1
# 671975  USR:MPG.ADVGROWTHCHART.O1 - LOAD COMPONENT (VB...                  1
# 671978  USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT ...                  1
# 671984  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 671987  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 671993  USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB (VB_WOR...                  1
# 671994                       USR:ORM.ACCEPTRXREFILL (N/A)                  1
# 671997  USR:MPG.LABORATORY.WF - LOAD COMPONENT (VB_WOR...                  1
# 672000  USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB (VB_WOR...                  1
# 672001  USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT (VB_WORK...                  1
# 672002  USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT ...                  1
# 672005              USR:ORM.CLAIMSHXSPREADCONVERTHX (N/A)                  1
# 672007  USR:MPG.ALLERGY.O2 - LOAD COMPONENT (VB_WORKFL...                  1
#
#        application_name         dt       strt                    subtimername  \
# 3            POWERCHART 2018-09-14   0.225968                             NaN
# 4            POWERCHART 2018-09-04   0.615354         VB_WORKFLOWAMBPEDSPSYCH
# 5            POWERCHART 2018-09-27   0.397299              VB_ONCOLOGYSUMMARY
# 8            POWERCHART 2018-09-11   0.002295                             NaN
# 13           POWERCHART 2018-09-20   0.043101             VB_WORKFLOWIPCHARIS
# 18           POWERCHART 2018-07-26   0.089713                             NaN
# 27           POWERCHART 2018-09-19   0.806611    VB_WORKFLOWAMBPEDSNEPHROLOGY
# 28           POWERCHART 2018-08-21   0.130344                   VB_HCWORKLIST
# 29           POWERCHART 2018-08-20   0.750812            VB_IUHNEONATESUMMARY
# 36           POWERCHART 2018-08-15   0.276444                             NaN
# 37           POWERCHART 2018-09-14   0.081339  VB_WORKFLOWIPADMITPEDSENDOCRIN
# 38           POWERCHART 2018-09-28   0.239003                    CRRT NXSTAGE
# 44           POWERCHART 2018-08-13   8.073872                      POSTPARTUM
# 49           POWERCHART 2018-08-21   0.147104      VB_CMUTILIZATIONMANAGEMENT
# 52           POWERCHART 2018-07-30   0.556974  NICU TREATMENTS AND PROCEDURES
# 54           POWERCHART 2018-09-27   0.064656                             NaN
# 58           POWERCHART 2018-09-28   0.106032  VB_WORKFLOWAMBGASTROENTEROLOGY
# 60           POWERCHART 2018-10-08   0.013185        VB_WORKFLOWIPPEDSUROLOGY
# 66           POWERCHART 2018-09-20   0.114911  VB_WORKFLOWAMBOBPRENATALPPDIPU
# 72           POWERCHART 2018-08-17   1.045806           VB_WORKFLOWAMBSURGERY
# 84           POWERCHART 2018-10-11   0.453976                             NaN
# 89           POWERCHART 2018-10-05   2.198333            CLINDOCUMENT/PVNOTES
# 90           POWERCHART 2018-09-10   0.183747                VB_OPQUICKORDERS
# 91           POWERCHART 2018-07-23   0.802715            VB_WORKFLOWAMBPCPEDS
# 94           POWERCHART 2018-08-10   0.076900                             NaN
# 97           POWERCHART 2018-09-13   0.018385    ED TREATMENTS AND PROCEDURES
# 100          POWERCHART 2018-10-12   0.038617                             NaN
# 101          POWERCHART 2018-10-11   0.287283                      CA OB ADLS
# 102          POWERCHART 2018-09-06   0.808187           VB_WORKFLOWIPSTANDARD
# 104          POWERCHART 2018-09-10   0.022638                             NaN
# ...                 ...        ...        ...                             ...
# 671933       POWERCHART 2018-09-19   0.791446                             NaN
# 671935       POWERCHART 2018-08-08   0.121791                           LINES
# 671936       POWERCHART 2018-07-20   2.086792  VB_WORKFLOWIPPEDSPALLIATIVECAR
# 671937       POWERCHART 2018-08-13  15.762122              REFRESHING MAR TAB
# 671938       POWERCHART 2018-08-09        NaN          VB_EDPHYSICIANWORKFLOW
# 671940       POWERCHART 2018-07-24   0.132851          VB_WORKFLOWIPNEUROLOGY
# 671942       POWERCHART 2018-09-14   0.156640       VB_WORKFLOWIPNURSEHANDOFF
# 671948       POWERCHART 2018-08-16   0.051451     VB_WORKFLOWAMBADOLESCENTMED
# 671951       POWERCHART 2018-10-03   0.064726        NICU PHYSICAL ASSESSMENT
# 671953       POWERCHART 2018-09-12  21.014708                             NaN
# 671959       POWERCHART 2018-09-20   0.119925   VB_PREOPERATIVECOMMUNICATIONS
# 671960       POWERCHART 2018-08-01   0.317998    VB_WORKFLOWAMBOBPRENATALPPUN
# 671961       POWERCHART 2018-09-17   0.263961   VB_QUICKORDERSCLINICALSUPPORT
# 671962       POWERCHART 2018-10-09   0.954571  VB_WORKFLOWAMBPEDSENDOCRINOLOG
# 671965       POWERCHART 2018-08-24   0.336074   VB_QUICKORDERSCLINICALSUPPORT
# 671969       POWERCHART 2018-08-31   0.601376  VB_WORKFLOWAMBOBPRENATALPPDIPU
# 671971       POWERCHART 2018-09-06   0.339671     VB_WORKFLOWAMBADOLESCENTMED
# 671974       POWERCHART 2018-08-20   0.010528                         NEWBORN
# 671975       POWERCHART 2018-08-09   0.172956       VB_WORKFLOWAMBPEDSALLERGY
# 671978       POWERCHART 2018-08-13   0.129927               VB_AMBGYNWORKFLOW
# 671984       POWERCHART 2018-08-24   0.091993       VB_WORKFLOWIPRHEUMATOLOGY
# 671987       POWERCHART 2018-08-24   0.188118   VB_WORKFLOWIPGASTROENTEROLOGY
# 671993       POWERCHART 2018-09-17   0.784020    VB_WORKFLOWOBCLINICALSUPPORT
# 671994       POWERCHART 2018-07-23   0.942257                             NaN
# 671997       POWERCHART 2018-10-12   1.325320  VB_WORKFLOWAMBINFECTIOUSDISEAS
# 672000       POWERCHART 2018-10-11   0.599969    VB_WORKFLOWOBCLINICALSUPPORT
# 672001       POWERCHART 2018-09-06   0.320734            VB_WORKFLOWIPSURGERY
# 672002       POWERCHART 2018-08-15   0.326089  VB_WORKFLOWAMBPCPROVIDERINTERN
# 672005       POWERCHART 2018-09-28   0.000032                             NaN
# 672007       POWERCHART 2018-08-24   1.316103            VB_WORKFLOWIPPEDSPMR
#
#                                                 timername  total_elapsed  \
# 3                              USR:BSC-ENSURE MAW RESULTS   31670.881000
# 4             USR:MPG.NEW_ORDER_ENTRY.O2 - LOAD COMPONENT       6.338292
# 5             USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT    1355.636862
# 8                       USR:ORM.SIGNORDERS-NONMEDDUPCHECK     259.930018
# 13                  USR:MPG.DOCUMENTS.O2 - LOAD COMPONENT       2.673216
# 18      USR:ICU-IVIEW-ACTIVATE AN INACTIVE REPEATABLE ...      39.155000
# 27                  USR:MPG.REMINDERS.O2 - LOAD COMPONENT      29.397991
# 28            USR:MPG.NOTES_REMINDERS.O1 - LOAD COMPONENT     227.100146
# 29                       USR:MPG.MEDS.O1 - LOAD COMPONENT     679.916677
# 36                     USR:ORM.CONVERTTOINPATIENTMR-BEGIN     490.151686
# 37                 USR:MPG.VITALSIGNS.WF - LOAD COMPONENT       0.583004
# 38                                  USR: ICU-OPENING-BAND     147.244392
# 44                         USR: PDOC NAVIGATOR BAND CLICK    1202.316000
# 49                 USR:MPG.VITALSIGNS.O1 - LOAD COMPONENT    1925.280518
# 52                         USR: PDOC NAVIGATOR BAND CLICK     259.199000
# 54      USR:WH-DELIVERY RECORD-ACCESS CONFIRMATION WINDOW       6.724000
# 58                  USR:MPG.REMINDERS.O2 - LOAD COMPONENT      15.957278
# 60                  USR:MPG.PATHOLOGY.O2 - LOAD COMPONENT       0.366088
# 66                   USR:MPG.FOLLOWUP.O2 - LOAD COMPONENT      15.275936
# 72               USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT      67.137717
# 84                          USR:SCH SCHACTION ONOK CANCEL     321.751120
# 89                                     USR:PWR-OPEN CHART   21418.252366
# 90            USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT    3692.638163
# 91                 USR:MPG.VITALSIGNS.WF - LOAD COMPONENT     424.376458
# 94               USR:ORM.DISPLAYFUTUREORDERSCHEDULEDIALOG      39.372550
# 97                         USR: PDOC NAVIGATOR BAND CLICK       1.100000
# 100                             USR:POWERPLANS.SIGN PLANS    1193.048407
# 101                        USR: PDOC NAVIGATOR BAND CLICK     972.286605
# 102                USR:MPG.VITALSIGNS.WF - LOAD COMPONENT    3123.268584
# 104                          USR:FN.SAVE PROVIDER CHECKIN      30.835000
# ...                                                   ...            ...
# 671933         USR:PWR.PVINBOX.OPEN ITEM.DISCRETE RESULTS   12701.785813
# 671935                  USR: PDOC NAVIGATOR DOC SET CLICK     102.498000
# 671936             USR:MPG.VITALSIGNS.WF - LOAD COMPONENT      50.455645
# 671937                               USR:PWR-REFRESH VIEW   40286.436610
# 671938             USR:MPG.LABORATORY.WF - LOAD COMPONENT       0.719880
# 671940              USR:MPG.REMINDERS.O2 - LOAD COMPONENT       7.701366
# 671942            USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT       5.799001
# 671948      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT       0.995904
# 671951                  USR: PDOC NAVIGATOR DOC SET CLICK      20.033000
# 671953                 USR: DYNDOC OPEN EXISTING DOCUMENT    9878.941958
# 671959            USR:MPG.CUSTOM_COMP.O1 - LOAD COMPONENT     174.702166
# 671960         USR:MPG.PRENATALVISITS.O2 - LOAD COMPONENT     116.708625
# 671961        USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT     521.601600
# 671962        USR:MPG.CHIEF_COMPLAINT.O1 - LOAD COMPONENT      45.987068
# 671965        USR:MPG.NEW_ORDER_ENTRY.O1 - LOAD COMPONENT     310.273313
# 671969           USR:MPG.CONSOL_PROBS.O3 - LOAD COMPONENT     123.009524
# 671971       USR:MPG.PATIENTEDUCATION.O2 - LOAD COMPONENT      41.502350
# 671974                  USR: PDOC NAVIGATOR DOC SET CLICK       2.611000
# 671975         USR:MPG.ADVGROWTHCHART.O1 - LOAD COMPONENT       4.896030
# 671978      USR:MPG.CONSOLIDATED_HISTORY - LOAD COMPONENT      60.632940
# 671984      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT       3.583534
# 671987      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT      68.380047
# 671993             USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB    1185.531946
# 671994                             USR:ORM.ACCEPTRXREFILL    5221.348871
# 671997             USR:MPG.LABORATORY.WF - LOAD COMPONENT     159.003811
# 672000             USR:MPG.RECOMMENDATIONS.O2_PENDING_TAB    1252.311785
# 672001              USR:MPG.HOME_MEDS.O2 - LOAD COMPONENT      49.674515
# 672002      USR:MPG.DOCUMENTATION_HPI.O1 - LOAD COMPONENT     580.064963
# 672005                    USR:ORM.CLAIMSHXSPREADCONVERTHX       0.048142
# 672007                USR:MPG.ALLERGY.O2 - LOAD COMPONENT      22.822446
#
#         transAbove5  transUnder2  transaction_cnt     isBDay
# 3                 8        37109            37153 2018-09-14
# 4                 0            2                3 2018-09-04
# 5                 2         2740             2780 2018-09-27
# 8                 0        70146            70146 2018-09-11
# 13                0           13               13 2018-09-20
# 18                0           93               93 2018-07-26
# 27                0           31               34 2018-09-19
# 28                0          439              439 2018-08-21
# 29                5         1201             1246 2018-08-20
# 36                1         2323             2325 2018-08-15
# 37                0            2                2 2018-09-14
# 38                0          205              206 2018-09-28
# 44               26          775              834 2018-08-13
# 49                0         5456             5460 2018-08-21
# 52                1          564              565 2018-07-30
# 54                0           82               82 2018-09-27
# 58                0           41               41 2018-09-28
# 60                0            3                3 2018-10-08
# 66                0           17               17 2018-09-20
# 72                1           22               35 2018-08-17
# 84                1          396              410 2018-10-11
# 89              100         7346            10904 2018-10-05
# 90                1         5977             5985 2018-09-10
# 91                1          469              494 2018-07-23
# 94                0          990              990 2018-08-10
# 97                0            2                2 2018-09-13
# 100               0        48091            48092 2018-10-12
# 101               0         2070             2077 2018-10-11
# 102              22         2711             2950 2018-09-06
# 104               0          262              262 2018-09-10
# ...             ...          ...              ...        ...
# 671933           42          614             4625 2018-09-19
# 671935            0          774              774 2018-08-08
# 671936            1           25               28 2018-07-20
# 671937          994        14384            16249 2018-08-13
# 671938            0            1                1 2018-08-09
# 671940            0           20               20 2018-07-24
# 671942            0           51               51 2018-09-14
# 671948            0            8                8 2018-08-16
# 671951            0          242              242 2018-10-03
# 671953           39         2771             3509 2018-09-12
# 671959            0         1737             1738 2018-09-20
# 671960            0          157              158 2018-08-01
# 671961            0         1079             1081 2018-09-17
# 671962            1           75               78 2018-10-09
# 671965            0          593              596 2018-08-24
# 671969            0           73               80 2018-08-31
# 671971            0            0               16 2018-09-06
# 671974            0           86               86 2018-08-20
# 671975            0           14               14 2018-08-09
# 671978            0          616              617 2018-08-13
# 671984            0           11               11 2018-08-24
# 671987            0          275              275 2018-08-24
# 671993           10          882              930 2018-09-17
# 671994           17         2104             2920 2018-07-23
# 671997            1           72              100 2018-10-12
# 672000            6         1035             1071 2018-10-11
# 672001            0           51               51 2018-09-06
# 672002            0         1862             1877 2018-08-15
# 672005            0          342              342 2018-09-28
# 672007            1           17               20 2018-08-24
#
# [199602 rows x 15 columns]

# %% [markdown]
# ### Anomaly detection/Handling

# %% [markdown]
# ### Anomaly detection/Handling
# #### Applying quantiles:
#
# Apply 5th and 95th quantiles to each timer for the entire 90 day period.
# Then we can lookup the values using ```loc``` and ```filter```
#
#
# **To-do**
# - Investigate outliers/anomalies by timer. Replace with mean/remove altogether.
# - Use KNN?
# - Complete - remove outliers by timer.
#
# Sample outlier removal calculation by group.
# ```atrt_df_PC[np.abs(atrt_df_PC.ATRT-atrt_df_PC.ATRT.mean()) <= (3*atrt_df_PC.ATRT.std())]```
#
# Takes the absolute value of standardized value for each datapoint, then removes it if it's less than 3 standard deviations from the mean.
# - I need to do this by group!
# - Group first, then pass in group calculation.

# %%
outliers = atrt_df_PC.groupby(["Timer Subtimer Name"])['ATRT'].quantile([0.05, 0.95]).unstack(level=1)
#outliers
atrt_df_PC = atrt_df_PC.loc[((outliers.loc[atrt_df_PC['Timer Subtimer Name'], .05] < atrt_df_PC.ATRT.values) & (atrt_df_PC.ATRT.values < outliers.loc[atrt_df_PC['Timer Subtimer Name'], .95])).values]

# %% [markdown]
# ### Rolling average notes
# Lambda function for applying rolling average to a group:
# The groupby statement can be in an earlier variable, but I've chosen to include it here.
#
# **To-do**
# - Find out exactly what reset_index does - reset the average calculation to the beginning of each group?
# - Remove outliers/anomalies by timer. Replace with mean/remove altogether.
# - Use KNN?
# ```
# atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])['ATRT'].rolling(30).mean().reset_index(0,drop=True)
# ```
# Pass into dataset feature with ```atrt_df_PC['mavg30'] = (above statement)```

# %%
#atrt_df_PC['mavg30'] = atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])['ATRT'].rolling(30).mean().reset_index(0,drop=True)

# %%
#Setting index appears to cause issues when outputting to csv: 
#atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name', 'dt'])

atrt_df_PC = atrt_df_PC.sort_values(['Timer Subtimer Name', 'dt'])
atrt_df_PC['mavg30'] = atrt_df_PC.groupby('Timer Subtimer Name')['ATRT'].apply(lambda x:x.rolling(center=False,window=30).mean())

#check to make sure that everything looks correct: 
atrt_df_PC
# Out:
#         ATRT % of Transactions > 5 seconds % of Transactions < 2 seconds  \
# 627225  0.15                         0.00%                        99.98%
# 321786  0.16                         0.00%                       100.00%
# 166151  0.16                         0.00%                        99.91%
# 3945    0.15                         0.00%                       100.00%
# 75089   0.14                         0.00%                       100.00%
# 371081  0.14                         0.00%                        99.98%
# 667501  0.16                         0.00%                        99.91%
# 134037  0.14                         0.00%                       100.00%
# 30443   0.14                         0.00%                       100.00%
# 290495  0.14                         0.02%                        99.98%
# 495111  0.14                         0.02%                        99.98%
# 352819  0.15                         0.00%                       100.00%
# 52266   0.16                         0.00%                        99.98%
# 507358  0.15                         0.00%                       100.00%
# 589607  0.15                         0.00%                        99.98%
# 142350  0.16                         0.00%                        99.98%
# 26699   0.16                         0.00%                        99.98%
# 90320   0.16                         0.00%                        99.96%
# 318894  0.15                         0.00%                       100.00%
# 557502  0.15                         0.00%                       100.00%
# 314501  0.15                         0.02%                        99.98%
# 77922   0.15                         0.00%                       100.00%
# 43825   0.16                         0.00%                        99.97%
# 212261  0.16                         0.00%                        99.97%
# 670191  0.15                         0.00%                       100.00%
# 573386  0.16                         0.00%                        99.95%
# 345626  0.15                         0.00%                        99.98%
# 669339  0.15                         0.00%                       100.00%
# 569989  0.15                         0.00%                        99.98%
# 217890  0.15                         0.00%                       100.00%
# ...      ...                           ...                           ...
# 216163  4.75                        52.50%                        37.50%
# 339336  3.78                        43.90%                        47.56%
# 428702  4.96                        54.12%                        41.18%
# 430972  4.08                        45.45%                        50.00%
# 420896  4.94                        53.01%                        38.55%
# 454986  4.15                        44.19%                        48.84%
# 367886  4.04                        46.90%                        46.02%
# 226016  5.00                        53.75%                        45.00%
# 191426  4.12                        45.59%                        50.00%
# 420903  4.96                        56.04%                        37.36%
# 32769   4.18                        43.04%                        46.84%
# 481237  4.72                        53.85%                        44.87%
# 253335  4.49                        48.28%                        50.00%
# 557646  4.95                        53.42%                        41.10%
# 326063  4.76                        52.33%                        38.37%
# 201761  4.38                        48.72%                        46.15%
# 2886    4.60                        53.03%                        37.88%
# 73520   4.29                        46.74%                        43.48%
# 255513  4.75                        52.63%                        44.74%
# 571931  4.17                        48.78%                        47.56%
# 315853  3.89                        41.57%                        53.93%
# 105894  4.53                        51.28%                        43.59%
# 277256  3.89                        43.30%                        50.52%
# 298958  4.69                        48.28%                        46.55%
# 226011  4.75                        52.94%                        43.14%
# 32758   4.84                        55.00%                        40.00%
# 422291  4.53                        51.47%                        39.71%
# 380109  4.06                        46.75%                        50.65%
# 522181  4.53                        55.41%                        44.59%
# 240512  3.99                        41.30%                        45.65%
#
#                                 Timer Subtimer Name  Number of Records  \
# 627225                   DMSM_GETMEDIACONTENT (N/A)                  1
# 321786                   DMSM_GETMEDIACONTENT (N/A)                  1
# 166151                   DMSM_GETMEDIACONTENT (N/A)                  1
# 3945                     DMSM_GETMEDIACONTENT (N/A)                  1
# 75089                    DMSM_GETMEDIACONTENT (N/A)                  1
# 371081                   DMSM_GETMEDIACONTENT (N/A)                  1
# 667501                   DMSM_GETMEDIACONTENT (N/A)                  1
# 134037                   DMSM_GETMEDIACONTENT (N/A)                  1
# 30443                    DMSM_GETMEDIACONTENT (N/A)                  1
# 290495                   DMSM_GETMEDIACONTENT (N/A)                  1
# 495111                   DMSM_GETMEDIACONTENT (N/A)                  1
# 352819                   DMSM_GETMEDIACONTENT (N/A)                  1
# 52266                    DMSM_GETMEDIACONTENT (N/A)                  1
# 507358                   DMSM_GETMEDIACONTENT (N/A)                  1
# 589607                   DMSM_GETMEDIACONTENT (N/A)                  1
# 142350                   DMSM_GETMEDIACONTENT (N/A)                  1
# 26699                    DMSM_GETMEDIACONTENT (N/A)                  1
# 90320                    DMSM_GETMEDIACONTENT (N/A)                  1
# 318894                   DMSM_GETMEDIACONTENT (N/A)                  1
# 557502                   DMSM_GETMEDIACONTENT (N/A)                  1
# 314501                   DMSM_GETMEDIACONTENT (N/A)                  1
# 77922                    DMSM_GETMEDIACONTENT (N/A)                  1
# 43825                    DMSM_GETMEDIACONTENT (N/A)                  1
# 212261                   DMSM_GETMEDIACONTENT (N/A)                  1
# 670191                   DMSM_GETMEDIACONTENT (N/A)                  1
# 573386                   DMSM_GETMEDIACONTENT (N/A)                  1
# 345626                   DMSM_GETMEDIACONTENT (N/A)                  1
# 669339                   DMSM_GETMEDIACONTENT (N/A)                  1
# 569989                   DMSM_GETMEDIACONTENT (N/A)                  1
# 217890                   DMSM_GETMEDIACONTENT (N/A)                  1
# ...                                             ...                ...
# 216163  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 339336  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 428702  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 430972  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 420896  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 454986  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 367886  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 226016  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 191426  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 420903  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 32769   USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 481237  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 253335  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 557646  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 326063  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 201761  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 2886    USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 73520   USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 255513  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 571931  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 315853  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 105894  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 277256  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 298958  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 226011  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 32758   USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 422291  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 380109  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 522181  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
# 240512  USR:WH-DELIVERY RECORD-ENSURE RESULTS (N/A)                  1
#
#        application_name         dt      strt subtimername  \
# 627225       POWERCHART 2018-07-17  0.077647          NaN
# 321786       POWERCHART 2018-07-18  0.077975          NaN
# 166151       POWERCHART 2018-07-19  0.129868          NaN
# 3945         POWERCHART 2018-07-23  0.072386          NaN
# 75089        POWERCHART 2018-07-24  0.068667          NaN
# 371081       POWERCHART 2018-07-25  0.077925          NaN
# 667501       POWERCHART 2018-07-26  0.127473          NaN
# 134037       POWERCHART 2018-07-27  0.069255          NaN
# 30443        POWERCHART 2018-07-30  0.071464          NaN
# 290495       POWERCHART 2018-07-31  0.273690          NaN
# 495111       POWERCHART 2018-08-01  0.143897          NaN
# 352819       POWERCHART 2018-08-02  0.074053          NaN
# 52266        POWERCHART 2018-08-03  0.086916          NaN
# 507358       POWERCHART 2018-08-06  0.080803          NaN
# 589607       POWERCHART 2018-08-07  0.085864          NaN
# 142350       POWERCHART 2018-08-08  0.093581          NaN
# 26699        POWERCHART 2018-08-09  0.104255          NaN
# 90320        POWERCHART 2018-08-10  0.097991          NaN
# 318894       POWERCHART 2018-08-14  0.070129          NaN
# 557502       POWERCHART 2018-08-15  0.081760          NaN
# 314501       POWERCHART 2018-08-16  0.109795          NaN
# 77922        POWERCHART 2018-08-17  0.073036          NaN
# 43825        POWERCHART 2018-08-20  0.096728          NaN
# 212261       POWERCHART 2018-08-21  0.105542          NaN
# 670191       POWERCHART 2018-08-22  0.074734          NaN
# 573386       POWERCHART 2018-08-23  0.103197          NaN
# 345626       POWERCHART 2018-08-24  0.085955          NaN
# 669339       POWERCHART 2018-08-27  0.079786          NaN
# 569989       POWERCHART 2018-08-28  0.105092          NaN
# 217890       POWERCHART 2018-08-29  0.077442          NaN
# ...                 ...        ...       ...          ...
# 216163       POWERCHART 2018-08-28  3.711754          NaN
# 339336       POWERCHART 2018-08-29  3.374766          NaN
# 428702       POWERCHART 2018-08-30  4.440766          NaN
# 430972       POWERCHART 2018-08-31  3.748155          NaN
# 420896       POWERCHART 2018-09-05  4.052206          NaN
# 454986       POWERCHART 2018-09-06  3.934355          NaN
# 367886       POWERCHART 2018-09-07  3.487045          NaN
# 226016       POWERCHART 2018-09-11  4.376641          NaN
# 191426       POWERCHART 2018-09-12  4.013126          NaN
# 420903       POWERCHART 2018-09-13  4.034174          NaN
# 32769        POWERCHART 2018-09-14  3.909331          NaN
# 481237       POWERCHART 2018-09-17  4.164425          NaN
# 253335       POWERCHART 2018-09-18  4.305383          NaN
# 557646       POWERCHART 2018-09-19  4.199626          NaN
# 326063       POWERCHART 2018-09-20  3.840833          NaN
# 201761       POWERCHART 2018-09-21  4.157388          NaN
# 2886         POWERCHART 2018-09-24  3.544378          NaN
# 73520        POWERCHART 2018-09-25  3.780417          NaN
# 255513       POWERCHART 2018-09-26  4.128597          NaN
# 571931       POWERCHART 2018-09-27  3.785608          NaN
# 315853       POWERCHART 2018-09-28  3.793539          NaN
# 105894       POWERCHART 2018-10-01  3.758748          NaN
# 277256       POWERCHART 2018-10-02  3.640664          NaN
# 298958       POWERCHART 2018-10-04  5.265499          NaN
# 226011       POWERCHART 2018-10-05  4.127223          NaN
# 32758        POWERCHART 2018-10-08  3.735527          NaN
# 422291       POWERCHART 2018-10-09  3.649069          NaN
# 380109       POWERCHART 2018-10-10  3.760897          NaN
# 522181       POWERCHART 2018-10-11  3.818554          NaN
# 240512       POWERCHART 2018-10-12  3.615590          NaN
#
#                                     timername  total_elapsed  transAbove5  \
# 627225                   DMSM_GETMEDIACONTENT        928.780            0
# 321786                   DMSM_GETMEDIACONTENT        932.560            0
# 166151                   DMSM_GETMEDIACONTENT        861.357            0
# 3945                     DMSM_GETMEDIACONTENT        904.326            0
# 75089                    DMSM_GETMEDIACONTENT        837.677            0
# 371081                   DMSM_GETMEDIACONTENT        850.282            0
# 667501                   DMSM_GETMEDIACONTENT        893.685            0
# 134037                   DMSM_GETMEDIACONTENT        703.502            0
# 30443                    DMSM_GETMEDIACONTENT        856.344            0
# 290495                   DMSM_GETMEDIACONTENT        880.955            1
# 495111                   DMSM_GETMEDIACONTENT        900.327            1
# 352819                   DMSM_GETMEDIACONTENT        889.563            0
# 52266                    DMSM_GETMEDIACONTENT        777.760            0
# 507358                   DMSM_GETMEDIACONTENT        908.990            0
# 589607                   DMSM_GETMEDIACONTENT        931.508            0
# 142350                   DMSM_GETMEDIACONTENT        900.311            0
# 26699                    DMSM_GETMEDIACONTENT        938.544            0
# 90320                    DMSM_GETMEDIACONTENT        782.390            0
# 318894                   DMSM_GETMEDIACONTENT        921.509            0
# 557502                   DMSM_GETMEDIACONTENT        900.628            0
# 314501                   DMSM_GETMEDIACONTENT        939.268            1
# 77922                    DMSM_GETMEDIACONTENT        762.252            0
# 43825                    DMSM_GETMEDIACONTENT        923.240            0
# 212261                   DMSM_GETMEDIACONTENT        983.956            0
# 670191                   DMSM_GETMEDIACONTENT        902.111            0
# 573386                   DMSM_GETMEDIACONTENT        956.747            0
# 345626                   DMSM_GETMEDIACONTENT        737.080            0
# 669339                   DMSM_GETMEDIACONTENT        956.114            0
# 569989                   DMSM_GETMEDIACONTENT        971.635            0
# 217890                   DMSM_GETMEDIACONTENT        873.157            0
# ...                                       ...            ...          ...
# 216163  USR:WH-DELIVERY RECORD-ENSURE RESULTS        380.335           42
# 339336  USR:WH-DELIVERY RECORD-ENSURE RESULTS        310.358           36
# 428702  USR:WH-DELIVERY RECORD-ENSURE RESULTS        421.548           46
# 430972  USR:WH-DELIVERY RECORD-ENSURE RESULTS        359.458           40
# 420896  USR:WH-DELIVERY RECORD-ENSURE RESULTS        409.857           44
# 454986  USR:WH-DELIVERY RECORD-ENSURE RESULTS        356.669           38
# 367886  USR:WH-DELIVERY RECORD-ENSURE RESULTS        456.361           53
# 226016  USR:WH-DELIVERY RECORD-ENSURE RESULTS        400.371           43
# 191426  USR:WH-DELIVERY RECORD-ENSURE RESULTS        280.377           31
# 420903  USR:WH-DELIVERY RECORD-ENSURE RESULTS        451.235           51
# 32769   USR:WH-DELIVERY RECORD-ENSURE RESULTS        329.904           34
# 481237  USR:WH-DELIVERY RECORD-ENSURE RESULTS        367.804           42
# 253335  USR:WH-DELIVERY RECORD-ENSURE RESULTS        260.176           28
# 557646  USR:WH-DELIVERY RECORD-ENSURE RESULTS        361.667           39
# 326063  USR:WH-DELIVERY RECORD-ENSURE RESULTS        409.504           45
# 201761  USR:WH-DELIVERY RECORD-ENSURE RESULTS        341.620           38
# 2886    USR:WH-DELIVERY RECORD-ENSURE RESULTS        303.532           35
# 73520   USR:WH-DELIVERY RECORD-ENSURE RESULTS        394.814           43
# 255513  USR:WH-DELIVERY RECORD-ENSURE RESULTS        361.065           40
# 571931  USR:WH-DELIVERY RECORD-ENSURE RESULTS        342.199           40
# 315853  USR:WH-DELIVERY RECORD-ENSURE RESULTS        346.592           37
# 105894  USR:WH-DELIVERY RECORD-ENSURE RESULTS        353.719           40
# 277256  USR:WH-DELIVERY RECORD-ENSURE RESULTS        377.708           42
# 298958  USR:WH-DELIVERY RECORD-ENSURE RESULTS        271.731           28
# 226011  USR:WH-DELIVERY RECORD-ENSURE RESULTS        242.042           27
# 32758   USR:WH-DELIVERY RECORD-ENSURE RESULTS        290.554           33
# 422291  USR:WH-DELIVERY RECORD-ENSURE RESULTS        307.879           35
# 380109  USR:WH-DELIVERY RECORD-ENSURE RESULTS        312.688           36
# 522181  USR:WH-DELIVERY RECORD-ENSURE RESULTS        335.575           41
# 240512  USR:WH-DELIVERY RECORD-ENSURE RESULTS        367.508           38
#
#         transUnder2  transaction_cnt     isBDay    mavg30
# 627225         6062             6063 2018-07-17       NaN
# 321786         5956             5956 2018-07-18       NaN
# 166151         5364             5369 2018-07-19       NaN
# 3945           6217             6217 2018-07-23       NaN
# 75089          5890             5890 2018-07-24       NaN
# 371081         5897             5898 2018-07-25       NaN
# 667501         5668             5673 2018-07-26       NaN
# 134037         4993             4993 2018-07-27       NaN
# 30443          6038             6038 2018-07-30       NaN
# 290495         6210             6211 2018-07-31       NaN
# 495111         6230             6231 2018-08-01       NaN
# 352819         6090             6090 2018-08-02       NaN
# 52266          5006             5007 2018-08-03       NaN
# 507358         6021             6021 2018-08-06       NaN
# 589607         6202             6203 2018-08-07       NaN
# 142350         5663             5664 2018-08-08       NaN
# 26699          5701             5702 2018-08-09       NaN
# 90320          4969             4971 2018-08-10       NaN
# 318894         6318             6318 2018-08-14       NaN
# 557502         6110             6110 2018-08-15       NaN
# 314501         6180             6181 2018-08-16       NaN
# 77922          5042             5042 2018-08-17       NaN
# 43825          5939             5941 2018-08-20       NaN
# 212261         6153             6155 2018-08-21       NaN
# 670191         5971             5971 2018-08-22       NaN
# 573386         6023             6026 2018-08-23       NaN
# 345626         4960             4961 2018-08-24       NaN
# 669339         6325             6325 2018-08-27       NaN
# 569989         6498             6499 2018-08-28       NaN
# 217890         6017             6017 2018-08-29  0.151333
# ...             ...              ...        ...       ...
# 216163           30               80 2018-08-28       NaN
# 339336           39               82 2018-08-29       NaN
# 428702           35               85 2018-08-30       NaN
# 430972           44               88 2018-08-31  4.358333
# 420896           32               83 2018-09-05  4.368333
# 454986           42               86 2018-09-06  4.347000
# 367886           52              113 2018-09-07  4.356333
# 226016           36               80 2018-09-11  4.375667
# 191426           34               68 2018-09-12  4.371333
# 420903           34               91 2018-09-13  4.396000
# 32769            37               79 2018-09-14  4.386333
# 481237           35               78 2018-09-17  4.409667
# 253335           29               58 2018-09-18  4.391000
# 557646           30               73 2018-09-19  4.407667
# 326063           33               86 2018-09-20  4.416000
# 201761           36               78 2018-09-21  4.437000
# 2886             25               66 2018-09-24  4.437667
# 73520            40               92 2018-09-25  4.439667
# 255513           34               76 2018-09-26  4.444667
# 571931           39               82 2018-09-27  4.423333
# 315853           48               89 2018-09-28  4.419333
# 105894           34               78 2018-10-01  4.442000
# 277256           49               97 2018-10-02  4.425333
# 298958           27               58 2018-10-04  4.434667
# 226011           22               51 2018-10-05  4.454000
# 32758            24               60 2018-10-08  4.478667
# 422291           27               68 2018-10-09  4.464667
# 380109           39               77 2018-10-10  4.457000
# 522181           33               74 2018-10-11  4.473000
# 240512           42               92 2018-10-12  4.459000
#
# [156262 rows x 16 columns]

# %% [markdown]
# ### Investigate the data on a weekly basis
#
# Counts
# Sums
# Averages
# Variance

# %% [markdown]
# ### Continue post-processing:
# - include "magnitude of change"
# -

# %% [markdown]
# ### Write out to csv:

# %%
atrt_df_PC.to_csv('C:\\Users\\khickman1\\Desktop\\PCMavg30.csv', sep=',')

# %% [markdown]
# ### Stuff I learned:
#
# - Moving average example
# - Subsetting
# - Date and column filtering
# - Here, index by both date and by timer/subtimer using pandas 'set index'
# - Indexing
# - Sorting
# - Get unique values
# - grouping
# - filtering outliers (clipping, trimming, winsorizing)
# - moving data
#
# ```
# open_chart = atrt_df['Timer Subtimer Name' == "USR:PWR-OPEN CHART (DISCERNRPT/DISCERNPCTAB.DLL)"]
# open_chart = atrt_df[atrt_df['Timer Subtimer Name'] == 'USR:PWR-OPEN CHART (DISCERNRPT/DISCERNPCTAB.DLL)']
# open_chart = open_chart[open_chart['application_name']== 'POWERCHART']
# open_chart_post = open_chart[(open_chart['dt'] > '2018-07-01') & (open_chart['dt'] < '2018-09-30')]
# open_chart = open_chart.set_index(['Timer Subtimer Name', 'dt'])
# open_chart = open_chart.sort_index(axis=0)
# open_chart['moving_avg'] = open_chart['ATRT'].rolling(30).mean()
# atrt_df['dt'] = pd.to_datetime(atrt_df['dt'].dt.date)
# atrt_high_trans = atrt_df[atrt_df['transaction_cnt'] > 1000]
# atrt_high_trans.sort_values(by=['transaction_cnt'], ascending=False)
# len(atrt_high_trans)
# grp_high_trans = atrt_high_trans.groupby(["Timer Subtimer Name", "dt"])
# grp_high_trans.head()
# open_chart_post.groupby('Timer Subtimer Name').nunique()
# len(open_chart_post['Timer Subtimer Name'].unique())
# len(open_chart_post)
# open_chart_slim = open_chart_post[['ATRT', 'dt']]
# open_chart_slim.set_index('dt')
# open_chart_slim.sort_values('dt')
#
# Stuff that didn't work
# #atrt_df_PC = atrt_df_PC[['Timer Subtimer Name', 'dt', 'ATRT', 'application_name']]
# #atrt_df_PC['mavg30'] = atrt_df_PC['ATRT'].rolling(30).mean()
# #PC = atrt_df_PC.groupby(['Timer Subtimer Name', 'dt'])
# #atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name', 'dt'])
# #PC = atrt_df_PC
# #PC.head()
# #atrt_df_PC = atrt_df_PC.set_index(['Timer Subtimer Name'])
# #atrt_df_PC = atrt_df_PC.sort_index(axis=0)
# #atrt_df_PC = atrt_df_PC.groupby(['Timer Subtimer Name'])
# #atrt_df_PC = atrt_df_PC.sort(['Timer Subtimer Name', 'dt']).groupby('Timer Subtimer Name')
# #atrt_df_PC['mavg30'] = atrt_df_PC['ATRT'].rolling(30).mean()
# #atrt_df_PC[0:100]```

# %% [markdown]
# Getting csv from website example
# ```
# import csv
# import urllib3
# import requests
#
# #This URL will be the URL that your login form points to with the "action" tag.
# post_login_url = 'https://cernercare.com/accounts/login?returnTo=https%3A%2F%2Flightson.cerner.com%2Fsocial-auth%2Fcomplete%2Fprofessional%2F%3Fjanrain_nonce%3D2018-10-23T15%253A00%253A41ZYe3mOd'
#
# #This URL is the page you actually want to pull down with requests.
# request_url = 'https://lightson.cerner.com/clients/CHP_IN/domains/P1558/kpi/response-time/worst-timers.csv?dt=2018-10-22'
# #request_url = 'https://lightson.cerner.com/api/metrics/trend.csv?category_name=Performance&metrics%5B%5D=RT_2SEC&cdr_ids=95370&data_type=ENVIRONMENT&date_type=DAILY&days_of_week=1%2C2%2C3%2C4%2C5%2C6%2C7&doc_cuid=LONfa31c997c3d543768036e2941&end_date=2018-10-22&physician_rollup_flag=2&start_date=2018-07-25'
#
# payload = {
#     'username': 'khickman1',
#     'pass': 'Sw@gelok01!'
# }
#
# with requests.Session() as session:
#     post = session.post(post_login_url, data=payload)
#     r = session.get(request_url)
#     decoded_content = r.content.decode('utf-8')
#     cr = csv.reader(decoded_content.splitlines(), delimiter=',')
#     my_list = list(cr)
#     for row in my_list:
#         print(row)
#
# for row in cr:
#     with open("daily.csv", "wb") as f:
#         writer = csv.writer(f)
#         writer.writerows(row)
# ```
